# %% [markdown]
# <a href="https://colab.research.google.com/github/shaon11579/DNN-fall-2021/blob/main/Assignment_3_NN_v3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Introduction
# The aim of this shor report is three folds: first, implement the ResNet50 architecture and evaluate the performance of the model on Tiny ImageNet dataset. Second, download the pretrained weights of ResNet 50 model on ImageNet dataset and prsent outcomes. Third, select best model from 15 classfications task, and traina single DCNN and ensambled three models and compare the results with the single model.
#
#  - **What is Transferleanring and how it works?**
#
#  Transfer learning itself is a very simple yet powerful concept. It is about solving a bespoke task by leveraging the knowledge impregnated in a model that’s already good at solving a similar task. Following the long-standing tradition of “a picture worth a thousand words”, here’s a depiction of transfer learning process.
#
# ### Why Transfer Learning Now?
#
#
# ### Overview of the Ensemble models
#
#
# ### Ensemble Techniques
# Bagging
# - The idea of bagging is based on making the training data available to an iterative process of learning. Each model learns the error produced by the previous model using a slightly different subset of the training dataset. Bagging reduces variance and minimizes overfitting. One example of such a technique is the Random Forest algorithm.
#
# Boosting
# - Adaptive Boosting (AdaBoost): is an ensemble of algorithms, where we build models on the top of several weak learners [1]. As we mentioned earlier, those learners are called weak because they are typically simple with limited prediction capabilities. The adaptation capability of AdaBoost made this technique one of the earliest successful binary classifiers. Sequential decision trees were the core of such adaptability where each tree is adjusting its weights based on prior knowledge of accuracies. Hence, we perform the training in such a technique in sequential rather than parallel process. In this technique, the process of training and measuring the error in estimates can be repeated for a given number of iteration or when the error rate is not changing significantly.
#
#
#
#
#
# # 3. Methodology
#  **Data**:
# The Tiny ImageNet dataset is a modified
# subset of the original ImageNet dataset.
# Here, there are 200 different classes instead of
# 1000 classes of ImageNet dataset, with
# 100,000 training examples and 10,000
# validation examples. The resolution of the
# images is just 64x64 pixels, which makes it
# more challenging to extract information from
# it. A glance at the images shows that it is
# difficult for the human eye to detect objects in
# some images.
#
# **Importing Data:**
# Deep Learning models require machine with high computational power. For this task, I have implemented the project on Google Collaboratory. For the project I will be using TensorFlow and matplotlib library and other packages as needed.
#
#
# # 4. Deep Learning Architecture
#
#
# # 5. Experiment and Results
#
# # i. Training and testing logs
# # ii. Discussion and comparison (if necessary)
# # 6. Conclusion

# %%
import time
import copy
import numpy as np
import matplotlib.pyplot as plt

import torch
import torchvision
import torch.nn as nn
import torch.optim as optim
import torchvision.transforms as transforms
from torch.utils.data import DataLoader

torch.manual_seed(17)

# %%
kaggle datasets download -d akash2sharma/tiny-imagenet
# Out:
#   File "<ipython-input-2-77a86f0407ec>", line 1
#     kaggle datasets download -d akash2sharma/tiny-imagenet
#                   ^
# SyntaxError: invalid syntax

# %%
! pip install -q kaggle

# %%
! mkdir ~/content/kaggle.json
# Out:
# mkdir: cannot create directory ‘/root/content/kaggle.json’: No such file or directory

# %%
! chmod 600 ~/.kaggle/kaggle.json
# Out:
# chmod: cannot access '/root/.kaggle/kaggle.json': No such file or directory

# %%
! kaggle competitions download 'https://www.kaggle.com/akash2sharma/tiny-imagenet'
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/kaggle", line 5, in <module>
#     from kaggle.cli import main
#   File "/usr/local/lib/python2.7/dist-packages/kaggle/__init__.py", line 23, in <module>
#     api.authenticate()
#   File "/usr/local/lib/python2.7/dist-packages/kaggle/api/kaggle_api_extended.py", line 146, in authenticate
#     self.config_file, self.config_dir))
# IOError: Could not find kaggle.json. Make sure it's located in /root/.kaggle. Or use the environment method.

# %%
! kaggle datasets download -d akash2sharma/tiny-imagenet
# Out:
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 /root/.kaggle/kaggle.json'
# 401 - Unauthorized

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

print(os.listdir("../input/tiny-imagenet/tiny-imagenet-200"))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-843af4c96634> in <module>()
#       4 import os
#       5
# ----> 6 print(os.listdir("../input/tiny-imagenet/tiny-imagenet-200"))
#
# FileNotFoundError: [Errno 2] No such file or directory: '../input/tiny-imagenet/tiny-imagenet-200'

# %% [markdown]
# # Data preparation

# %%
# !pip install onedrivesdk
# Out:
# Collecting onedrivesdk
#   Downloading onedrivesdk-2.0.1-py2.py3-none-any.whl (2.2 kB)
# Installing collected packages: onedrivesdk
# Successfully installed onedrivesdk-2.0.1

# %%
# !pip install -q kaggle

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-1ac2ffc9-a6e2-42c2-b594-5942106118b6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1ac2ffc9-a6e2-42c2-b594-5942106118b6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# {'kaggle.json': b'{"username":"shaon11579","key":"b3304201683dc95ee8cd4d81d98dfeb7"}'}

# %%
! mkdir ~/.kaggle
# Out:
# mkdir: cannot create directory ‘/root/.kaggle’: File exists

# %%
#copy keggle.json file 

! cp kaggle.json ~/.kaggle/

# %%
# grant permission

# %%
transform = transforms.Compose([ 
    transforms.Resize((224, 224)), 
    transforms.ToTensor()
])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-f419a10676f4> in <module>()
# ----> 1 transform = transforms.Compose([
#       2     transforms.Resize((224, 224)),
#       3     transforms.ToTensor()
#       4 ])
#
# NameError: name 'transforms' is not defined

# %%
dataset = torchvision.datasets.ImageFolder('kaggle kernels output ivankunyankin/googlenet-inception-from-scratch-using-pytorch -p /path/to/dest', transform=transform)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-507722d29145> in <module>()
# ----> 1 dataset = torchvision.datasets.ImageFolder('kaggle kernels output ivankunyankin/googlenet-inception-from-scratch-using-pytorch -p /path/to/dest', transform=transform)
#
# NameError: name 'torchvision' is not defined

# %%
transform = transforms.Compose([ 
    transforms.Resize((224, 224)), 
    transforms.ToTensor()
])

# %%
dataset = torchvision.datasets.ImageFolder('https://www.kaggle.com/akash2sharma/tiny-imagenet', transform=transform)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-11-7d757be22ec7> in <module>()
# ----> 1 dataset = torchvision.datasets.ImageFolder('https://www.kaggle.com/akash2sharma/tiny-imagenet', transform=transform)
#
# /usr/local/lib/python3.7/dist-packages/torchvision/datasets/folder.py in __init__(self, root, transform, target_transform, loader, is_valid_file)
#     311                                           transform=transform,
#     312                                           target_transform=target_transform,
# --> 313                                           is_valid_file=is_valid_file)
#     314         self.imgs = self.samples
#
# /usr/local/lib/python3.7/dist-packages/torchvision/datasets/folder.py in __init__(self, root, loader, extensions, transform, target_transform, is_valid_file)
#     143         super(DatasetFolder, self).__init__(root, transform=transform,
#     144                                             target_transform=target_transform)
# --> 145         classes, class_to_idx = self.find_classes(self.root)
#     146         samples = self.make_dataset(self.root, class_to_idx, extensions, is_valid_file)
#     147
#
# /usr/local/lib/python3.7/dist-packages/torchvision/datasets/folder.py in find_classes(self, directory)
#     219             (Tuple[List[str], Dict[str, int]]): List of all classes and dictionary mapping each class to an index.
#     220         """
# --> 221         return find_classes(directory)
#     222
#     223     def __getitem__(self, index: int) -> Tuple[Any, Any]:
#
# /usr/local/lib/python3.7/dist-packages/torchvision/datasets/folder.py in find_classes(directory)
#      38     See :class:`DatasetFolder` for details.
#      39     """
# ---> 40     classes = sorted(entry.name for entry in os.scandir(directory) if entry.is_dir())
#      41     if not classes:
#      42         raise FileNotFoundError(f"Couldn't find any class folder in {directory}.")
#
# FileNotFoundError: [Errno 2] No such file or directory: 'https://www.kaggle.com/akash2sharma/tiny-imagenet'

# %%
#list data from kaggle 
! kaggle datasets list
# Out:
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 /root/.kaggle/kaggle.json'
# Warning: Looks like you're using an outdated API Version, please consider updating (server 1.5.12 / client 1.5.4)
# ref                                                         title                                              size  lastUpdated          downloadCount
# ----------------------------------------------------------  ------------------------------------------------  -----  -------------------  -------------
# gpreda/reddit-vaccine-myths                                 Reddit Vaccine Myths                              235KB  2021-10-01 17:39:01          13061
# crowww/a-large-scale-fish-dataset                           A Large Scale Fish Dataset                          3GB  2021-04-28 17:03:01           7880
# imsparsh/musicnet-dataset                                   MusicNet Dataset                                   22GB  2021-02-18 14:12:19           3430
# dhruvildave/wikibooks-dataset                               Wikibooks Dataset                                   2GB  2021-07-03 18:37:20           3047
# fatiimaezzahra/famous-iconic-women                          Famous Iconic Women                               838MB  2021-02-28 14:56:00           1475
# nickuzmenkov/nih-chest-xrays-tfrecords                      NIH Chest X-rays TFRecords                         11GB  2021-03-09 04:49:23           1241
# promptcloud/careerbuilder-job-listing-2020                  Careerbuilder Job Listing 2020                     42MB  2021-03-05 06:59:52           2048
# coloradokb/dandelionimages                                  DandelionImages                                     4GB  2021-02-19 20:03:47            860
# mathurinache/twitter-edge-nodes                             Twitter Edge Nodes                                342MB  2021-03-08 06:43:04            998
# simiotic/github-code-snippets                               GitHub Code Snippets                                7GB  2021-03-03 11:34:39            356
# mathurinache/the-lj-speech-dataset                          The LJ Speech Dataset                               3GB  2021-02-15 09:19:54            363
# stuartjames/lights                                          LightS: Light Specularity Dataset                  18GB  2021-02-18 14:32:26            159
# alsgroup/end-als                                            End ALS Kaggle Challenge                           12GB  2021-04-08 12:16:37            924
# imsparsh/accentdb-core-extended                             AccentDB - Core & Extended                          6GB  2021-02-17 14:22:54            145
# landrykezebou/lvzhdr-tone-mapping-benchmark-dataset-tmonet  LVZ-HDR Tone Mapping Benchmark Dataset (TMO-Net)   24GB  2021-03-01 05:03:40            212
# nickuzmenkov/ranzcr-clip-kfold-tfrecords                    RANZCR CLiP KFold TFRecords                         2GB  2021-02-21 13:29:51            135
# datasnaek/youtube-new                                       Trending YouTube Video Statistics                 201MB  2019-06-03 00:56:47         153025
# zynicide/wine-reviews                                       Wine Reviews                                       51MB  2017-11-27 17:08:04         144789
# datasnaek/chess                                             Chess Game Dataset (Lichess)                        3MB  2017-09-04 03:09:09          22451
# residentmario/ramen-ratings                                 Ramen Ratings                                      40KB  2018-01-11 16:04:39          27552

# %%
# !kaggle datasets download -d akash2sharma/tiny-imagenet
# Out:
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 /root/.kaggle/kaggle.json'
# Downloading tiny-imagenet.zip to /content
#  97% 460M/474M [00:02<00:00, 183MB/s]
# 100% 474M/474M [00:02<00:00, 170MB/s]

# %%
# !unzip tiny-imagenet.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: tiny-imagenet-200/val/images/val_5500.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5501.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5502.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5503.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5504.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5505.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5506.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5507.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5508.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5509.JPEG
#   inflating: tiny-imagenet-200/val/images/val_551.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5510.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5511.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5512.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5513.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5514.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5515.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5516.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5517.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5518.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5519.JPEG
#   inflating: tiny-imagenet-200/val/images/val_552.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5520.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5521.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5522.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5523.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5524.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5525.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5526.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5527.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5528.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5529.JPEG
#   inflating: tiny-imagenet-200/val/images/val_553.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5530.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5531.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5532.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5533.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5534.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5535.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5536.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5537.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5538.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5539.JPEG
#   inflating: tiny-imagenet-200/val/images/val_554.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5540.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5541.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5542.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5543.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5544.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5545.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5546.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5547.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5548.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5549.JPEG
#   inflating: tiny-imagenet-200/val/images/val_555.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5550.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5551.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5552.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5553.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5554.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5555.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5556.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5557.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5558.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5559.JPEG
#   inflating: tiny-imagenet-200/val/images/val_556.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5560.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5561.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5562.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5563.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5564.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5565.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5566.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5567.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5568.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5569.JPEG
#   inflating: tiny-imagenet-200/val/images/val_557.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5570.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5571.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5572.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5573.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5574.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5575.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5576.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5577.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5578.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5579.JPEG
#   inflating: tiny-imagenet-200/val/images/val_558.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5580.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5581.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5582.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5583.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5584.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5585.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5586.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5587.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5588.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5589.JPEG
#   inflating: tiny-imagenet-200/val/images/val_559.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5590.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5591.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5592.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5593.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5594.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5595.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5596.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5597.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5598.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5599.JPEG
#   inflating: tiny-imagenet-200/val/images/val_56.JPEG
#   inflating: tiny-imagenet-200/val/images/val_560.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5600.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5601.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5602.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5603.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5604.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5605.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5606.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5607.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5608.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5609.JPEG
#   inflating: tiny-imagenet-200/val/images/val_561.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5610.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5611.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5612.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5613.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5614.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5615.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5616.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5617.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5618.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5619.JPEG
#   inflating: tiny-imagenet-200/val/images/val_562.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5620.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5621.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5622.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5623.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5624.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5625.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5626.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5627.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5628.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5629.JPEG
#   inflating: tiny-imagenet-200/val/images/val_563.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5630.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5631.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5632.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5633.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5634.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5635.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5636.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5637.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5638.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5639.JPEG
#   inflating: tiny-imagenet-200/val/images/val_564.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5640.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5641.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5642.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5643.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5644.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5645.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5646.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5647.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5648.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5649.JPEG
#   inflating: tiny-imagenet-200/val/images/val_565.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5650.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5651.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5652.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5653.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5654.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5655.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5656.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5657.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5658.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5659.JPEG
#   inflating: tiny-imagenet-200/val/images/val_566.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5660.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5661.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5662.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5663.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5664.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5665.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5666.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5667.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5668.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5669.JPEG
#   inflating: tiny-imagenet-200/val/images/val_567.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5670.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5671.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5672.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5673.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5674.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5675.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5676.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5677.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5678.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5679.JPEG
#   inflating: tiny-imagenet-200/val/images/val_568.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5680.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5681.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5682.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5683.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5684.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5685.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5686.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5687.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5688.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5689.JPEG
#   inflating: tiny-imagenet-200/val/images/val_569.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5690.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5691.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5692.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5693.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5694.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5695.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5696.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5697.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5698.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5699.JPEG
#   inflating: tiny-imagenet-200/val/images/val_57.JPEG
#   inflating: tiny-imagenet-200/val/images/val_570.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5700.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5701.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5702.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5703.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5704.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5705.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5706.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5707.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5708.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5709.JPEG
#   inflating: tiny-imagenet-200/val/images/val_571.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5710.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5711.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5712.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5713.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5714.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5715.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5716.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5717.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5718.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5719.JPEG
#   inflating: tiny-imagenet-200/val/images/val_572.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5720.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5721.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5722.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5723.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5724.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5725.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5726.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5727.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5728.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5729.JPEG
#   inflating: tiny-imagenet-200/val/images/val_573.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5730.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5731.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5732.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5733.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5734.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5735.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5736.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5737.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5738.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5739.JPEG
#   inflating: tiny-imagenet-200/val/images/val_574.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5740.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5741.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5742.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5743.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5744.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5745.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5746.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5747.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5748.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5749.JPEG
#   inflating: tiny-imagenet-200/val/images/val_575.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5750.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5751.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5752.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5753.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5754.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5755.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5756.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5757.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5758.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5759.JPEG
#   inflating: tiny-imagenet-200/val/images/val_576.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5760.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5761.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5762.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5763.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5764.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5765.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5766.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5767.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5768.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5769.JPEG
#   inflating: tiny-imagenet-200/val/images/val_577.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5770.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5771.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5772.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5773.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5774.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5775.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5776.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5777.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5778.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5779.JPEG
#   inflating: tiny-imagenet-200/val/images/val_578.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5780.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5781.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5782.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5783.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5784.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5785.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5786.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5787.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5788.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5789.JPEG
#   inflating: tiny-imagenet-200/val/images/val_579.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5790.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5791.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5792.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5793.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5794.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5795.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5796.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5797.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5798.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5799.JPEG
#   inflating: tiny-imagenet-200/val/images/val_58.JPEG
#   inflating: tiny-imagenet-200/val/images/val_580.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5800.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5801.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5802.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5803.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5804.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5805.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5806.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5807.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5808.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5809.JPEG
#   inflating: tiny-imagenet-200/val/images/val_581.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5810.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5811.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5812.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5813.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5814.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5815.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5816.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5817.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5818.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5819.JPEG
#   inflating: tiny-imagenet-200/val/images/val_582.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5820.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5821.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5822.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5823.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5824.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5825.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5826.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5827.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5828.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5829.JPEG
#   inflating: tiny-imagenet-200/val/images/val_583.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5830.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5831.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5832.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5833.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5834.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5835.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5836.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5837.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5838.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5839.JPEG
#   inflating: tiny-imagenet-200/val/images/val_584.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5840.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5841.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5842.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5843.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5844.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5845.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5846.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5847.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5848.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5849.JPEG
#   inflating: tiny-imagenet-200/val/images/val_585.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5850.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5851.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5852.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5853.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5854.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5855.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5856.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5857.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5858.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5859.JPEG
#   inflating: tiny-imagenet-200/val/images/val_586.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5860.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5861.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5862.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5863.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5864.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5865.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5866.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5867.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5868.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5869.JPEG
#   inflating: tiny-imagenet-200/val/images/val_587.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5870.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5871.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5872.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5873.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5874.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5875.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5876.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5877.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5878.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5879.JPEG
#   inflating: tiny-imagenet-200/val/images/val_588.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5880.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5881.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5882.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5883.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5884.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5885.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5886.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5887.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5888.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5889.JPEG
#   inflating: tiny-imagenet-200/val/images/val_589.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5890.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5891.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5892.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5893.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5894.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5895.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5896.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5897.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5898.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5899.JPEG
#   inflating: tiny-imagenet-200/val/images/val_59.JPEG
#   inflating: tiny-imagenet-200/val/images/val_590.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5900.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5901.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5902.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5903.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5904.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5905.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5906.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5907.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5908.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5909.JPEG
#   inflating: tiny-imagenet-200/val/images/val_591.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5910.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5911.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5912.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5913.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5914.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5915.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5916.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5917.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5918.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5919.JPEG
#   inflating: tiny-imagenet-200/val/images/val_592.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5920.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5921.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5922.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5923.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5924.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5925.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5926.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5927.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5928.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5929.JPEG
#   inflating: tiny-imagenet-200/val/images/val_593.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5930.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5931.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5932.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5933.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5934.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5935.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5936.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5937.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5938.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5939.JPEG
#   inflating: tiny-imagenet-200/val/images/val_594.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5940.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5941.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5942.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5943.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5944.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5945.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5946.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5947.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5948.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5949.JPEG
#   inflating: tiny-imagenet-200/val/images/val_595.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5950.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5951.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5952.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5953.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5954.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5955.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5956.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5957.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5958.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5959.JPEG
#   inflating: tiny-imagenet-200/val/images/val_596.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5960.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5961.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5962.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5963.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5964.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5965.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5966.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5967.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5968.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5969.JPEG
#   inflating: tiny-imagenet-200/val/images/val_597.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5970.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5971.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5972.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5973.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5974.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5975.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5976.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5977.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5978.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5979.JPEG
#   inflating: tiny-imagenet-200/val/images/val_598.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5980.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5981.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5982.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5983.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5984.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5985.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5986.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5987.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5988.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5989.JPEG
#   inflating: tiny-imagenet-200/val/images/val_599.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5990.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5991.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5992.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5993.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5994.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5995.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5996.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5997.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5998.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5999.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6.JPEG
#   inflating: tiny-imagenet-200/val/images/val_60.JPEG
#   inflating: tiny-imagenet-200/val/images/val_600.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6000.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6001.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6002.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6003.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6004.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6005.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6006.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6007.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6008.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6009.JPEG
#   inflating: tiny-imagenet-200/val/images/val_601.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6010.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6011.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6012.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6013.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6014.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6015.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6016.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6017.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6018.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6019.JPEG
#   inflating: tiny-imagenet-200/val/images/val_602.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6020.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6021.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6022.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6023.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6024.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6025.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6026.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6027.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6028.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6029.JPEG
#   inflating: tiny-imagenet-200/val/images/val_603.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6030.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6031.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6032.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6033.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6034.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6035.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6036.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6037.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6038.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6039.JPEG
#   inflating: tiny-imagenet-200/val/images/val_604.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6040.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6041.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6042.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6043.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6044.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6045.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6046.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6047.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6048.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6049.JPEG
#   inflating: tiny-imagenet-200/val/images/val_605.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6050.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6051.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6052.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6053.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6054.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6055.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6056.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6057.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6058.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6059.JPEG
#   inflating: tiny-imagenet-200/val/images/val_606.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6060.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6061.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6062.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6063.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6064.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6065.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6066.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6067.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6068.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6069.JPEG
#   inflating: tiny-imagenet-200/val/images/val_607.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6070.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6071.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6072.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6073.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6074.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6075.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6076.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6077.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6078.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6079.JPEG
#   inflating: tiny-imagenet-200/val/images/val_608.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6080.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6081.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6082.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6083.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6084.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6085.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6086.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6087.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6088.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6089.JPEG
#   inflating: tiny-imagenet-200/val/images/val_609.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6090.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6091.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6092.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6093.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6094.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6095.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6096.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6097.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6098.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6099.JPEG
#   inflating: tiny-imagenet-200/val/images/val_61.JPEG
#   inflating: tiny-imagenet-200/val/images/val_610.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6100.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6101.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6102.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6103.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6104.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6105.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6106.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6107.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6108.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6109.JPEG
#   inflating: tiny-imagenet-200/val/images/val_611.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6110.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6111.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6112.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6113.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6114.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6115.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6116.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6117.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6118.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6119.JPEG
#   inflating: tiny-imagenet-200/val/images/val_612.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6120.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6121.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6122.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6123.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6124.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6125.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6126.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6127.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6128.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6129.JPEG
#   inflating: tiny-imagenet-200/val/images/val_613.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6130.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6131.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6132.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6133.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6134.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6135.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6136.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6137.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6138.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6139.JPEG
#   inflating: tiny-imagenet-200/val/images/val_614.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6140.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6141.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6142.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6143.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6144.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6145.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6146.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6147.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6148.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6149.JPEG
#   inflating: tiny-imagenet-200/val/images/val_615.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6150.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6151.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6152.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6153.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6154.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6155.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6156.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6157.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6158.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6159.JPEG
#   inflating: tiny-imagenet-200/val/images/val_616.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6160.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6161.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6162.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6163.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6164.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6165.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6166.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6167.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6168.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6169.JPEG
#   inflating: tiny-imagenet-200/val/images/val_617.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6170.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6171.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6172.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6173.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6174.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6175.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6176.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6177.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6178.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6179.JPEG
#   inflating: tiny-imagenet-200/val/images/val_618.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6180.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6181.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6182.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6183.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6184.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6185.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6186.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6187.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6188.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6189.JPEG
#   inflating: tiny-imagenet-200/val/images/val_619.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6190.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6191.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6192.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6193.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6194.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6195.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6196.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6197.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6198.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6199.JPEG
#   inflating: tiny-imagenet-200/val/images/val_62.JPEG
#   inflating: tiny-imagenet-200/val/images/val_620.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6200.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6201.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6202.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6203.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6204.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6205.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6206.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6207.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6208.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6209.JPEG
#   inflating: tiny-imagenet-200/val/images/val_621.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6210.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6211.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6212.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6213.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6214.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6215.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6216.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6217.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6218.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6219.JPEG
#   inflating: tiny-imagenet-200/val/images/val_622.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6220.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6221.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6222.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6223.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6224.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6225.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6226.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6227.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6228.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6229.JPEG
#   inflating: tiny-imagenet-200/val/images/val_623.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6230.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6231.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6232.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6233.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6234.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6235.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6236.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6237.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6238.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6239.JPEG
#   inflating: tiny-imagenet-200/val/images/val_624.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6240.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6241.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6242.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6243.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6244.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6245.JPEG
# ...
#   inflating: tiny-imagenet-200/val/images/val_9753.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9754.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9755.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9756.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9757.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9758.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9759.JPEG
#   inflating: tiny-imagenet-200/val/images/val_976.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9760.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9761.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9762.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9763.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9764.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9765.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9766.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9767.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9768.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9769.JPEG
#   inflating: tiny-imagenet-200/val/images/val_977.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9770.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9771.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9772.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9773.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9774.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9775.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9776.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9777.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9778.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9779.JPEG
#   inflating: tiny-imagenet-200/val/images/val_978.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9780.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9781.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9782.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9783.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9784.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9785.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9786.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9787.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9788.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9789.JPEG
#   inflating: tiny-imagenet-200/val/images/val_979.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9790.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9791.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9792.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9793.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9794.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9795.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9796.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9797.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9798.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9799.JPEG
#   inflating: tiny-imagenet-200/val/images/val_98.JPEG
#   inflating: tiny-imagenet-200/val/images/val_980.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9800.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9801.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9802.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9803.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9804.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9805.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9806.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9807.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9808.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9809.JPEG
#   inflating: tiny-imagenet-200/val/images/val_981.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9810.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9811.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9812.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9813.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9814.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9815.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9816.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9817.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9818.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9819.JPEG
#   inflating: tiny-imagenet-200/val/images/val_982.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9820.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9821.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9822.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9823.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9824.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9825.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9826.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9827.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9828.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9829.JPEG
#   inflating: tiny-imagenet-200/val/images/val_983.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9830.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9831.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9832.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9833.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9834.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9835.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9836.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9837.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9838.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9839.JPEG
#   inflating: tiny-imagenet-200/val/images/val_984.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9840.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9841.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9842.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9843.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9844.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9845.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9846.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9847.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9848.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9849.JPEG
#   inflating: tiny-imagenet-200/val/images/val_985.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9850.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9851.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9852.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9853.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9854.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9855.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9856.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9857.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9858.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9859.JPEG
#   inflating: tiny-imagenet-200/val/images/val_986.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9860.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9861.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9862.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9863.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9864.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9865.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9866.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9867.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9868.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9869.JPEG
#   inflating: tiny-imagenet-200/val/images/val_987.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9870.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9871.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9872.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9873.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9874.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9875.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9876.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9877.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9878.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9879.JPEG
#   inflating: tiny-imagenet-200/val/images/val_988.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9880.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9881.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9882.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9883.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9884.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9885.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9886.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9887.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9888.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9889.JPEG
#   inflating: tiny-imagenet-200/val/images/val_989.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9890.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9891.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9892.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9893.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9894.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9895.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9896.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9897.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9898.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9899.JPEG
#   inflating: tiny-imagenet-200/val/images/val_99.JPEG
#   inflating: tiny-imagenet-200/val/images/val_990.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9900.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9901.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9902.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9903.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9904.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9905.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9906.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9907.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9908.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9909.JPEG
#   inflating: tiny-imagenet-200/val/images/val_991.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9910.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9911.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9912.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9913.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9914.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9915.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9916.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9917.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9918.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9919.JPEG
#   inflating: tiny-imagenet-200/val/images/val_992.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9920.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9921.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9922.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9923.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9924.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9925.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9926.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9927.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9928.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9929.JPEG
#   inflating: tiny-imagenet-200/val/images/val_993.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9930.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9931.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9932.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9933.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9934.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9935.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9936.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9937.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9938.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9939.JPEG
#   inflating: tiny-imagenet-200/val/images/val_994.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9940.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9941.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9942.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9943.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9944.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9945.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9946.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9947.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9948.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9949.JPEG
#   inflating: tiny-imagenet-200/val/images/val_995.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9950.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9951.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9952.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9953.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9954.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9955.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9956.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9957.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9958.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9959.JPEG
#   inflating: tiny-imagenet-200/val/images/val_996.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9960.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9961.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9962.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9963.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9964.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9965.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9966.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9967.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9968.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9969.JPEG
#   inflating: tiny-imagenet-200/val/images/val_997.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9970.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9971.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9972.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9973.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9974.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9975.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9976.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9977.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9978.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9979.JPEG
#   inflating: tiny-imagenet-200/val/images/val_998.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9980.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9981.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9982.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9983.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9984.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9985.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9986.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9987.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9988.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9989.JPEG
#   inflating: tiny-imagenet-200/val/images/val_999.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9990.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9991.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9992.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9993.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9994.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9995.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9996.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9997.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9998.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9999.JPEG
#   inflating: tiny-imagenet-200/val/val_annotations.txt
#   inflating: tiny-imagenet-200/wnids.txt
#   inflating: tiny-imagenet-200/words.txt

# %%
dataset = torchvision.datasets.ImageFolder('/content/tiny-imagenet-200', transform=transform)

# %%
#split the data
train,val,test = torch.utils.data.random_split(dataset, [80000, 10000, 10000])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-d38c0fc4234b> in <module>()
#       1 #split the data
# ----> 2 train,val,test = torch.utils.data.random_split(dataset, [80000, 10000, 10000])
#
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataset.py in random_split(dataset, lengths, generator)
#     330     # Cannot verify that dataset is Sized
#     331     if sum(lengths) != len(dataset):  # type: ignore[arg-type]
# --> 332         raise ValueError("Sum of input lengths does not equal the length of the input dataset!")
#     333
#     334     indices = randperm(sum(lengths), generator=generator).tolist()
#
# ValueError: Sum of input lengths does not equal the length of the input dataset!

# %%
train=('/content/tiny-imagenet-200/train')
test=('/content/tiny-imagenet-200/test')
val=('/content/tiny-imagenet-200/val')
batch_size = 32
train_loader = DataLoader(train, batch_size=batch_size, shuffle=True, num_workers=4)
val_loader = DataLoader(val, batch_size=batch_size, shuffle=False, num_workers=4)
test_loader = DataLoader(test, batch_size=batch_size, shuffle=False, num_workers=4)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %%
from torchvision.utils import make_grid

for images, _ in train_loader:
    plt.figure(figsize=(16,8))
    plt.axis('off')
    plt.imshow(make_grid(images, nrow=8).permute((1, 2, 0)))
    break
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-53-56cd4130093f> in <module>()
#       1 from torchvision.utils import make_grid
#       2
# ----> 3 for images, _ in train_loader:
#       4     plt.figure(figsize=(16,8))
#       5     plt.axis('off')
#
# ValueError: too many values to unpack (expected 2)

# %%
batch_size = 32
train_loader = DataLoader(train, batch_size=batch_size, shuffle=True, num_workers=4)
val_loader = DataLoader(val, batch_size=batch_size, shuffle=False, num_workers=4)
test_loader = DataLoader(test, batch_size=batch_size, shuffle=False, num_workers=4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-7cefc939f7ad> in <module>()
#       1 batch_size = 32
# ----> 2 train_loader = DataLoader(train, batch_size=batch_size, shuffle=True, num_workers=4)
#       3 val_loader = DataLoader(val, batch_size=batch_size, shuffle=False, num_workers=4)
#       4 test_loader = DataLoader(test, batch_size=batch_size, shuffle=False, num_workers=4)
#
# NameError: name 'train' is not defined

# %%
# Out:
#   File "<ipython-input-54-175288e43ed1>", line 1
#     <iframe src="https://www.kaggle.com/embed/ivankunyankin/googlenet-inception-from-scratch-using-pytorch?cellIds=18&kernelSessionId=54791668" height="300" style="margin: 0 auto; width: 100%; max-width: 950px;" frameborder="0" scrolling="auto" title="GoogLeNet (Inception) from scratch using Pytorch💪"></iframe>
#     ^
# SyntaxError: invalid syntax

# %%
class Inception(nn.Module):
    
    def __init__(self, in_channels=3, use_auxiliary=True, num_classes=1000):
        super(Inception, self).__init__()
        
        self.conv1 = ConvBlock(in_channels, 64, kernel_size=7, stride=2, padding=3)
        self.conv2 = ConvBlock(64, 192, kernel_size=3, stride=1, padding=1)
        
        self.maxpool = nn.MaxPool2d(kernel_size=3, stride=2, padding=1)
        self.avgpool = nn.AvgPool2d(kernel_size=7, stride=1)
        
        self.dropout = nn.Dropout(0.4)
        self.linear = nn.Linear(1024, num_classes)
        
        self.use_auxiliary = use_auxiliary
        if use_auxiliary:
            self.auxiliary4a = Auxiliary(512, num_classes)
            self.auxiliary4d = Auxiliary(528, num_classes)
        
        self.inception3a = InceptionBlock(192, 64, 96, 128, 16, 32, 32)
        self.inception3b = InceptionBlock(256, 128, 128, 192, 32, 96, 64)
        self.inception4a = InceptionBlock(480, 192, 96, 208, 16, 48, 64)
        self.inception4b = InceptionBlock(512, 160, 112, 224, 24, 64, 64)
        self.inception4c = InceptionBlock(512, 128, 128, 256, 24, 64, 64)
        self.inception4d = InceptionBlock(512, 112, 144, 288, 32, 64, 64)
        self.inception4e = InceptionBlock(528, 256, 160, 320, 32, 128, 128)
        self.inception5a = InceptionBlock(832, 256, 160, 320, 32, 128, 128)
        self.inception5b = InceptionBlock(832, 384, 192, 384, 48, 128, 128)

    def forward(self, x):
        y = None
        z = None
        
        x = self.conv1(x)
        x = self.maxpool(x)
        x = self.conv2(x)
        x = self.maxpool(x)
        
        x = self.inception3a(x)
        x = self.inception3b(x)
        x = self.maxpool(x)
        
        x = self.inception4a(x)
        if self.training and self.use_auxiliary:
            y = self.auxiliary4a(x)
        
        x = self.inception4b(x)
        x = self.inception4c(x)
        x = self.inception4d(x)
        if self.training and self.use_auxiliary:
            z = self.auxiliary4d(x)
        
        x = self.inception4e(x)
        x = self.maxpool(x)
        
        x = self.inception5a(x)
        x = self.inception5b(x)
        x = self.avgpool(x)
        x = x.reshape(x.shape[0], -1)
        x = self.dropout(x)
        
        x = self.linear(x)
        
        return x, y, z

# %%
class ConvBlock(nn.Module):
    
    def __init__(self, in_channels, out_channels, kernel_size, **kwargs):
        super(ConvBlock, self).__init__()
        self.conv = nn.Conv2d(in_channels, out_channels, kernel_size, **kwargs)
        self.bn = nn.BatchNorm2d(out_channels)
        self.relu = nn.ReLU()
        
    def forward(self, x):
        return self.relu(self.bn(self.conv(x)))

# %%
class InceptionBlock(nn.Module):
    
    def __init__(self, im_channels, num_1x1, num_3x3_red, num_3x3, num_5x5_red, num_5x5, num_pool_proj):
        super(InceptionBlock, self).__init__()
        
        self.one_by_one = ConvBlock(im_channels, num_1x1, kernel_size=1)
        
        self.tree_by_three_red = ConvBlock(im_channels, num_3x3_red, kernel_size=1)  
        self.tree_by_three = ConvBlock(num_3x3_red, num_3x3, kernel_size=3, padding=1)
        
        self.five_by_five_red = ConvBlock(im_channels, num_5x5_red, kernel_size=1)
        self.five_by_five = ConvBlock(num_5x5_red, num_5x5, kernel_size=5, padding=2)
        
        self.maxpool = nn.MaxPool2d(kernel_size=3, stride=1, padding=1)
        self.pool_proj = ConvBlock(im_channels, num_pool_proj, kernel_size=1)
         
    def forward(self, x):
        x1 = self.one_by_one(x)
        
        x2 = self.tree_by_three_red(x)
        x2 = self.tree_by_three(x2)
        
        x3 = self.five_by_five_red(x)
        x3 = self.five_by_five(x3)
        
        x4 = self.maxpool(x)
        x4 = self.pool_proj(x4)
        
        x = torch.cat([x1, x2, x3, x4], 1)
        return x

# %%
class Auxiliary(nn.Module):
    
    def __init__(self, in_channels, num_classes):
        super(Auxiliary, self).__init__()
        self.avgpool = nn.AvgPool2d(kernel_size=5, stride=3)
        self.conv1x1 = ConvBlock(in_channels, 128, kernel_size=1)
        
        self.fc1 = nn.Linear(2048, 1024)
        self.fc2 = nn.Linear(1024, num_classes)
        
        self.dropout = nn.Dropout(0.7)
        self.relu = nn.ReLU()

    def forward(self, x):
        x = self.avgpool(x)
        x = self.conv1x1(x)
        x = x.reshape(x.shape[0], -1)
        x = self.relu(self.fc1(x))
        x = self.dropout(x)
        x = self.fc2(x)
        return x

# %%
model = Inception()

# %%
#define the device to use
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cpu')

# %%
#move the model to the device
model.to(device)
next(model.parameters()).is_cuda
# Out:
# False

# %%
#define everything we need for training
epochs = 3 #50
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.0001, weight_decay=1e-4)
lr_scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, patience=5, verbose=True)

# %%
def train_model(model, dataloaders, criterion, optimizer, num_epochs=50, use_auxiliary=True):
    
    since = time.time()
    val_acc_history = []
    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)

        for phase in ['train', 'val']: # Each epoch has a training and validation phase
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0

            for inputs, labels in dataloaders[phase]: # Iterate over data
                
                inputs = inputs.to(device)

                labels = labels.to(device)

                optimizer.zero_grad() # Zero the parameter gradients

                with torch.set_grad_enabled(phase == 'train'): # Forward. Track history if only in train
                    
                    if phase == 'train': # Backward + optimize only if in training phase
                        if use_auxiliary:
                            outputs, aux1, aux2 = model(inputs)
                            loss = criterion(outputs, labels) + 0.3 * criterion(aux1, labels) + 0.3 * criterion(aux2, labels)
                        else:
                            outputs, _, _ = model(inputs)
                            loss = criterion(outputs, labels)
                            
                        _, preds = torch.max(outputs, 1)
                        loss.backward()
                        optimizer.step()
                    
                    if phase == 'val':
                        outputs, _, _ = model(inputs)
                        loss = criterion(outputs, labels)
                        _, preds = torch.max(outputs, 1)

                # Statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)

            epoch_loss = running_loss / len(dataloaders[phase].dataset)
            
            if phase == 'val': # Adjust learning rate based on val loss
                lr_scheduler.step(epoch_loss)
                
            epoch_acc = running_corrects.double() / len(dataloaders[phase].dataset)

            print('{} Loss: {:.4f} Acc: {:.4f}'.format(phase, epoch_loss, epoch_acc))

            # deep copy the model
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())
            if phase == 'val':
                val_acc_history.append(epoch_acc)

        print()

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(time_elapsed // 60, time_elapsed % 60))
    print('Best val Acc: {:4f}'.format(best_acc))

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model, val_acc_history

# %%
model, _ = train_model(model, {"train": train_loader, "val": val_loader}, criterion, optimizer, epochs)
# Out:
# Epoch 0/2
# ----------
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-65-5cf676768c52> in <module>()
# ----> 1 model, _ = train_model(model, {"train": train_loader, "val": val_loader}, criterion, optimizer, epochs)
#
# <ipython-input-63-d692120060dc> in train_model(model, dataloaders, criterion, optimizer, num_epochs, use_auxiliary)
#      19             running_corrects = 0
#      20
# ---> 21             for inputs, labels in dataloaders[phase]: # Iterate over data
#      22
#      23                 inputs = inputs.to(device)
#
# ValueError: too many values to unpack (expected 2)

# %% [markdown]
# # most recent

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
# import warnings
import warnings
# filter warnings
warnings.filterwarnings('ignore')

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
print(os.listdir("/content/tiny-imagenet-200"))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# ['words.txt', 'wnids.txt', 'val', 'train', 'test', 'tiny-imagenet-200']

# %%
training_folder_name = '/content/tiny-imagenet-200/train'

# All images are 128x128 pixels
img_size = (128,128)

# The folder contains a subfolder for each class of shape
classes = sorted(os.listdir(training_folder_name))
print(classes)
# Out:
# ['n01443537', 'n01629819', 'n01641577', 'n01644900', 'n01698640', 'n01742172', 'n01768244', 'n01770393', 'n01774384', 'n01774750', 'n01784675', 'n01855672', 'n01882714', 'n01910747', 'n01917289', 'n01944390', 'n01945685', 'n01950731', 'n01983481', 'n01984695', 'n02002724', 'n02056570', 'n02058221', 'n02074367', 'n02085620', 'n02094433', 'n02099601', 'n02099712', 'n02106662', 'n02113799', 'n02123045', 'n02123394', 'n02124075', 'n02125311', 'n02129165', 'n02132136', 'n02165456', 'n02190166', 'n02206856', 'n02226429', 'n02231487', 'n02233338', 'n02236044', 'n02268443', 'n02279972', 'n02281406', 'n02321529', 'n02364673', 'n02395406', 'n02403003', 'n02410509', 'n02415577', 'n02423022', 'n02437312', 'n02480495', 'n02481823', 'n02486410', 'n02504458', 'n02509815', 'n02666196', 'n02669723', 'n02699494', 'n02730930', 'n02769748', 'n02788148', 'n02791270', 'n02793495', 'n02795169', 'n02802426', 'n02808440', 'n02814533', 'n02814860', 'n02815834', 'n02823428', 'n02837789', 'n02841315', 'n02843684', 'n02883205', 'n02892201', 'n02906734', 'n02909870', 'n02917067', 'n02927161', 'n02948072', 'n02950826', 'n02963159', 'n02977058', 'n02988304', 'n02999410', 'n03014705', 'n03026506', 'n03042490', 'n03085013', 'n03089624', 'n03100240', 'n03126707', 'n03160309', 'n03179701', 'n03201208', 'n03250847', 'n03255030', 'n03355925', 'n03388043', 'n03393912', 'n03400231', 'n03404251', 'n03424325', 'n03444034', 'n03447447', 'n03544143', 'n03584254', 'n03599486', 'n03617480', 'n03637318', 'n03649909', 'n03662601', 'n03670208', 'n03706229', 'n03733131', 'n03763968', 'n03770439', 'n03796401', 'n03804744', 'n03814639', 'n03837869', 'n03838899', 'n03854065', 'n03891332', 'n03902125', 'n03930313', 'n03937543', 'n03970156', 'n03976657', 'n03977966', 'n03980874', 'n03983396', 'n03992509', 'n04008634', 'n04023962', 'n04067472', 'n04070727', 'n04074963', 'n04099969', 'n04118538', 'n04133789', 'n04146614', 'n04149813', 'n04179913', 'n04251144', 'n04254777', 'n04259630', 'n04265275', 'n04275548', 'n04285008', 'n04311004', 'n04328186', 'n04356056', 'n04366367', 'n04371430', 'n04376876', 'n04398044', 'n04399382', 'n04417672', 'n04456115', 'n04465501', 'n04486054', 'n04487081', 'n04501370', 'n04507155', 'n04532106', 'n04532670', 'n04540053', 'n04560804', 'n04562935', 'n04596742', 'n04597913', 'n06596364', 'n07579787', 'n07583066', 'n07614500', 'n07615774', 'n07695742', 'n07711569', 'n07715103', 'n07720875', 'n07734744', 'n07747607', 'n07749582', 'n07753592', 'n07768694', 'n07871810', 'n07873807', 'n07875152', 'n07920052', 'n09193705', 'n09246464', 'n09256479', 'n09332890', 'n09428293', 'n12267677']

# %%
# Import PyTorch libraries
import torch
import torchvision
import torchvision.transforms as transforms
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

print("Libraries imported - ready to use PyTorch", torch.__version__)
# Out:
# Libraries imported - ready to use PyTorch 1.9.0+cu102

# %%
from PIL import Image

# function to resize image
def resize_image(src_image, size=(128,128), bg_color="white"): 
    from PIL import Image, ImageOps 
    
    # resize the image so the longest dimension matches our target size
    src_image.thumbnail(size, Image.ANTIALIAS)
    
    # Create a new square background image
    new_image = Image.new("RGB", size, bg_color)
    
    # Paste the resized image into the center of the square background
    new_image.paste(src_image, (int((size[0] - src_image.size[0]) / 2), int((size[1] - src_image.size[1]) / 2)))
  
    # return the resized image
    return new_image

# %%
def load_dataset(data_path):
    import torch
    import torchvision
    import torchvision.transforms as transforms
    # Load all the images
    transformation = transforms.Compose([
        # Randomly augment the image data
            # Random horizontal flip
        transforms.RandomHorizontalFlip(0.5),
            # Random vertical flip
        transforms.RandomVerticalFlip(0.3),
        # transform to tensors
        transforms.ToTensor(),
        # Normalize the pixel values (in R, G, and B channels)
        transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])
    ])

    # Load all of the images, transforming them
    full_dataset = torchvision.datasets.ImageFolder(
        root=data_path,
        transform=transformation
    )
    
    
    # Split into training (70% and testing (30%) datasets)
    train_size = int(0.7 * len(full_dataset))
    test_size = len(full_dataset) - train_size
    
    # use torch.utils.data.random_split for training/test split
    train_dataset, test_dataset = torch.utils.data.random_split(full_dataset, [train_size, test_size])
    
    # define a loader for the training data we can iterate through in 50-image batches
    train_loader = torch.utils.data.DataLoader(
        train_dataset,
        batch_size=50,
        num_workers=0,
        shuffle=False
    )
    
    # define a loader for the testing data we can iterate through in 50-image batches
    test_loader = torch.utils.data.DataLoader(
        test_dataset,
        batch_size=50,
        num_workers=0,
        shuffle=False
    )
        
    return train_loader, test_loader

# %%
train_folder = '/content/tiny-imagenet-200/train'

# Get the iterative dataloaders for test and training data
train_loader, test_loader = load_dataset(train_folder)
batch_size = train_loader.batch_size
print("Data loaders ready to read", train_folder)
# Out:
# Data loaders ready to read /content/tiny-imagenet-200/train

# %%
# Create a neural net class
class Net(nn.Module):
    
    
    # Defining the Constructor
    def __init__(self, num_classes=3):
        super(Net, self).__init__()
        
        # In the init function, we define each layer we will use in our model
        
        # Our images are RGB, so we have input channels = 3. 
        # We will apply 12 filters in the first convolutional layer
        self.conv1 = nn.Conv2d(in_channels=3, out_channels=12, kernel_size=3, stride=1, padding=1)
        
        # A second convolutional layer takes 12 input channels, and generates 24 outputs
        self.conv2 = nn.Conv2d(in_channels=12, out_channels=24, kernel_size=3, stride=1, padding=1)
        
        # We in the end apply max pooling with a kernel size of 2
        self.pool = nn.MaxPool2d(kernel_size=2)
        
        # A drop layer deletes 20% of the features to help prevent overfitting
        self.drop = nn.Dropout2d(p=0.2)
        
        # Our 128x128 image tensors will be pooled twice with a kernel size of 2. 128/2/2 is 32.
        # This means that our feature tensors are now 32 x 32, and we've generated 24 of them
        
        # We need to flatten these in order to feed them to a fully-connected layer
        self.fc = nn.Linear(in_features=32 * 32 * 24, out_features=num_classes)

    def forward(self, x):
        # In the forward function, pass the data through the layers we defined in the init function
        
        # Use a ReLU activation function after layer 1 (convolution 1 and pool)
        x = F.relu(self.pool(self.conv1(x))) 
        
        # Use a ReLU activation function after layer 2
        x = F.relu(self.pool(self.conv2(x)))  
        
        # Select some features to drop to prevent overfitting (only drop during training)
        x = F.dropout(self.drop(x), training=self.training)
        
        # Flatten
        x = x.view(-1, 32 * 32 * 24)
        # Feed to fully-connected layer to predict class
        x = self.fc(x)
        # Return class probabilities via a log_softmax function 
        return torch.log_softmax(x, dim=1)
    
device = "cpu"
if (torch.cuda.is_available()):
    # if GPU available, use cuda (on a cpu, training will take a considerable length of time!)
    device = "cuda"

# Create an instance of the model class and allocate it to the device
model = Net(num_classes=len(classes)).to(device)

print(model)
# Out:
# Net(
#   (conv1): Conv2d(3, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv2): Conv2d(12, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (drop): Dropout2d(p=0.2, inplace=False)
#   (fc): Linear(in_features=24576, out_features=200, bias=True)
# )

# %%
def train(model, device, train_loader, optimizer, epoch):
    # Set the model to training mode
    model.train()
    train_loss = 0
    print("Epoch:", epoch)
    # Process the images in batches
    for batch_idx, (data, target) in enumerate(train_loader):
        # Use the CPU or GPU as appropriate
        # Recall that GPU is optimized for the operations we are dealing with
        data, target = data.to(device), target.to(device)
        
        # Reset the optimizer
        optimizer.zero_grad()
        
        # Push the data forward through the model layers
        output = model(data)
        
        # Get the loss
        loss = loss_criteria(output, target)

        # Keep a running total
        train_loss += loss.item()
        
        # Backpropagate
        loss.backward()
        optimizer.step()
        
        # Print metrics so we see some progress
        print('\tTraining batch {} Loss: {:.6f}'.format(batch_idx + 1, loss.item()))
            
    # return average loss for the epoch
    avg_loss = train_loss / (batch_idx+1)
    print('Training set: Average loss: {:.6f}'.format(avg_loss))
    return avg_loss

# %%
def test(model, device, test_loader):
    # Switch the model to evaluation mode (so we don't backpropagate or drop)
    model.eval()
    test_loss = 0
    correct = 0
    with torch.no_grad():
        batch_count = 0
        for data, target in test_loader:
            batch_count += 1
            data, target = data.to(device), target.to(device)
            
            # Get the predicted classes for this batch
            output = model(data)
            
            # Calculate the loss for this batch
            test_loss += loss_criteria(output, target).item()
            
            # Calculate the accuracy for this batch
            _, predicted = torch.max(output.data, 1)
            correct += torch.sum(target==predicted).item()

    # Calculate the average loss and total accuracy for this epoch
    avg_loss = test_loss / batch_count
    print('Validation set: Average loss: {:.6f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
        avg_loss, correct, len(test_loader.dataset),
        100. * correct / len(test_loader.dataset)))
    
    # return average loss for the epoch
    return avg_loss

# %%
# Use an "Adam" optimizer to adjust weights
optimizer = optim.Adam(model.parameters(), lr=0.01)

# Specify the loss criteria
loss_criteria = nn.CrossEntropyLoss()

# Track metrics in these arrays
epoch_nums = []
training_loss = []
validation_loss = []

# Train over 10 epochs (We restrict to 10 for time issues)
epochs = 100
print('Training on', device)
for epoch in range(1, epochs + 1):
        train_loss = train(model, device, train_loader, optimizer, epoch)
        test_loss = test(model, device, test_loader)
        epoch_nums.append(epoch)
        training_loss.append(train_loss)
        validation_loss.append(test_loss)
# Out:
# Training on cpu
# Epoch: 1
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-79-a5ff50ab3c9a> in <module>()
#      14 print('Training on', device)
#      15 for epoch in range(1, epochs + 1):
# ---> 16         train_loss = train(model, device, train_loader, optimizer, epoch)
#      17         test_loss = test(model, device, test_loader)
#      18         epoch_nums.append(epoch)
#
# <ipython-input-74-f40348c75629> in train(model, device, train_loader, optimizer, epoch)
#      14
#      15         # Push the data forward through the model layers
# ---> 16         output = model(data)
#      17
#      18         # Get the loss
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1049         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051             return forward_call(*input, **kwargs)
#    1052         # Do not call functions when jit is used
#    1053         full_backward_hooks, non_full_backward_hooks = [], []
#
# <ipython-input-73-c8f0b5a24938> in forward(self, x)
#      41
#      42         # Flatten
# ---> 43         x = x.view(-1, 32 * 32 * 24)
#      44         # Feed to fully-connected layer to predict class
#      45         x = self.fc(x)
#
# RuntimeError: shape '[-1, 24576]' is invalid for input of size 307200

# %%
plt.figure(figsize=(15,15))
plt.plot(epoch_nums, training_loss)
plt.plot(epoch_nums, validation_loss)
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['training', 'validation'], loc='upper right')
plt.show()

# %%
# Defining Labels and Predictions
truelabels = []
predictions = []
model.eval()
print("Getting predictions from test set...")
for data, target in test_loader:
    for label in target.data.numpy():
        truelabels.append(label)
    for prediction in model(data).data.numpy().argmax(1):
        predictions.append(prediction) 

# Plot the confusion matrix
cm = confusion_matrix(truelabels, predictions)
tick_marks = np.arange(len(classes))

df_cm = pd.DataFrame(cm, index = classes, columns = classes)
plt.figure(figsize = (7,7))
sns.heatmap(df_cm, annot=True, cmap=plt.cm.Blues, fmt='g')
plt.xlabel("Predicted Shape", fontsize = 20)
plt.ylabel("True Shape", fontsize = 20)
plt.show()
# Out:
# Getting predictions from test set...
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-81-11daf0596992> in <module>()
#       7     for label in target.data.numpy():
#       8         truelabels.append(label)
# ----> 9     for prediction in model(data).data.numpy().argmax(1):
#      10         predictions.append(prediction)
#      11
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1049         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051             return forward_call(*input, **kwargs)
#    1052         # Do not call functions when jit is used
#    1053         full_backward_hooks, non_full_backward_hooks = [], []
#
# <ipython-input-73-c8f0b5a24938> in forward(self, x)
#      41
#      42         # Flatten
# ---> 43         x = x.view(-1, 32 * 32 * 24)
#      44         # Feed to fully-connected layer to predict class
#      45         x = self.fc(x)
#
# RuntimeError: shape '[-1, 24576]' is invalid for input of size 307200

# %% [markdown]
# # New code

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

print(os.listdir("/content/drive/MyDrive/tiny-imagenet-200"))
# Out:
# ['words.txt', 'wnids.txt', 'train', 'test', 'val', 'tiny-imagenet-200']

# %%
import torch
from torchvision.datasets import ImageFolder
from torchvision.transforms import ToTensor, Compose, Normalize, RandomHorizontalFlip, RandomErasing, RandomPerspective, RandomRotation

composed_transformers = Compose([
    ToTensor(),
    # Аугментация
    #RandomPerspective(distortion_scale=0.5, p=0.5, interpolation=3, fill=0),
    #RandomRotation(15, resample=False, expand=False, center=None, fill=None)
    #RandomHorizontalFlip(p=0.5),
    #RandomErasing(p=0.5, scale=(0.02, 0.33), ratio=(0.3, 3.3), value=0, inplace=False)
    #Normalize((0.5, 0.5, 0.5), (0.225, 0.225, 0.225)),    
])

dataset = ImageFolder("/content/drive/MyDrive/tiny-imagenet-200", composed_transformers)

# делим выборку на train, validation (cv_data) и test (val_data)
torch.manual_seed(42)
train_data, cv_data, val_data = torch.utils.data.random_split(dataset, [80000, 10000, 10000])
#val_data = ImageFolder('../input/tiny-imagenet/tiny-imagenet-200/test', composed_transformers)
#test_data = ImageFolder('../input/tiny-imagenet/tiny-imagenet-200/val', composed_transformers)
len(train_data), len(cv_data), len(val_data)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-79-b03a2995aa4a> in <module>()
#      13 ])
#      14
# ---> 15 dataset = ImageFolder("/content/drive/MyDrive/tiny-imagenet-200", composed_transformers)
#      16
#      17 # делим выборку на train, validation (cv_data) и test (val_data)
#
# /usr/local/lib/python3.7/dist-packages/torchvision/datasets/folder.py in __init__(self, root, transform, target_transform, loader, is_valid_file)
#     311                                           transform=transform,
#     312                                           target_transform=target_transform,
# --> 313                                           is_valid_file=is_valid_file)
#     314         self.imgs = self.samples
#
# /usr/local/lib/python3.7/dist-packages/torchvision/datasets/folder.py in __init__(self, root, loader, extensions, transform, target_transform, is_valid_file)
#     144                                             target_transform=target_transform)
#     145         classes, class_to_idx = self.find_classes(self.root)
# --> 146         samples = self.make_dataset(self.root, class_to_idx, extensions, is_valid_file)
#     147
#     148         self.loader = loader
#
# /usr/local/lib/python3.7/dist-packages/torchvision/datasets/folder.py in make_dataset(directory, class_to_idx, extensions, is_valid_file)
#     190                 "The class_to_idx parameter cannot be None."
#     191             )
# --> 192         return make_dataset(directory, class_to_idx, extensions=extensions, is_valid_file=is_valid_file)
#     193
#     194     def find_classes(self, directory: str) -> Tuple[List[str], Dict[str, int]]:
#
# /usr/local/lib/python3.7/dist-packages/torchvision/datasets/folder.py in make_dataset(directory, class_to_idx, extensions, is_valid_file)
#     100         if extensions is not None:
#     101             msg += f"Supported extensions are: {', '.join(extensions)}"
# --> 102         raise FileNotFoundError(msg)
#     103
#     104     return instances
#
# FileNotFoundError: Found no valid file for the classes tiny-imagenet-200, train, val. Supported extensions are: .jpg, .jpeg, .png, .ppm, .bmp, .pgm, .tif, .tiff, .webp

# %%
# загрузчики выборок

# размер батча
batch_size = 256

# train выборка
train_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size, shuffle=True, num_workers=4)

# validation выборка для проверки train
cv_loader = torch.utils.data.DataLoader(cv_data, batch_size=batch_size, shuffle=False, num_workers=4)

# тестовая выборка для проверки финального accuracy
val_loader = torch.utils.data.DataLoader(val_data, batch_size=batch_size, shuffle=False, num_workers=4)

# %%
# выведем батч с картинками (16 шт.) для выборки train
from torchvision.utils import make_grid

for images, _ in train_loader:
    print('images.shape:', images.shape)
    plt.figure(figsize=(16,8))
    plt.axis('off')
    plt.imshow(make_grid(images, nrow=8).permute((1, 2, 0)))
    break
# Out:
# images.shape: torch.Size([256, 3, 64, 64])

# %%
# выведем батч с картинками (16 шт.) для выборки валидационной выборки (cv_data)
from torchvision.utils import make_grid

for images, _ in cv_loader:
    print('images.shape:', images.shape)
    plt.figure(figsize=(16,8))
    plt.axis('off')
    plt.imshow(make_grid(images, nrow=8).permute((1, 2, 0)))
    break
# Out:
# images.shape: torch.Size([256, 3, 64, 64])

# %%
# выведем батч с картинками (16 шт.) для выборки Тестовой выборки (val_data)
from torchvision.utils import make_grid

for images, _ in val_loader:
    print('images.shape:', images.shape)
    plt.figure(figsize=(16,8))
    plt.axis('off')
    plt.imshow(make_grid(images, nrow=8).permute((1, 2, 0)))
    break
# Out:
# images.shape: torch.Size([256, 3, 64, 64])

# %%
# доступность GPU
# если мы на GPU, то будет выведено соответствующее уведомление, иначе - отобразится CPU
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
if(not torch.cuda.is_available()):
    print('Текущий device - CPU. Необходимо включить GPU (видеокарта не подключена)')
else:
    print(device)
# Out:
# cuda:0

# %%
import torch.nn as nn
import torch.nn.functional as F

class Flatten(nn.Module):
    def forward(self, input):
        return input.view(input.size(0), -1)

# %%
class CNNClassifier(nn.Module):
    def __init__(self):
        super().__init__()
        #self.device = device
        #self.conv0 = nn.Conv2d(3, 32, kernel_size=3)
        #self.maxpool0 = nn.MaxPool2d((2,2))
        self.conv1 = nn.Conv2d(3, 64, kernel_size=3)
        #self.bnorm1 = nn.BatchNorm2d(64)
        #self.drop1 = nn.Dropout(p=0.3)
        self.maxpool1 = nn.MaxPool2d((4,4))
        self.conv2 = nn.Conv2d(64, 128, kernel_size=3)
        self.maxpool2 = nn.MaxPool2d((2,2))
        #self.conv3 = nn.Conv2d(64, 3, kernel_size=3)
        #self.bnorm2 = nn.BatchNorm2d(3)
        #self.drop2 = nn.Dropout(p=0.5)
        self.flatten = Flatten()
        # kernel = 3,  conv1-64, maxpool 4x4
        self.fc1 = nn.Linear(4608, 1024)
        self.fc2 = nn.Linear(1024, 200)
        
        #self.fc1 = nn.Linear(512, 256)
        #self.fc2 = nn.Linear(256, 200)
        # kernel = 3,  conv1-64, maxpool 4x4
        #self.fc1 = nn.Linear(14400, 4096)
        #self.fc2 = nn.Linear(4096, 200)
        # kernel = 3, conv-16 x 3 - maxpool 4x4
        #self.fc = n.Linear(3600, 200)
        # kernel = 3, conv-16 x 3 - maxpool 2x2
        #self.fc = nn.Linear(15376, 200)
        # maxpooling, kernel = 3, conv-64, maxpool 4x4
        #self.fc = nn.Linear(14400, 200)
        # без maxpooling, kernel = 3, conv-64 x 3
        #self.fc = nn.Linear(10092, 200)
        # без maxpooling, kernel = 3
        # self.fc = nn.Linear(10800, 200)
        # для maxpooling, kernel = 3
        #self.fc = nn.Linear(972, 200)
        # без maxpooling, kernel = 2
        #self.fc = nn.Linear(11532, 200)
        
    
    def forward(self, x):
        # forward pass сети
        # умножение на матрицу весов 1 слоя и применение функции активации
        #x = F.relu(self.conv0(x))
        #x = self.maxpool0(x)
        x = F.relu(self.conv1(x))
        #x = self.bnorm1(x)
        #x = self.drop1(x)
        x = self.maxpool1(x)
        x = F.relu(self.conv2(x))
        x = self.maxpool2(x)
        #x = F.relu(self.conv3(x))
        #x = self.bnorm2(x)
        #x = self.drop2(x)
        x = self.flatten(x)
        # умножение на матрицу весов 2 слоя и применение функции активации
        #print(x.shape)
        #x = F.softmax(self.fc(x))
        #x = F.relu(self.fc(x))
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return x

cnn_model = CNNClassifier()

# переносим сеть на GPU
cnn_model.to(device)
# Out:
# CNNClassifier(
#   (conv1): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1))
#   (maxpool1): MaxPool2d(kernel_size=(4, 4), stride=(4, 4), padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1))
#   (maxpool2): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#   (flatten): Flatten()
#   (fc1): Linear(in_features=4608, out_features=1024, bias=True)
#   (fc2): Linear(in_features=1024, out_features=200, bias=True)
# )

# %%
# Loss-функция и оптимизатор

from torch import optim
from torch.optim.lr_scheduler import CosineAnnealingLR

LEARNING_RATE = 7e-4

criterion = nn.CrossEntropyLoss().to(device)
optimizer = optim.Adam(
    filter(lambda p: p.requires_grad, cnn_model.parameters()),
    lr=LEARNING_RATE,
)

scheduler = CosineAnnealingLR(optimizer, 1)

# %%
# определяем функцию и необходимые шаги для тренировки

def train_epoch(model, optimizer, train_loader):
    model.train()
    total_loss, total = 0, 0
    for i, (inputs, target) in enumerate(train_loader):
        # переносим на GPU
        inputs = inputs.to(device)
        target = target.to(device)
        
        # Reset gradient
        optimizer.zero_grad()
        
        # Forward pass
        output = model(inputs)
        
        # Compute loss
        loss = criterion(output, target)
        
        # Perform gradient descent, backwards pass
        loss.backward()

        # Take a step in the right direction
        optimizer.step()
        scheduler.step()

        # Record metrics
        total_loss += loss.item()
        total += len(target)

    return total_loss / total

# функция и шаги для валидации
def validate_epoch(model, cv_loader):
    model.eval()
    total_loss, total = 0, 0
    with torch.no_grad():
        for inputs, target in cv_loader:           
            # переносим на GPU
            inputs = inputs.to(device)
            target = target.to(device)
            
            # Forward pass
            output = model(inputs)

            # Calculate how wrong the model is
            loss = criterion(output, target)

            # Record metrics
            total_loss += loss.item()
            total += len(target)

    return total_loss / total

# %%
# тренируем
from tqdm import tqdm

max_epochs = 145
n_epochs = 0
train_losses = []
valid_losses = []

for epoch_num in range(max_epochs):

    train_loss = train_epoch(cnn_model, optimizer, train_loader)
    valid_loss = validate_epoch(cnn_model, val_loader)
    
    tqdm.write(
        f'эпоха #{n_epochs + 1:3d}\ttrain_loss: {train_loss:.2e}\tvalid_loss: {valid_loss:.2e}\n',
    )
    
    # Early stopping (ранняя остановка) если текущий valid_loss (значение функции ошибки для валидаионной выборки) больше чем 10 последних valid losses
    if len(valid_losses) > 4 and all(valid_loss >= loss for loss in valid_losses[-5:]):
        print('Stopping early')
        break
    
    train_losses.append(train_loss)
    valid_losses.append(valid_loss)
    
    n_epochs += 1

print('Тренировка окончена')
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# эпоха #  1	train_loss: 1.87e-02	valid_loss: 1.77e-02
#
# эпоха #  2	train_loss: 1.64e-02	valid_loss: 1.63e-02
#
# эпоха #  3	train_loss: 1.52e-02	valid_loss: 1.55e-02
#
# эпоха #  4	train_loss: 1.44e-02	valid_loss: 1.50e-02
#
# эпоха #  5	train_loss: 1.36e-02	valid_loss: 1.49e-02
#
# эпоха #  6	train_loss: 1.29e-02	valid_loss: 1.46e-02
#
# эпоха #  7	train_loss: 1.23e-02	valid_loss: 1.43e-02
#
# эпоха #  8	train_loss: 1.17e-02	valid_loss: 1.41e-02
#
# эпоха #  9	train_loss: 1.12e-02	valid_loss: 1.41e-02
#
# эпоха # 10	train_loss: 1.07e-02	valid_loss: 1.42e-02
#
# эпоха # 11	train_loss: 1.01e-02	valid_loss: 1.43e-02
#
# эпоха # 12	train_loss: 9.51e-03	valid_loss: 1.44e-02
#
# Stopping early
# Тренировка окончена

# %%
# строим график loss-функции после тренировки
epoch_ticks = range(1, n_epochs + 1)
plt.plot(epoch_ticks, train_losses)
plt.plot(epoch_ticks, valid_losses)
plt.legend(['Train Loss', 'Valid Loss'])
#plt.legend(['Train Loss'])
plt.title('Losses') 
plt.xlabel('Epoch #')
plt.ylabel('Loss')
plt.xticks(epoch_ticks)
plt.show()

# %%
## Эффективность CNN-модели
from sklearn.metrics import accuracy_score

cnn_model.eval()
test_accuracy, n_examples = 0, 0
y_true, y_pred = [], []

with torch.no_grad():
    for inputs, target in val_loader:
       
        inputs = inputs.to(device)
        target = target.to(device)
        
        probs = cnn_model(inputs)
        
        probs = probs.detach().cpu().numpy()
        predictions = np.argmax(probs, axis=1)
        target = target.cpu().numpy()
        
        y_true.extend(predictions)
        y_pred.extend(target)
        
test_accuracy = accuracy_score(y_true, y_pred)

print("Final results:")
print("  test accuracy:\t\t{:.2f} %".format(
    test_accuracy * 100))

if test_accuracy * 100 > 40:
    print("Achievement unlocked: 110lvl Warlock!")
elif test_accuracy * 100 > 35:
    print("Achievement unlocked: 80lvl Warlock!")
elif test_accuracy * 100 > 30:
    print("Achievement unlocked: 70lvl Warlock!")
elif test_accuracy * 100 > 25:
    print("Achievement unlocked: 60lvl Warlock!")
else:
    print("We need more magic! Follow instructons below")
# Out:
# Final results:
#   test accuracy:		24.57 %
# We need more magic! Follow instructons below

# %% [markdown]
# # Tiny image new 51%accu

# %%
import time
import scipy.ndimage as nd
import numpy as np

path = '/content/drive/MyDrive/tiny-imagenet-200'

def get_id_dictionary():
    id_dict = {}
    for i, line in enumerate(open( path + 'wnids.txt','r')):
        id_dict[line.replace('\n', '')] = i
    return id_dict
  
def get_class_to_id_dict():
    id_dict = get_id_dictionary()
    all_classes = {}
    result = {}
    for i, line in enumerate(open( path + 'words.txt', 'r')):
        n_id, word = line.split('\t')[:2]
        all_classes[n_id] = word
    for key, value in id_dict.items():
        result[value] = (key, all_classes[key])      
    return result

def get_data(id_dict):
    print('starting loading data')
    train_data, test_data = [], []
    train_labels, test_labels = [], []
    t = time.time()
    for key, value in id_dict.items():
        train_data += [nd.imread( path + 'train/{}/images/{}_{}.JPEG'.format(key, key, str(i)), mode='RGB') for i in range(500)]
        train_labels_ = np.array([[0]*200]*500)
        train_labels_[:, value] = 1
        train_labels += train_labels_.tolist()

    for line in open( path + 'val/val_annotations.txt'):
        img_name, class_id = line.split('\t')[:2]
        test_data.append(nd.imread( path + 'val/images/{}'.format(img_name) ,mode='RGB'))
        test_labels_ = np.array([[0]*200])
        test_labels_[0, id_dict[class_id]] = 1
        test_labels += test_labels_.tolist()

    print('finished loading data, in {} seconds'.format(time.time() - t))
    return np.array(train_data), np.array(train_labels), np.array(test_data), np.array(test_labels)
  
train_data, train_labels, test_data, test_labels = get_data(get_id_dictionary())

print( "train data shape: ",  train_data.shape )
print( "train label shape: ", train_labels.shape )
print( "test data shape: ",   test_data.shape )
print( "test_labels.shape: ", test_labels.shape )
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-81-ee58ef369cdc> in <module>()
#      43     return np.array(train_data), np.array(train_labels), np.array(test_data), np.array(test_labels)
#      44
# ---> 45 train_data, train_labels, test_data, test_labels = get_data(get_id_dictionary())
#      46
#      47 print( "train data shape: ",  train_data.shape )
#
# <ipython-input-81-ee58ef369cdc> in get_id_dictionary()
#       7 def get_id_dictionary():
#       8     id_dict = {}
# ----> 9     for i, line in enumerate(open( path + 'wnids.txt','r')):
#      10         id_dict[line.replace('\n', '')] = i
#      11     return id_dict
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/tiny-imagenet-200wnids.txt'

# %%
import tensorflow
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, BatchNormalization
from tensorflow.keras.regularizers import l1,l1_l2,l2
from tensorflow.keras.layers import Conv2D, MaxPooling2D,AveragePooling2D
from sklearn.model_selection import train_test_split
from tensorflow.keras.initializers import he_uniform,he_normal
from sklearn.utils import class_weight
from shutil import copy2

import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import os
from collections import Counter
import numpy as np
from tensorflow.keras.optimizers import RMSprop, SGD, Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from sklearn.utils.multiclass import unique_labels

# from vis.utils import utils
from tensorflow.keras import activations 
from tensorflow.keras.datasets import cifar10
from sklearn.metrics import classification_report,accuracy_score,confusion_matrix

# %% [markdown]
# # part 2 15 scene data

# %%
import tensorflow
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, BatchNormalization
from tensorflow.keras.regularizers import l1,l1_l2,l2
from tensorflow.keras.layers import Conv2D, MaxPooling2D,AveragePooling2D
from sklearn.model_selection import train_test_split
from tensorflow.keras.initializers import he_uniform,he_normal
from sklearn.utils import class_weight
from shutil import copy2

import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import os
from collections import Counter
import numpy as np
from tensorflow.keras.optimizers import RMSprop, SGD, Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from sklearn.utils.multiclass import unique_labels

# from vis.utils import utils
from tensorflow.keras import activations 
from tensorflow.keras.datasets import cifar10
from sklearn.metrics import classification_report,accuracy_score,confusion_matrix

# %%
num_classes = 15
img_rows, img_cols = 64,64
batch_size =32
# rescale=1./255
# home/kashraf/fall2021_cours
train_data_dir ="/content/drive/MyDrive/tiny-imagenet-200/train"
validation_data_dir = "/content/drive/MyDrive/tiny-imagenet-200/val"

# Let's use some data augmentaiton 
train_datagen = ImageDataGenerator(
      
      horizontal_flip=True,
      vertical_flip=True,
      )
validation_datagen = ImageDataGenerator()
 
train_generator = train_datagen.flow_from_directory(
    train_data_dir,
    target_size=(img_rows, img_cols),
    color_mode="grayscale",
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=True)

validation_generator = validation_datagen.flow_from_directory(
    validation_data_dir,
    target_size=(img_rows, img_cols),
    color_mode="grayscale",
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False)
# Out:
# Found 0 images belonging to 200 classes.
# Found 0 images belonging to 1 classes.

# %%
model = Sequential()

# First CONV-ReLU Layer
model.add(Conv2D(32, (3, 3), padding = 'same', input_shape = (img_rows, img_cols,1),kernel_regularizer=l2(0.38),
                 kernel_initializer=he_normal()))
model.add(BatchNormalization())
model.add(Activation('elu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.35))

# Second CONV-ReLU Layer
model.add(Conv2D(64, (5, 5), padding = "same",kernel_regularizer=l2(0.38),kernel_initializer=he_normal()))
model.add(BatchNormalization())
model.add(Activation('elu'))
model.add(MaxPooling2D(pool_size=(2,2)))
# model.add(Dropout(0.35))

# Second CONV-ReLU Layer
model.add(Conv2D(128, (7, 7), padding = "same",kernel_regularizer=l2(0.38),kernel_initializer=he_normal()))
model.add(BatchNormalization())
model.add(Activation('elu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.35))

## 3rd conv-pool layer
model.add(Conv2D(256, (3, 3), padding="same",kernel_regularizer=l2(0.38), kernel_initializer=he_normal()))
model.add(BatchNormalization())
model.add(Activation('elu'))
model.add(MaxPooling2D(pool_size=(2,2)))
# model.add(Dropout(0.35))

model.add(Flatten())

model.add(Dense(621))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(Dropout(0.35))


# Final Dense Layer
model.add(Dense(num_classes,activation='softmax',name='Hafizzo'))

print(model.summary())
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_98 (Conv2D)           (None, 64, 64, 32)        320
# _________________________________________________________________
# batch_normalization_99 (Batc (None, 64, 64, 32)        128
# _________________________________________________________________
# activation_99 (Activation)   (None, 64, 64, 32)        0
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 32, 32, 32)        0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_99 (Conv2D)           (None, 32, 32, 64)        51264
# _________________________________________________________________
# batch_normalization_100 (Bat (None, 32, 32, 64)        256
# _________________________________________________________________
# activation_100 (Activation)  (None, 32, 32, 64)        0
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_100 (Conv2D)          (None, 16, 16, 128)       401536
# _________________________________________________________________
# batch_normalization_101 (Bat (None, 16, 16, 128)       512
# _________________________________________________________________
# activation_101 (Activation)  (None, 16, 16, 128)       0
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 8, 8, 128)         0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 8, 8, 128)         0
# _________________________________________________________________
# conv2d_101 (Conv2D)          (None, 8, 8, 256)         295168
# _________________________________________________________________
# batch_normalization_102 (Bat (None, 8, 8, 256)         1024
# _________________________________________________________________
# activation_102 (Activation)  (None, 8, 8, 256)         0
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 4, 4, 256)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 4096)              0
# _________________________________________________________________
# dense_5 (Dense)              (None, 621)               2544237
# _________________________________________________________________
# activation_103 (Activation)  (None, 621)               0
# _________________________________________________________________
# batch_normalization_103 (Bat (None, 621)               2484
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 621)               0
# _________________________________________________________________
# Hafizzo (Dense)              (None, 15)                9330
# =================================================================
# Total params: 3,306,259
# Trainable params: 3,304,057
# Non-trainable params: 2,202
# _________________________________________________________________
# None

# %%
checkpoint = ModelCheckpoint("cnn_scene_SGDv2.h5",
                             monitor="val_loss",
                             mode="min",
                             save_best_only = True,
                             verbose=1)

earlystop = EarlyStopping(monitor = 'val_loss', 
                          min_delta = 0, 
                          patience = 5,
                          verbose = 1,
                          restore_best_weights = True)

reduce_lr = ReduceLROnPlateau(monitor = 'val_loss',
                              factor = 0.2,
                              patience = 3,
                              verbose = 1,
                              min_delta = 0.0001)

# we put our call backs into a callback list
callbacks = [ checkpoint,reduce_lr]

# We use a very small learning rate 
model.compile(loss = 'categorical_crossentropy',
              optimizer = SGD(learning_rate=0.001),
              metrics = ['accuracy'])


epochs = 100
import time
time_start=time.perf_counter()

history= model.fit_generator(
       
    train_generator,
    epochs = epochs,
    callbacks = callbacks,
    validation_data = validation_generator)

elapsed_time=time.perf_counter()-time_start
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:1972: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-91-2ace80597256> in <module>()
#      35     epochs = epochs,
#      36     callbacks = callbacks,
# ---> 37     validation_data = validation_generator)
#      38
#      39 elapsed_time=time.perf_counter()-time_start
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1987         use_multiprocessing=use_multiprocessing,
#    1988         shuffle=shuffle,
# -> 1989         initial_epoch=initial_epoch)
#    1990
#    1991   @doc_controls.do_not_generate_docs
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1146           use_multiprocessing=use_multiprocessing,
#    1147           model=self,
# -> 1148           steps_per_execution=self._steps_per_execution)
#    1149
#    1150       # Container that configures and calls `tf.keras.Callback`s.
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/data_adapter.py in get_data_handler(*args, **kwargs)
#    1381   if getattr(kwargs["model"], "_cluster_coordinator", None):
#    1382     return _ClusterCoordinatorDataHandler(*args, **kwargs)
# -> 1383   return DataHandler(*args, **kwargs)
#    1384
#    1385
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/data_adapter.py in __init__(self, x, y, sample_weight, batch_size, steps_per_epoch, initial_epoch, epochs, shuffle, class_weight, max_queue_size, workers, use_multiprocessing, model, steps_per_execution, distribute)
#    1148         use_multiprocessing=use_multiprocessing,
#    1149         distribution_strategy=tf.distribute.get_strategy(),
# -> 1150         model=model)
#    1151
#    1152     strategy = tf.distribute.get_strategy()
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/data_adapter.py in __init__(self, x, y, sample_weights, shuffle, workers, use_multiprocessing, max_queue_size, model, **kwargs)
#     922         max_queue_size=max_queue_size,
#     923         model=model,
# --> 924         **kwargs)
#     925
#     926   @staticmethod
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/data_adapter.py in __init__(self, x, y, sample_weights, workers, use_multiprocessing, max_queue_size, model, **kwargs)
#     792     # Since we have to know the dtype of the python generator when we build the
#     793     # dataset, we have to look at a batch to infer the structure.
# --> 794     peek, x = self._peek_and_restore(x)
#     795     peek = self._standardize_batch(peek)
#     796     peek = _process_tensorlike(peek)
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/data_adapter.py in _peek_and_restore(x)
#     926   @staticmethod
#     927   def _peek_and_restore(x):
# --> 928     return x[0], x
#     929
#     930   def _handle_multiprocessing(self, x, workers, use_multiprocessing,
#
# /usr/local/lib/python3.7/dist-packages/keras_preprocessing/image/iterator.py in __getitem__(self, idx)
#      55                              'but the Sequence '
#      56                              'has length {length}'.format(idx=idx,
# ---> 57                                                           length=len(self)))
#      58         if self.seed is not None:
#      59             np.random.seed(self.seed + self.total_batches_seen)
#
# ValueError: Asked to retrieve element 0, but the Sequence has length 0

# %% [markdown]
# # Preprocessing

# %%
num_classes = 15
img_rows, img_cols = 64,64
batch_size =32
# rescale=1./255
# home/kashraf/fall2021_cours
train_data_dir ="/content/drive/MyDrive/2021 Spring Courses/train_validation/train"
validation_data_dir = "/content/drive/MyDrive/2021 Spring Courses/train_validation/validation"

# Let's use some data augmentaiton 
train_datagen = ImageDataGenerator(
      
      horizontal_flip=True,
      vertical_flip=True,
      )
validation_datagen = ImageDataGenerator()
 
train_generator = train_datagen.flow_from_directory(
    train_data_dir,
    target_size=(img_rows, img_cols),
    color_mode="grayscale",
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=True)

validation_generator = validation_datagen.flow_from_directory(
    validation_data_dir,
    target_size=(img_rows, img_cols),
    color_mode="grayscale",
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False)
# Out:
# Found 4458 images belonging to 15 classes.
# Found 1362 images belonging to 15 classes.

# %%
model = Sequential()

# First CONV-ReLU Layer
model.add(Conv2D(32, (3, 3), padding = 'same', input_shape = (img_rows, img_cols,1),kernel_regularizer=l2(0.38),
                 kernel_initializer=he_normal()))
model.add(BatchNormalization())
model.add(Activation('elu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.35))

# Second CONV-ReLU Layer
model.add(Conv2D(64, (5, 5), padding = "same",kernel_regularizer=l2(0.38),kernel_initializer=he_normal()))
model.add(BatchNormalization())
model.add(Activation('elu'))
model.add(MaxPooling2D(pool_size=(2,2)))
# model.add(Dropout(0.35))

# Second CONV-ReLU Layer
model.add(Conv2D(128, (7, 7), padding = "same",kernel_regularizer=l2(0.38),kernel_initializer=he_normal()))
model.add(BatchNormalization())
model.add(Activation('elu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.35))

## 3rd conv-pool layer
model.add(Conv2D(256, (3, 3), padding="same",kernel_regularizer=l2(0.38), kernel_initializer=he_normal()))
model.add(BatchNormalization())
model.add(Activation('elu'))
model.add(MaxPooling2D(pool_size=(2,2)))
# model.add(Dropout(0.35))

model.add(Flatten())

model.add(Dense(621))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(Dropout(0.35))


# Final Dense Layer
model.add(Dense(num_classes,activation='softmax',name='Hafizzo'))

print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 64, 64, 32)        320
# _________________________________________________________________
# batch_normalization (BatchNo (None, 64, 64, 32)        128
# _________________________________________________________________
# activation (Activation)      (None, 64, 64, 32)        0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 32, 32, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 64)        51264
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 32, 32, 64)        256
# _________________________________________________________________
# activation_1 (Activation)    (None, 32, 32, 64)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 128)       401536
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 16, 16, 128)       512
# _________________________________________________________________
# activation_2 (Activation)    (None, 16, 16, 128)       0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 8, 128)         0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 8, 8, 128)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 8, 256)         295168
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 8, 8, 256)         1024
# _________________________________________________________________
# activation_3 (Activation)    (None, 8, 8, 256)         0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 4, 4, 256)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 4096)              0
# _________________________________________________________________
# dense (Dense)                (None, 621)               2544237
# _________________________________________________________________
# activation_4 (Activation)    (None, 621)               0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 621)               2484
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 621)               0
# _________________________________________________________________
# Hafizzo (Dense)              (None, 15)                9330
# =================================================================
# Total params: 3,306,259
# Trainable params: 3,304,057
# Non-trainable params: 2,202
# _________________________________________________________________
# None

# %%
checkpoint = ModelCheckpoint("cnn_scene_SGDv2.h5",
                             monitor="val_loss",
                             mode="min",
                             save_best_only = True,
                             verbose=1)

earlystop = EarlyStopping(monitor = 'val_loss', 
                          min_delta = 0, 
                          patience = 5,
                          verbose = 1,
                          restore_best_weights = True)

reduce_lr = ReduceLROnPlateau(monitor = 'val_loss',
                              factor = 0.2,
                              patience = 3,
                              verbose = 1,
                              min_delta = 0.0001)

# we put our call backs into a callback list
callbacks = [ checkpoint,reduce_lr]

# We use a very small learning rate 
model.compile(loss = 'categorical_crossentropy',
              optimizer = SGD(learning_rate=0.001),
              metrics = ['accuracy'])


epochs = 100
import time
time_start=time.perf_counter()

history= model.fit_generator(   
    
    train_generator,
    epochs = epochs,
    callbacks = callbacks,
    validation_data = validation_generator)
elapsed_time=time.perf_counter()-time_start
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:1972: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/100
# 140/140 [==============================] - 1068s 8s/step - loss: 329.8335 - accuracy: 0.1337 - val_loss: 295.2513 - val_accuracy: 0.2012
#
# Epoch 00001: val_loss improved from inf to 295.25131, saving model to cnn_scene_SGDv2.h5
# Epoch 2/100
# 140/140 [==============================] - 10s 75ms/step - loss: 266.7293 - accuracy: 0.1920 - val_loss: 240.2629 - val_accuracy: 0.1410
#
# Epoch 00002: val_loss improved from 295.25131 to 240.26288, saving model to cnn_scene_SGDv2.h5
# Epoch 3/100
# 140/140 [==============================] - 11s 76ms/step - loss: 216.0722 - accuracy: 0.2225 - val_loss: 195.8018 - val_accuracy: 0.1314
#
# Epoch 00003: val_loss improved from 240.26288 to 195.80179, saving model to cnn_scene_SGDv2.h5
# Epoch 4/100
# 140/140 [==============================] - 10s 74ms/step - loss: 174.9933 - accuracy: 0.2501 - val_loss: 160.2696 - val_accuracy: 0.1109
#
# Epoch 00004: val_loss improved from 195.80179 to 160.26958, saving model to cnn_scene_SGDv2.h5
# Epoch 5/100
# 140/140 [==============================] - 11s 76ms/step - loss: 141.8040 - accuracy: 0.2900 - val_loss: 131.5175 - val_accuracy: 0.0837
#
# Epoch 00005: val_loss improved from 160.26958 to 131.51753, saving model to cnn_scene_SGDv2.h5
# Epoch 6/100
# 140/140 [==============================] - 10s 75ms/step - loss: 114.9217 - accuracy: 0.3188 - val_loss: 107.6549 - val_accuracy: 0.0954
#
# Epoch 00006: val_loss improved from 131.51753 to 107.65486, saving model to cnn_scene_SGDv2.h5
# Epoch 7/100
# 140/140 [==============================] - 11s 76ms/step - loss: 93.2361 - accuracy: 0.3564 - val_loss: 89.2769 - val_accuracy: 0.0932
#
# Epoch 00007: val_loss improved from 107.65486 to 89.27689, saving model to cnn_scene_SGDv2.h5
# Epoch 8/100
# 140/140 [==============================] - 11s 75ms/step - loss: 75.6578 - accuracy: 0.3798 - val_loss: 72.9322 - val_accuracy: 0.1065
#
# Epoch 00008: val_loss improved from 89.27689 to 72.93220, saving model to cnn_scene_SGDv2.h5
# Epoch 9/100
# 140/140 [==============================] - 10s 73ms/step - loss: 61.4932 - accuracy: 0.4053 - val_loss: 60.6881 - val_accuracy: 0.1035
#
# Epoch 00009: val_loss improved from 72.93220 to 60.68811, saving model to cnn_scene_SGDv2.h5
# Epoch 10/100
# 140/140 [==============================] - 10s 73ms/step - loss: 50.0531 - accuracy: 0.4163 - val_loss: 48.0598 - val_accuracy: 0.1711
#
# Epoch 00010: val_loss improved from 60.68811 to 48.05975, saving model to cnn_scene_SGDv2.h5
# Epoch 11/100
# 140/140 [==============================] - 10s 72ms/step - loss: 40.7710 - accuracy: 0.4495 - val_loss: 39.4005 - val_accuracy: 0.1880
#
# Epoch 00011: val_loss improved from 48.05975 to 39.40055, saving model to cnn_scene_SGDv2.h5
# Epoch 12/100
# 140/140 [==============================] - 10s 74ms/step - loss: 33.2633 - accuracy: 0.4565 - val_loss: 34.3852 - val_accuracy: 0.1373
#
# Epoch 00012: val_loss improved from 39.40055 to 34.38515, saving model to cnn_scene_SGDv2.h5
# Epoch 13/100
# 140/140 [==============================] - 11s 76ms/step - loss: 27.2205 - accuracy: 0.4830 - val_loss: 27.1970 - val_accuracy: 0.2048
#
# Epoch 00013: val_loss improved from 34.38515 to 27.19699, saving model to cnn_scene_SGDv2.h5
# Epoch 14/100
# 140/140 [==============================] - 10s 75ms/step - loss: 22.3348 - accuracy: 0.4883 - val_loss: 24.6997 - val_accuracy: 0.1388
#
# Epoch 00014: val_loss improved from 27.19699 to 24.69971, saving model to cnn_scene_SGDv2.h5
# Epoch 15/100
# 140/140 [==============================] - 11s 75ms/step - loss: 18.3596 - accuracy: 0.4989 - val_loss: 23.5568 - val_accuracy: 0.1167
#
# Epoch 00015: val_loss improved from 24.69971 to 23.55677, saving model to cnn_scene_SGDv2.h5
# Epoch 16/100
# 140/140 [==============================] - 10s 75ms/step - loss: 15.1718 - accuracy: 0.5105 - val_loss: 19.6461 - val_accuracy: 0.1219
#
# Epoch 00016: val_loss improved from 23.55677 to 19.64607, saving model to cnn_scene_SGDv2.h5
# Epoch 17/100
# 140/140 [==============================] - 11s 75ms/step - loss: 12.5689 - accuracy: 0.5301 - val_loss: 13.4256 - val_accuracy: 0.2401
#
# Epoch 00017: val_loss improved from 19.64607 to 13.42557, saving model to cnn_scene_SGDv2.h5
# Epoch 18/100
# 140/140 [==============================] - 10s 74ms/step - loss: 10.4934 - accuracy: 0.5269 - val_loss: 12.9232 - val_accuracy: 0.1953
#
# Epoch 00018: val_loss improved from 13.42557 to 12.92316, saving model to cnn_scene_SGDv2.h5
# Epoch 19/100
# 140/140 [==============================] - 11s 75ms/step - loss: 8.7792 - accuracy: 0.5523 - val_loss: 10.1607 - val_accuracy: 0.2482
#
# Epoch 00019: val_loss improved from 12.92316 to 10.16073, saving model to cnn_scene_SGDv2.h5
# Epoch 20/100
# 140/140 [==============================] - 10s 74ms/step - loss: 7.4382 - accuracy: 0.5451 - val_loss: 8.1706 - val_accuracy: 0.3245
#
# Epoch 00020: val_loss improved from 10.16073 to 8.17062, saving model to cnn_scene_SGDv2.h5
# Epoch 21/100
# 140/140 [==============================] - 10s 75ms/step - loss: 6.3269 - accuracy: 0.5493 - val_loss: 8.0005 - val_accuracy: 0.2357
#
# Epoch 00021: val_loss improved from 8.17062 to 8.00054, saving model to cnn_scene_SGDv2.h5
# Epoch 22/100
# 140/140 [==============================] - 11s 76ms/step - loss: 5.4272 - accuracy: 0.5642 - val_loss: 6.4448 - val_accuracy: 0.3399
#
# Epoch 00022: val_loss improved from 8.00054 to 6.44475, saving model to cnn_scene_SGDv2.h5
# Epoch 23/100
# 140/140 [==============================] - 10s 74ms/step - loss: 4.6940 - accuracy: 0.5702 - val_loss: 6.6120 - val_accuracy: 0.2386
#
# Epoch 00023: val_loss did not improve from 6.44475
# Epoch 24/100
# 140/140 [==============================] - 10s 74ms/step - loss: 4.1042 - accuracy: 0.5774 - val_loss: 7.5997 - val_accuracy: 0.1696
#
# Epoch 00024: val_loss did not improve from 6.44475
# Epoch 25/100
# 140/140 [==============================] - 10s 75ms/step - loss: 3.6365 - accuracy: 0.5812 - val_loss: 3.9316 - val_accuracy: 0.5059
#
# Epoch 00025: val_loss improved from 6.44475 to 3.93157, saving model to cnn_scene_SGDv2.h5
# Epoch 26/100
# 140/140 [==============================] - 11s 76ms/step - loss: 3.2458 - accuracy: 0.5965 - val_loss: 6.1531 - val_accuracy: 0.2026
#
# Epoch 00026: val_loss did not improve from 3.93157
# Epoch 27/100
# 140/140 [==============================] - 10s 74ms/step - loss: 2.9642 - accuracy: 0.5971 - val_loss: 4.1410 - val_accuracy: 0.3069
#
# Epoch 00027: val_loss did not improve from 3.93157
# Epoch 28/100
# 140/140 [==============================] - 11s 76ms/step - loss: 2.6977 - accuracy: 0.6007 - val_loss: 3.9621 - val_accuracy: 0.4148
#
# Epoch 00028: val_loss did not improve from 3.93157
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Epoch 29/100
# 140/140 [==============================] - 11s 76ms/step - loss: 2.4049 - accuracy: 0.6494 - val_loss: 3.1159 - val_accuracy: 0.4978
#
# Epoch 00029: val_loss improved from 3.93157 to 3.11591, saving model to cnn_scene_SGDv2.h5
# Epoch 30/100
# 140/140 [==============================] - 11s 76ms/step - loss: 2.3036 - accuracy: 0.6655 - val_loss: 3.3147 - val_accuracy: 0.4486
#
# Epoch 00030: val_loss did not improve from 3.11591
# Epoch 31/100
# 140/140 [==============================] - 10s 74ms/step - loss: 2.2257 - accuracy: 0.6651 - val_loss: 2.3146 - val_accuracy: 0.6564
#
# Epoch 00031: val_loss improved from 3.11591 to 2.31459, saving model to cnn_scene_SGDv2.h5
# Epoch 32/100
# 140/140 [==============================] - 11s 75ms/step - loss: 2.1612 - accuracy: 0.6745 - val_loss: 2.5217 - val_accuracy: 0.5433
#
# Epoch 00032: val_loss did not improve from 2.31459
# Epoch 33/100
# 140/140 [==============================] - 10s 75ms/step - loss: 2.1099 - accuracy: 0.6801 - val_loss: 2.6498 - val_accuracy: 0.5382
#
# Epoch 00033: val_loss did not improve from 2.31459
# Epoch 34/100
# 140/140 [==============================] - 11s 77ms/step - loss: 2.0366 - accuracy: 0.6878 - val_loss: 2.4482 - val_accuracy: 0.5984
#
# Epoch 00034: val_loss did not improve from 2.31459
#
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 35/100
# 140/140 [==============================] - 11s 78ms/step - loss: 1.9798 - accuracy: 0.6963 - val_loss: 2.2358 - val_accuracy: 0.6490
#
# Epoch 00035: val_loss improved from 2.31459 to 2.23577, saving model to cnn_scene_SGDv2.h5
# Epoch 36/100
# 140/140 [==============================] - 11s 76ms/step - loss: 1.9573 - accuracy: 0.7082 - val_loss: 1.9822 - val_accuracy: 0.7232
#
# Epoch 00036: val_loss improved from 2.23577 to 1.98219, saving model to cnn_scene_SGDv2.h5
# Epoch 37/100
# 140/140 [==============================] - 11s 76ms/step - loss: 1.9344 - accuracy: 0.7059 - val_loss: 2.3711 - val_accuracy: 0.5977
#
# Epoch 00037: val_loss did not improve from 1.98219
# Epoch 38/100
# 140/140 [==============================] - 10s 75ms/step - loss: 1.9265 - accuracy: 0.7073 - val_loss: 2.4915 - val_accuracy: 0.5675
#
# Epoch 00038: val_loss did not improve from 1.98219
# Epoch 39/100
# 140/140 [==============================] - 10s 74ms/step - loss: 1.9169 - accuracy: 0.7039 - val_loss: 2.1415 - val_accuracy: 0.6637
#
# Epoch 00039: val_loss did not improve from 1.98219
#
# Epoch 00039: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# Epoch 40/100
# 140/140 [==============================] - 10s 74ms/step - loss: 1.8977 - accuracy: 0.7097 - val_loss: 1.9202 - val_accuracy: 0.7291
#
# Epoch 00040: val_loss improved from 1.98219 to 1.92023, saving model to cnn_scene_SGDv2.h5
# Epoch 41/100
# 140/140 [==============================] - 10s 74ms/step - loss: 1.9027 - accuracy: 0.7068 - val_loss: 2.0095 - val_accuracy: 0.7048
#
# Epoch 00041: val_loss did not improve from 1.92023
# Epoch 42/100
# 140/140 [==============================] - 10s 74ms/step - loss: 1.8793 - accuracy: 0.7158 - val_loss: 1.9101 - val_accuracy: 0.7364
#
# Epoch 00042: val_loss improved from 1.92023 to 1.91008, saving model to cnn_scene_SGDv2.h5
# Epoch 43/100
# 140/140 [==============================] - 10s 73ms/step - loss: 1.8867 - accuracy: 0.7113 - val_loss: 1.9447 - val_accuracy: 0.7173
#
# Epoch 00043: val_loss did not improve from 1.91008
# Epoch 44/100
# 140/140 [==============================] - 10s 74ms/step - loss: 1.8874 - accuracy: 0.7214 - val_loss: 1.9488 - val_accuracy: 0.7115
#
# Epoch 00044: val_loss did not improve from 1.91008
# Epoch 45/100
# 140/140 [==============================] - 10s 74ms/step - loss: 1.8632 - accuracy: 0.7183 - val_loss: 2.0002 - val_accuracy: 0.6953
#
# Epoch 00045: val_loss did not improve from 1.91008
#
# Epoch 00045: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# Epoch 46/100
# 140/140 [==============================] - 10s 74ms/step - loss: 1.8843 - accuracy: 0.7084 - val_loss: 1.9537 - val_accuracy: 0.7137
#
# Epoch 00046: val_loss did not improve from 1.91008
# Epoch 47/100
# 140/140 [==============================] - 10s 75ms/step - loss: 1.8726 - accuracy: 0.7185 - val_loss: 1.9534 - val_accuracy: 0.7115
#
# Epoch 00047: val_loss did not improve from 1.91008
# Epoch 48/100
# 140/140 [==============================] - 10s 75ms/step - loss: 1.8858 - accuracy: 0.7131 - val_loss: 1.9397 - val_accuracy: 0.7225
#
# Epoch 00048: val_loss did not improve from 1.91008
#
# Epoch 00048: ReduceLROnPlateau reducing learning rate to 3.200000264769187e-07.
# Epoch 49/100
# 140/140 [==============================] - 10s 75ms/step - loss: 1.8720 - accuracy: 0.7279 - val_loss: 1.9414 - val_accuracy: 0.7203
#
# Epoch 00049: val_loss did not improve from 1.91008
# Epoch 50/100
# 140/140 [==============================] - 10s 74ms/step - loss: 1.8795 - accuracy: 0.7165 - val_loss: 1.9386 - val_accuracy: 0.7188
#
# Epoch 00050: val_loss did not improve from 1.91008
# Epoch 51/100
# 140/140 [==============================] - 10s 75ms/step - loss: 1.8598 - accuracy: 0.7212 - val_loss: 1.9438 - val_accuracy: 0.7195
#
# Epoch 00051: val_loss did not improve from 1.91008
#
# Epoch 00051: ReduceLROnPlateau reducing learning rate to 6.400000529538374e-08.
# Epoch 52/100
# 140/140 [==============================] - 10s 75ms/step - loss: 1.8952 - accuracy: 0.7057 - val_loss: 1.9421 - val_accuracy: 0.7203
#
# Epoch 00052: val_loss did not improve from 1.91008
# Epoch 53/100
# 140/140 [==============================] - 10s 75ms/step - loss: 1.8703 - accuracy: 0.7227 - val_loss: 1.9416 - val_accuracy: 0.7195
#
# Epoch 00053: val_loss did not improve from 1.91008
# Epoch 54/100
# 140/140 [==============================] - 10s 74ms/step - loss: 1.8812 - accuracy: 0.7178 - val_loss: 1.9458 - val_accuracy: 0.7159
#
# Epoch 00054: val_loss did not improve from 1.91008
#
# Epoch 00054: ReduceLROnPlateau reducing learning rate to 1.2800001059076749e-08.
# Epoch 55/100
# 140/140 [==============================] - 10s 74ms/step - loss: 1.9012 - accuracy: 0.7048 - val_loss: 1.9445 - val_accuracy: 0.7166
#
# Epoch 00055: val_loss did not improve from 1.91008
# Epoch 56/100
# 140/140 [==============================] - 10s 75ms/step - loss: 1.9096 - accuracy: 0.7082 - val_loss: 1.9386 - val_accuracy: 0.7210
#
# Epoch 00056: val_loss did not improve from 1.91008
# Epoch 57/100
# 140/140 [==============================] - 10s 74ms/step - loss: 1.8715 - accuracy: 0.7183 - val_loss: 1.9480 - val_accuracy: 0.7181
#
# Epoch 00057: val_loss did not improve from 1.91008
#
# Epoch 00057: ReduceLROnPlateau reducing learning rate to 2.5600002118153498e-09.
# Epoch 58/100
# 140/140 [==============================] - 11s 75ms/step - loss: 1.8865 - accuracy: 0.7133 - val_loss: 1.9413 - val_accuracy: 0.7210
#
# Epoch 00058: val_loss did not improve from 1.91008
# Epoch 59/100
# 140/140 [==============================] - 11s 76ms/step - loss: 1.8938 - accuracy: 0.7122 - val_loss: 1.9428 - val_accuracy: 0.7181
#
# Epoch 00059: val_loss did not improve from 1.91008
# Epoch 60/100
# 140/140 [==============================] - 11s 75ms/step - loss: 1.8625 - accuracy: 0.7218 - val_loss: 1.9390 - val_accuracy: 0.7188
#
# Epoch 00060: val_loss did not improve from 1.91008
#
# Epoch 00060: ReduceLROnPlateau reducing learning rate to 5.1200004236307e-10.
# Epoch 61/100
# 140/140 [==============================] - 11s 76ms/step - loss: 1.8805 - accuracy: 0.7118 - val_loss: 1.9406 - val_accuracy: 0.7188
#
# Epoch 00061: val_loss did not improve from 1.91008
# Epoch 62/100
# 140/140 [==============================] - 11s 76ms/step - loss: 1.9046 - accuracy: 0.7010 - val_loss: 1.9414 - val_accuracy: 0.7203
#
# Epoch 00062: val_loss did not improve from 1.91008
# Epoch 63/100
# 140/140 [==============================] - 11s 76ms/step - loss: 1.8804 - accuracy: 0.7122 - val_loss: 1.9458 - val_accuracy: 0.7181
#
# Epoch 00063: val_loss did not improve from 1.91008
#
# Epoch 00063: ReduceLROnPlateau reducing learning rate to 1.0240001069306004e-10.
# Epoch 64/100
# 140/140 [==============================] - 11s 76ms/step - loss: 1.8654 - accuracy: 0.7113 - val_loss: 1.9449 - val_accuracy: 0.7203
#
# Epoch 00064: val_loss did not improve from 1.91008
# Epoch 65/100
# 140/140 [==============================] - 11s 76ms/step - loss: 1.8864 - accuracy: 0.7095 - val_loss: 1.9404 - val_accuracy: 0.7188
#
# Epoch 00065: val_loss did not improve from 1.91008
# Epoch 66/100
# 140/140 [==============================] - 11s 75ms/step - loss: 1.8905 - accuracy: 0.7115 - val_loss: 1.9374 - val_accuracy: 0.7195
#
# Epoch 00066: val_loss did not improve from 1.91008
#
# Epoch 00066: ReduceLROnPlateau reducing learning rate to 2.0480002416167767e-11.
# Epoch 67/100
# 140/140 [==============================] - 10s 74ms/step - loss: 1.8809 - accuracy: 0.7149 - val_loss: 1.9499 - val_accuracy: 0.7173
#
# Epoch 00067: val_loss did not improve from 1.91008
# Epoch 68/100
# 140/140 [==============================] - 10s 75ms/step - loss: 1.9045 - accuracy: 0.7055 - val_loss: 1.9502 - val_accuracy: 0.7173
#
# Epoch 00068: val_loss did not improve from 1.91008
# Epoch 69/100
# 140/140 [==============================] - 10s 75ms/step - loss: 1.8871 - accuracy: 0.7091 - val_loss: 1.9456 - val_accuracy: 0.7166
#
# Epoch 00069: val_loss did not improve from 1.91008
#
# Epoch 00069: ReduceLROnPlateau reducing learning rate to 4.096000622011431e-12.
# Epoch 70/100
# 140/140 [==============================] - 11s 75ms/step - loss: 1.8685 - accuracy: 0.7227 - val_loss: 1.9474 - val_accuracy: 0.7173
#
# Epoch 00070: val_loss did not improve from 1.91008
# Epoch 71/100
# 140/140 [==============================] - 11s 76ms/step - loss: 1.8750 - accuracy: 0.7127 - val_loss: 1.9460 - val_accuracy: 0.7195
#
# Epoch 00071: val_loss did not improve from 1.91008
# Epoch 72/100
# 140/140 [==============================] - 11s 76ms/step - loss: 1.8723 - accuracy: 0.7147 - val_loss: 1.9457 - val_accuracy: 0.7188
#
# Epoch 00072: val_loss did not improve from 1.91008
#
# Epoch 00072: ReduceLROnPlateau reducing learning rate to 8.192000897078167e-13.
# Epoch 73/100
# 140/140 [==============================] - 11s 76ms/step - loss: 1.8732 - accuracy: 0.7183 - val_loss: 1.9444 - val_accuracy: 0.7159
#
# Epoch 00073: val_loss did not improve from 1.91008
# Epoch 74/100
# 140/140 [==============================] - 11s 77ms/step - loss: 1.8928 - accuracy: 0.7120 - val_loss: 1.9509 - val_accuracy: 0.7181
#
# Epoch 00074: val_loss did not improve from 1.91008
# Epoch 75/100
# 140/140 [==============================] - 11s 77ms/step - loss: 1.9038 - accuracy: 0.7014 - val_loss: 1.9439 - val_accuracy: 0.7181
#
# Epoch 00075: val_loss did not improve from 1.91008
#
# Epoch 00075: ReduceLROnPlateau reducing learning rate to 1.6384001360475466e-13.
# Epoch 76/100
# 140/140 [==============================] - 11s 75ms/step - loss: 1.8842 - accuracy: 0.7035 - val_loss: 1.9485 - val_accuracy: 0.7159
#
# Epoch 00076: val_loss did not improve from 1.91008
# Epoch 77/100
# 140/140 [==============================] - 11s 76ms/step - loss: 1.8925 - accuracy: 0.7086 - val_loss: 1.9419 - val_accuracy: 0.7173
#
# Epoch 00077: val_loss did not improve from 1.91008
# Epoch 78/100
# 140/140 [==============================] - 11s 76ms/step - loss: 1.8812 - accuracy: 0.7113 - val_loss: 1.9478 - val_accuracy: 0.7173
#
# Epoch 00078: val_loss did not improve from 1.91008
#
# Epoch 00078: ReduceLROnPlateau reducing learning rate to 3.2768002178849846e-14.
# Epoch 79/100
# 140/140 [==============================] - 11s 77ms/step - loss: 1.8821 - accuracy: 0.7120 - val_loss: 1.9424 - val_accuracy: 0.7173
#
# Epoch 00079: val_loss did not improve from 1.91008
# Epoch 80/100
# 140/140 [==============================] - 11s 77ms/step - loss: 1.8974 - accuracy: 0.7084 - val_loss: 1.9467 - val_accuracy: 0.7166
#
# Epoch 00080: val_loss did not improve from 1.91008
# Epoch 81/100
# 140/140 [==============================] - 11s 77ms/step - loss: 1.8881 - accuracy: 0.7120 - val_loss: 1.9442 - val_accuracy: 0.7181
#
# Epoch 00081: val_loss did not improve from 1.91008
#
# Epoch 00081: ReduceLROnPlateau reducing learning rate to 6.553600300244697e-15.
# Epoch 82/100
# 140/140 [==============================] - 10s 75ms/step - loss: 1.8882 - accuracy: 0.7158 - val_loss: 1.9389 - val_accuracy: 0.7188
#
# Epoch 00082: val_loss did not improve from 1.91008
# Epoch 83/100
# 140/140 [==============================] - 10s 75ms/step - loss: 1.8659 - accuracy: 0.7223 - val_loss: 1.9451 - val_accuracy: 0.7181
#
# Epoch 00083: val_loss did not improve from 1.91008
# Epoch 84/100
# 140/140 [==============================] - 11s 77ms/step - loss: 1.8576 - accuracy: 0.7165 - val_loss: 1.9392 - val_accuracy: 0.7210
#
# Epoch 00084: val_loss did not improve from 1.91008
#
# Epoch 00084: ReduceLROnPlateau reducing learning rate to 1.3107200431082805e-15.
# Epoch 85/100
# 140/140 [==============================] - 11s 75ms/step - loss: 1.8796 - accuracy: 0.7138 - val_loss: 1.9444 - val_accuracy: 0.7181
#
# Epoch 00085: val_loss did not improve from 1.91008
# Epoch 86/100
# 140/140 [==============================] - 11s 75ms/step - loss: 1.8779 - accuracy: 0.7156 - val_loss: 1.9451 - val_accuracy: 0.7181
#
# Epoch 00086: val_loss did not improve from 1.91008
# Epoch 87/100
# 140/140 [==============================] - 11s 76ms/step - loss: 1.8657 - accuracy: 0.7118 - val_loss: 1.9406 - val_accuracy: 0.7181
#
# Epoch 00087: val_loss did not improve from 1.91008
#
# Epoch 00087: ReduceLROnPlateau reducing learning rate to 2.6214401285682084e-16.
# Epoch 88/100
# 140/140 [==============================] - 10s 74ms/step - loss: 1.8747 - accuracy: 0.7158 - val_loss: 1.9437 - val_accuracy: 0.7188
#
# Epoch 00088: val_loss did not improve from 1.91008
# Epoch 89/100
# 140/140 [==============================] - 10s 75ms/step - loss: 1.8794 - accuracy: 0.7156 - val_loss: 1.9416 - val_accuracy: 0.7188
#
# Epoch 00089: val_loss did not improve from 1.91008
# Epoch 90/100
# 140/140 [==============================] - 10s 75ms/step - loss: 1.8778 - accuracy: 0.7158 - val_loss: 1.9440 - val_accuracy: 0.7181
#
# Epoch 00090: val_loss did not improve from 1.91008
#
# Epoch 00090: ReduceLROnPlateau reducing learning rate to 5.2428803630155353e-17.
# Epoch 91/100
# 140/140 [==============================] - 11s 78ms/step - loss: 1.8825 - accuracy: 0.7084 - val_loss: 1.9411 - val_accuracy: 0.7173
#
# Epoch 00091: val_loss did not improve from 1.91008
# Epoch 92/100
# 140/140 [==============================] - 11s 80ms/step - loss: 1.8737 - accuracy: 0.7192 - val_loss: 1.9371 - val_accuracy: 0.7195
#
# Epoch 00092: val_loss did not improve from 1.91008
# Epoch 93/100
# 140/140 [==============================] - 11s 80ms/step - loss: 1.8840 - accuracy: 0.7158 - val_loss: 1.9466 - val_accuracy: 0.7173
#
# Epoch 00093: val_loss did not improve from 1.91008
#
# Epoch 00093: ReduceLROnPlateau reducing learning rate to 1.0485760990728867e-17.
# Epoch 94/100
# 140/140 [==============================] - 11s 80ms/step - loss: 1.8829 - accuracy: 0.7044 - val_loss: 1.9487 - val_accuracy: 0.7173
#
# Epoch 00094: val_loss did not improve from 1.91008
# Epoch 95/100
# 140/140 [==============================] - 14s 103ms/step - loss: 1.8789 - accuracy: 0.7127 - val_loss: 1.9513 - val_accuracy: 0.7159
#
# Epoch 00095: val_loss did not improve from 1.91008
# Epoch 96/100
# 140/140 [==============================] - 10s 75ms/step - loss: 1.8861 - accuracy: 0.7124 - val_loss: 1.9436 - val_accuracy: 0.7181
#
# Epoch 00096: val_loss did not improve from 1.91008
#
# Epoch 00096: ReduceLROnPlateau reducing learning rate to 2.097152165058549e-18.
# Epoch 97/100
# 140/140 [==============================] - 11s 76ms/step - loss: 1.8634 - accuracy: 0.7207 - val_loss: 1.9461 - val_accuracy: 0.7166
#
# Epoch 00097: val_loss did not improve from 1.91008
# Epoch 98/100
# 140/140 [==============================] - 11s 77ms/step - loss: 1.8865 - accuracy: 0.7174 - val_loss: 1.9439 - val_accuracy: 0.7188
#
# Epoch 00098: val_loss did not improve from 1.91008
# Epoch 99/100
# 140/140 [==============================] - 11s 81ms/step - loss: 1.8925 - accuracy: 0.7106 - val_loss: 1.9457 - val_accuracy: 0.7188
#
# Epoch 00099: val_loss did not improve from 1.91008
#
# Epoch 00099: ReduceLROnPlateau reducing learning rate to 4.19430449555322e-19.
# Epoch 100/100
# 140/140 [==============================] - 14s 98ms/step - loss: 1.8966 - accuracy: 0.7075 - val_loss: 1.9377 - val_accuracy: 0.7210
#
# Epoch 00100: val_loss did not improve from 1.91008

# %%
print(history.history.keys())
# Plotting our loss charts
import matplotlib.pyplot as plt

history_dict = history.history
loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']
epochs = range(1, len(loss_values) + 1)

line1 = plt.plot(epochs, val_loss_values, label='Validation/Test Loss')
line2 = plt.plot(epochs, loss_values, label='Training Loss')
plt.setp(line1, linewidth=2.0, marker = '+', markersize=10.0)
plt.setp(line2, linewidth=2.0, marker = '4', markersize=10.0)
plt.xlabel('Epochs') 
plt.ylabel('Loss')
plt.grid(True)
plt.legend()
plt.savefig('Loss.png', dpi = 1200)
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])

# %%
# Plotting our accuracy charts
import matplotlib.pyplot as plt

history_dict = history.history
acc_values = history_dict['accuracy']
val_acc_values = history_dict['val_accuracy']
epochs = range(1, len(loss_values) + 1)
line1 = plt.plot(epochs, val_acc_values, label='Validation/Test Accuracy')
line2 = plt.plot(epochs, acc_values, label='Training Accuracy')
plt.setp(line1, linewidth=2.0, marker = '+', markersize=10.0)
plt.setp(line2, linewidth=2.0, marker = '4', markersize=10.0)
plt.xlabel('Epochs') 
plt.ylabel('Accuracy')
plt.grid(True)
plt.legend()
plt.savefig('Accuracy.png', dpi = 1200)
plt.show()

# %%
elapsed_time
# Out:
# 2148.1909870299996

# %% [markdown]
# # Evaluation

# %%
import seaborn as sr
import pandas as pd

y_pred=np.argmax(model.predict(validation_generator), axis=1)
y_test=validation_generator.classes


# y_predict,distances1=  face_recognition(x_test_recog,T_distance)
# accuracy=accuracy_score(y_test_recog,y_predict)
class_names=["Bedroom","Building","Store","Industry","Living room","Kitchen","Highway",'Coast',
             "Office","Mountain","Inside city","Forest","Surbub","Street","Opencountry"]
report=classification_report(y_test,y_pred,target_names=class_names)

conf=confusion_matrix(y_test,y_pred,normalize="true")
conf_df=pd.DataFrame(conf, index=class_names, columns=class_names)
# print("\nFace  accuracy =",accuracy)
print("\n Classification report: \n",report)
fig=plt.figure(figsize=(15,10))
sr.heatmap(conf_df,annot=True,cmap="Blues")
plt.title("Confusion matrix")
plt.show()
# Out:
#  Classification report:
#                precision    recall  f1-score   support
#
#      Bedroom       0.76      0.68      0.72       114
#     Building       0.96      0.92      0.94       111
#        Store       0.91      0.25      0.39       121
#     Industry       0.77      0.67      0.72       122
#  Living room       0.70      0.65      0.67       125
#      Kitchen       0.83      0.65      0.73        77
#      Highway       0.62      0.99      0.76        75
#        Coast       1.00      0.62      0.77        77
#       Office       0.67      0.78      0.73        79
#     Mountain       0.86      0.71      0.78        79
#  Inside city       0.49      0.94      0.64        77
#       Forest       0.85      0.81      0.83        79
#       Surbub       0.51      0.96      0.67        78
#       Street       0.96      0.72      0.83        76
#  Opencountry       0.60      0.75      0.67        72
#
#     accuracy                           0.72      1362
#    macro avg       0.77      0.74      0.72      1362
# weighted avg       0.77      0.72      0.72      1362

# %%
len(validation_generator.classes)
# Out:
# 1362

# %%
checkpoint = ModelCheckpoint("cnn_scene_Adam.h5",
                             monitor="val_loss",
                             mode="min",
                             save_best_only = True,
                             verbose=1)

earlystop = EarlyStopping(monitor = 'val_loss', 
                          min_delta = 0, 
                          patience = 5,
                          verbose = 1,
                          restore_best_weights = True)

reduce_lr = ReduceLROnPlateau(monitor = 'val_loss',
                              factor = 0.2,
                              patience = 3,
                              verbose = 1,
                              min_delta = 0.0001)

# we put our call backs into a callback list
callbacks = [ checkpoint,reduce_lr]

# We use a very small learning rate 
model.compile(loss = 'categorical_crossentropy',
              optimizer = Adam(learning_rate=0.001),
              metrics = ['accuracy'])


epochs = 100
import time
time_start=time.perf_counter()

history= model.fit_generator(   
    
    train_generator,
    epochs = epochs,
    callbacks = callbacks,
    validation_data = validation_generator)
elapsed_time=time.perf_counter()-time_start
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:1972: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/100
# 140/140 [==============================] - 11s 75ms/step - loss: 4.1893 - accuracy: 0.3484 - val_loss: 8.2122 - val_accuracy: 0.1079
#
# Epoch 00001: val_loss improved from inf to 8.21218, saving model to cnn_scene_Adam.h5
# Epoch 2/100
# 140/140 [==============================] - 12s 86ms/step - loss: 2.9155 - accuracy: 0.3699 - val_loss: 3.5216 - val_accuracy: 0.2261
#
# Epoch 00002: val_loss improved from 8.21218 to 3.52164, saving model to cnn_scene_Adam.h5
# Epoch 3/100
# 140/140 [==============================] - 10s 75ms/step - loss: 2.7453 - accuracy: 0.4040 - val_loss: 2.9709 - val_accuracy: 0.2959
#
# Epoch 00003: val_loss improved from 3.52164 to 2.97093, saving model to cnn_scene_Adam.h5
# Epoch 4/100
# 140/140 [==============================] - 10s 74ms/step - loss: 2.7561 - accuracy: 0.4217 - val_loss: 6.0801 - val_accuracy: 0.1145
#
# Epoch 00004: val_loss did not improve from 2.97093
# Epoch 5/100
# 140/140 [==============================] - 10s 74ms/step - loss: 2.7177 - accuracy: 0.4253 - val_loss: 6.3592 - val_accuracy: 0.0683
#
# Epoch 00005: val_loss did not improve from 2.97093
# Epoch 6/100
# 140/140 [==============================] - 11s 80ms/step - loss: 2.6108 - accuracy: 0.4392 - val_loss: 4.9266 - val_accuracy: 0.1285
#
# Epoch 00006: val_loss did not improve from 2.97093
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Epoch 7/100
# 140/140 [==============================] - 10s 74ms/step - loss: 1.8984 - accuracy: 0.5247 - val_loss: 2.2585 - val_accuracy: 0.3605
#
# Epoch 00007: val_loss improved from 2.97093 to 2.25854, saving model to cnn_scene_Adam.h5
# Epoch 8/100
# 140/140 [==============================] - 11s 75ms/step - loss: 1.6614 - accuracy: 0.5543 - val_loss: 3.3534 - val_accuracy: 0.2372
#
# Epoch 00008: val_loss did not improve from 2.25854
# Epoch 9/100
# 140/140 [==============================] - 10s 75ms/step - loss: 1.6815 - accuracy: 0.5462 - val_loss: 2.5197 - val_accuracy: 0.3275
#
# Epoch 00009: val_loss did not improve from 2.25854
# Epoch 10/100
# 140/140 [==============================] - 10s 75ms/step - loss: 1.6813 - accuracy: 0.5594 - val_loss: 2.0997 - val_accuracy: 0.4369
#
# Epoch 00010: val_loss improved from 2.25854 to 2.09970, saving model to cnn_scene_Adam.h5
# Epoch 11/100
# 140/140 [==============================] - 10s 74ms/step - loss: 1.6563 - accuracy: 0.5592 - val_loss: 1.6646 - val_accuracy: 0.5653
#
# Epoch 00011: val_loss improved from 2.09970 to 1.66460, saving model to cnn_scene_Adam.h5
# Epoch 12/100
# 140/140 [==============================] - 10s 73ms/step - loss: 1.6580 - accuracy: 0.5698 - val_loss: 1.9527 - val_accuracy: 0.5000
#
# Epoch 00012: val_loss did not improve from 1.66460
# Epoch 13/100
# 140/140 [==============================] - 10s 73ms/step - loss: 1.6019 - accuracy: 0.5774 - val_loss: 2.3630 - val_accuracy: 0.3855
#
# Epoch 00013: val_loss did not improve from 1.66460
# Epoch 14/100
# 140/140 [==============================] - 10s 74ms/step - loss: 1.6016 - accuracy: 0.5823 - val_loss: 1.7496 - val_accuracy: 0.5411
#
# Epoch 00014: val_loss did not improve from 1.66460
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 15/100
# 140/140 [==============================] - 11s 75ms/step - loss: 1.4057 - accuracy: 0.6310 - val_loss: 1.4484 - val_accuracy: 0.6160
#
# Epoch 00015: val_loss improved from 1.66460 to 1.44842, saving model to cnn_scene_Adam.h5
# Epoch 16/100
# 140/140 [==============================] - 11s 79ms/step - loss: 1.2713 - accuracy: 0.6456 - val_loss: 1.3015 - val_accuracy: 0.6388
#
# Epoch 00016: val_loss improved from 1.44842 to 1.30152, saving model to cnn_scene_Adam.h5
# Epoch 17/100
# 140/140 [==============================] - 10s 74ms/step - loss: 1.1924 - accuracy: 0.6604 - val_loss: 1.2820 - val_accuracy: 0.6270
#
# Epoch 00017: val_loss improved from 1.30152 to 1.28200, saving model to cnn_scene_Adam.h5
# Epoch 18/100
# 140/140 [==============================] - 10s 75ms/step - loss: 1.1877 - accuracy: 0.6563 - val_loss: 1.2686 - val_accuracy: 0.6248
#
# Epoch 00018: val_loss improved from 1.28200 to 1.26863, saving model to cnn_scene_Adam.h5
# Epoch 19/100
# 140/140 [==============================] - 10s 73ms/step - loss: 1.1837 - accuracy: 0.6676 - val_loss: 1.6062 - val_accuracy: 0.5323
#
# Epoch 00019: val_loss did not improve from 1.26863
# Epoch 20/100
# 140/140 [==============================] - 11s 75ms/step - loss: 1.1520 - accuracy: 0.6712 - val_loss: 1.2095 - val_accuracy: 0.6424
#
# Epoch 00020: val_loss improved from 1.26863 to 1.20949, saving model to cnn_scene_Adam.h5
# Epoch 21/100
# 140/140 [==============================] - 10s 74ms/step - loss: 1.1439 - accuracy: 0.6745 - val_loss: 1.3199 - val_accuracy: 0.6167
#
# Epoch 00021: val_loss did not improve from 1.20949
# Epoch 22/100
# 140/140 [==============================] - 10s 73ms/step - loss: 1.1453 - accuracy: 0.6765 - val_loss: 1.1362 - val_accuracy: 0.6630
#
# Epoch 00022: val_loss improved from 1.20949 to 1.13619, saving model to cnn_scene_Adam.h5
# Epoch 23/100
# 140/140 [==============================] - 10s 74ms/step - loss: 1.1509 - accuracy: 0.6803 - val_loss: 1.4771 - val_accuracy: 0.5698
#
# Epoch 00023: val_loss did not improve from 1.13619
# Epoch 24/100
# 140/140 [==============================] - 10s 74ms/step - loss: 1.1260 - accuracy: 0.6958 - val_loss: 1.3372 - val_accuracy: 0.6344
#
# Epoch 00024: val_loss did not improve from 1.13619
# Epoch 25/100
# 140/140 [==============================] - 10s 74ms/step - loss: 1.0946 - accuracy: 0.6983 - val_loss: 1.7697 - val_accuracy: 0.5499
#
# Epoch 00025: val_loss did not improve from 1.13619
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# Epoch 26/100
# 140/140 [==============================] - 10s 73ms/step - loss: 1.0191 - accuracy: 0.7214 - val_loss: 1.0026 - val_accuracy: 0.7203
#
# Epoch 00026: val_loss improved from 1.13619 to 1.00263, saving model to cnn_scene_Adam.h5
# Epoch 27/100
# 140/140 [==============================] - 10s 73ms/step - loss: 0.9629 - accuracy: 0.7382 - val_loss: 1.0040 - val_accuracy: 0.7269
#
# Epoch 00027: val_loss did not improve from 1.00263
# Epoch 28/100
# 140/140 [==============================] - 10s 74ms/step - loss: 0.9515 - accuracy: 0.7340 - val_loss: 0.9035 - val_accuracy: 0.7584
#
# Epoch 00028: val_loss improved from 1.00263 to 0.90347, saving model to cnn_scene_Adam.h5
# Epoch 29/100
# 140/140 [==============================] - 10s 74ms/step - loss: 0.9271 - accuracy: 0.7479 - val_loss: 0.8764 - val_accuracy: 0.7643
#
# Epoch 00029: val_loss improved from 0.90347 to 0.87644, saving model to cnn_scene_Adam.h5
# Epoch 30/100
# 140/140 [==============================] - 10s 74ms/step - loss: 0.9104 - accuracy: 0.7456 - val_loss: 0.8797 - val_accuracy: 0.7724
#
# Epoch 00030: val_loss did not improve from 0.87644
# Epoch 31/100
# 140/140 [==============================] - 10s 74ms/step - loss: 0.9063 - accuracy: 0.7461 - val_loss: 0.8671 - val_accuracy: 0.7724
#
# Epoch 00031: val_loss improved from 0.87644 to 0.86709, saving model to cnn_scene_Adam.h5
# Epoch 32/100
# 140/140 [==============================] - 10s 74ms/step - loss: 0.8972 - accuracy: 0.7544 - val_loss: 1.0567 - val_accuracy: 0.6975
#
# Epoch 00032: val_loss did not improve from 0.86709
# Epoch 33/100
# 140/140 [==============================] - 10s 75ms/step - loss: 0.8705 - accuracy: 0.7524 - val_loss: 0.9036 - val_accuracy: 0.7489
#
# Epoch 00033: val_loss did not improve from 0.86709
# Epoch 34/100
# 140/140 [==============================] - 10s 75ms/step - loss: 0.8736 - accuracy: 0.7645 - val_loss: 0.8332 - val_accuracy: 0.7805
#
# Epoch 00034: val_loss improved from 0.86709 to 0.83320, saving model to cnn_scene_Adam.h5
# Epoch 35/100
# 140/140 [==============================] - 10s 73ms/step - loss: 0.8486 - accuracy: 0.7649 - val_loss: 0.9019 - val_accuracy: 0.7555
#
# Epoch 00035: val_loss did not improve from 0.83320
# Epoch 36/100
# 140/140 [==============================] - 10s 74ms/step - loss: 0.8283 - accuracy: 0.7779 - val_loss: 0.8209 - val_accuracy: 0.7790
#
# Epoch 00036: val_loss improved from 0.83320 to 0.82092, saving model to cnn_scene_Adam.h5
# Epoch 37/100
# 140/140 [==============================] - 10s 73ms/step - loss: 0.8294 - accuracy: 0.7714 - val_loss: 0.7827 - val_accuracy: 0.7827
#
# Epoch 00037: val_loss improved from 0.82092 to 0.78267, saving model to cnn_scene_Adam.h5
# Epoch 38/100
# 140/140 [==============================] - 10s 74ms/step - loss: 0.8095 - accuracy: 0.7782 - val_loss: 0.8023 - val_accuracy: 0.7797
#
# Epoch 00038: val_loss did not improve from 0.78267
# Epoch 39/100
# 140/140 [==============================] - 10s 74ms/step - loss: 0.8162 - accuracy: 0.7799 - val_loss: 0.8160 - val_accuracy: 0.7746
#
# Epoch 00039: val_loss did not improve from 0.78267
# Epoch 40/100
# 140/140 [==============================] - 10s 74ms/step - loss: 0.7947 - accuracy: 0.7748 - val_loss: 0.8296 - val_accuracy: 0.7783
#
# Epoch 00040: val_loss did not improve from 0.78267
#
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# Epoch 41/100
# 140/140 [==============================] - 10s 73ms/step - loss: 0.7774 - accuracy: 0.7882 - val_loss: 0.7011 - val_accuracy: 0.8216
#
# Epoch 00041: val_loss improved from 0.78267 to 0.70108, saving model to cnn_scene_Adam.h5
# Epoch 42/100
# 140/140 [==============================] - 10s 73ms/step - loss: 0.7632 - accuracy: 0.7934 - val_loss: 0.7159 - val_accuracy: 0.8238
#
# Epoch 00042: val_loss did not improve from 0.70108
# Epoch 43/100
# 140/140 [==============================] - 11s 77ms/step - loss: 0.7504 - accuracy: 0.8001 - val_loss: 0.7076 - val_accuracy: 0.8223
#
# Epoch 00043: val_loss did not improve from 0.70108
# Epoch 44/100
# 140/140 [==============================] - 10s 74ms/step - loss: 0.7567 - accuracy: 0.7974 - val_loss: 0.6809 - val_accuracy: 0.8275
#
# Epoch 00044: val_loss improved from 0.70108 to 0.68090, saving model to cnn_scene_Adam.h5
# Epoch 45/100
# 140/140 [==============================] - 10s 74ms/step - loss: 0.7359 - accuracy: 0.8087 - val_loss: 0.6908 - val_accuracy: 0.8260
#
# Epoch 00045: val_loss did not improve from 0.68090
# Epoch 46/100
# 140/140 [==============================] - 10s 74ms/step - loss: 0.7293 - accuracy: 0.8069 - val_loss: 0.6977 - val_accuracy: 0.8186
#
# Epoch 00046: val_loss did not improve from 0.68090
# Epoch 47/100
# 140/140 [==============================] - 10s 74ms/step - loss: 0.7214 - accuracy: 0.8096 - val_loss: 0.6801 - val_accuracy: 0.8223
#
# Epoch 00047: val_loss improved from 0.68090 to 0.68012, saving model to cnn_scene_Adam.h5
# Epoch 48/100
# 140/140 [==============================] - 10s 74ms/step - loss: 0.7290 - accuracy: 0.8093 - val_loss: 0.6567 - val_accuracy: 0.8399
#
# Epoch 00048: val_loss improved from 0.68012 to 0.65675, saving model to cnn_scene_Adam.h5
# Epoch 49/100
# 140/140 [==============================] - 10s 74ms/step - loss: 0.7228 - accuracy: 0.8134 - val_loss: 0.6978 - val_accuracy: 0.8231
#
# Epoch 00049: val_loss did not improve from 0.65675
# Epoch 50/100
# 140/140 [==============================] - 10s 74ms/step - loss: 0.7143 - accuracy: 0.8120 - val_loss: 0.6827 - val_accuracy: 0.8267
#
# Epoch 00050: val_loss did not improve from 0.65675
# Epoch 51/100
# 140/140 [==============================] - 10s 74ms/step - loss: 0.7129 - accuracy: 0.8082 - val_loss: 0.6622 - val_accuracy: 0.8341
#
# Epoch 00051: val_loss did not improve from 0.65675
#
# Epoch 00051: ReduceLROnPlateau reducing learning rate to 3.200000264769187e-07.
# Epoch 52/100
# 140/140 [==============================] - 10s 75ms/step - loss: 0.7045 - accuracy: 0.8165 - val_loss: 0.6449 - val_accuracy: 0.8421
#
# Epoch 00052: val_loss improved from 0.65675 to 0.64494, saving model to cnn_scene_Adam.h5
# Epoch 53/100
# 140/140 [==============================] - 10s 74ms/step - loss: 0.7023 - accuracy: 0.8161 - val_loss: 0.6431 - val_accuracy: 0.8407
#
# Epoch 00053: val_loss improved from 0.64494 to 0.64307, saving model to cnn_scene_Adam.h5
# Epoch 54/100
# 140/140 [==============================] - 10s 74ms/step - loss: 0.7047 - accuracy: 0.8129 - val_loss: 0.6373 - val_accuracy: 0.8451
#
# Epoch 00054: val_loss improved from 0.64307 to 0.63727, saving model to cnn_scene_Adam.h5
# Epoch 55/100
# 140/140 [==============================] - 10s 74ms/step - loss: 0.6895 - accuracy: 0.8239 - val_loss: 0.6367 - val_accuracy: 0.8443
#
# Epoch 00055: val_loss improved from 0.63727 to 0.63671, saving model to cnn_scene_Adam.h5
# Epoch 56/100
# 140/140 [==============================] - 10s 74ms/step - loss: 0.6966 - accuracy: 0.8138 - val_loss: 0.6426 - val_accuracy: 0.8392
#
# Epoch 00056: val_loss did not improve from 0.63671
# Epoch 57/100
# 140/140 [==============================] - 10s 74ms/step - loss: 0.6880 - accuracy: 0.8228 - val_loss: 0.6427 - val_accuracy: 0.8399
#
# Epoch 00057: val_loss did not improve from 0.63671
# Epoch 58/100
# 140/140 [==============================] - 10s 74ms/step - loss: 0.6991 - accuracy: 0.8105 - val_loss: 0.6384 - val_accuracy: 0.8451
#
# Epoch 00058: val_loss did not improve from 0.63671
#
# Epoch 00058: ReduceLROnPlateau reducing learning rate to 6.400000529538374e-08.
# Epoch 59/100
# 140/140 [==============================] - 10s 74ms/step - loss: 0.6932 - accuracy: 0.8226 - val_loss: 0.6383 - val_accuracy: 0.8421
#
# Epoch 00059: val_loss did not improve from 0.63671
# Epoch 60/100
# 140/140 [==============================] - 10s 74ms/step - loss: 0.6921 - accuracy: 0.8134 - val_loss: 0.6356 - val_accuracy: 0.8407
#
# Epoch 00060: val_loss improved from 0.63671 to 0.63557, saving model to cnn_scene_Adam.h5
# Epoch 61/100
# 140/140 [==============================] - 10s 73ms/step - loss: 0.6957 - accuracy: 0.8179 - val_loss: 0.6357 - val_accuracy: 0.8436
#
# Epoch 00061: val_loss did not improve from 0.63557
# Epoch 62/100
# 140/140 [==============================] - 10s 74ms/step - loss: 0.6977 - accuracy: 0.8098 - val_loss: 0.6356 - val_accuracy: 0.8421
#
# Epoch 00062: val_loss did not improve from 0.63557
# Epoch 63/100
# 140/140 [==============================] - 10s 73ms/step - loss: 0.6972 - accuracy: 0.8145 - val_loss: 0.6339 - val_accuracy: 0.8473
#
# Epoch 00063: val_loss improved from 0.63557 to 0.63388, saving model to cnn_scene_Adam.h5
# Epoch 64/100
# 140/140 [==============================] - 10s 74ms/step - loss: 0.7020 - accuracy: 0.8138 - val_loss: 0.6358 - val_accuracy: 0.8421
#
# Epoch 00064: val_loss did not improve from 0.63388
# Epoch 65/100
# 140/140 [==============================] - 10s 72ms/step - loss: 0.6952 - accuracy: 0.8185 - val_loss: 0.6338 - val_accuracy: 0.8443
#
# Epoch 00065: val_loss improved from 0.63388 to 0.63377, saving model to cnn_scene_Adam.h5
# Epoch 66/100
# 140/140 [==============================] - 10s 74ms/step - loss: 0.6952 - accuracy: 0.8208 - val_loss: 0.6339 - val_accuracy: 0.8429
#
# Epoch 00066: val_loss did not improve from 0.63377
# Epoch 67/100
# 140/140 [==============================] - 10s 75ms/step - loss: 0.6975 - accuracy: 0.8246 - val_loss: 0.6358 - val_accuracy: 0.8421
#
# Epoch 00067: val_loss did not improve from 0.63377
# Epoch 68/100
# 140/140 [==============================] - 10s 75ms/step - loss: 0.6887 - accuracy: 0.8228 - val_loss: 0.6354 - val_accuracy: 0.8421
#
# Epoch 00068: val_loss did not improve from 0.63377
#
# Epoch 00068: ReduceLROnPlateau reducing learning rate to 1.2800001059076749e-08.
# Epoch 69/100
# 140/140 [==============================] - 10s 74ms/step - loss: 0.6899 - accuracy: 0.8185 - val_loss: 0.6334 - val_accuracy: 0.8443
#
# Epoch 00069: val_loss improved from 0.63377 to 0.63342, saving model to cnn_scene_Adam.h5
# Epoch 70/100
# 140/140 [==============================] - 10s 75ms/step - loss: 0.6933 - accuracy: 0.8172 - val_loss: 0.6311 - val_accuracy: 0.8480
#
# Epoch 00070: val_loss improved from 0.63342 to 0.63114, saving model to cnn_scene_Adam.h5
# Epoch 71/100
# 140/140 [==============================] - 11s 76ms/step - loss: 0.6876 - accuracy: 0.8199 - val_loss: 0.6358 - val_accuracy: 0.8429
#
# Epoch 00071: val_loss did not improve from 0.63114
# Epoch 72/100
# 140/140 [==============================] - 11s 76ms/step - loss: 0.6945 - accuracy: 0.8179 - val_loss: 0.6336 - val_accuracy: 0.8421
#
# Epoch 00072: val_loss did not improve from 0.63114
# Epoch 73/100
# 140/140 [==============================] - 11s 78ms/step - loss: 0.6814 - accuracy: 0.8268 - val_loss: 0.6347 - val_accuracy: 0.8436
#
# Epoch 00073: val_loss did not improve from 0.63114
#
# Epoch 00073: ReduceLROnPlateau reducing learning rate to 2.5600002118153498e-09.
# Epoch 74/100
# 140/140 [==============================] - 11s 76ms/step - loss: 0.6919 - accuracy: 0.8181 - val_loss: 0.6334 - val_accuracy: 0.8436
#
# Epoch 00074: val_loss did not improve from 0.63114
# Epoch 75/100
# 140/140 [==============================] - 11s 76ms/step - loss: 0.6896 - accuracy: 0.8158 - val_loss: 0.6352 - val_accuracy: 0.8421
#
# Epoch 00075: val_loss did not improve from 0.63114
# Epoch 76/100
# 140/140 [==============================] - 10s 74ms/step - loss: 0.6908 - accuracy: 0.8192 - val_loss: 0.6334 - val_accuracy: 0.8451
#
# Epoch 00076: val_loss did not improve from 0.63114
#
# Epoch 00076: ReduceLROnPlateau reducing learning rate to 5.1200004236307e-10.
# Epoch 77/100
# 140/140 [==============================] - 10s 74ms/step - loss: 0.6978 - accuracy: 0.8201 - val_loss: 0.6332 - val_accuracy: 0.8421
#
# Epoch 00077: val_loss did not improve from 0.63114
# Epoch 78/100
# 140/140 [==============================] - 10s 75ms/step - loss: 0.6973 - accuracy: 0.8197 - val_loss: 0.6346 - val_accuracy: 0.8429
#
# Epoch 00078: val_loss did not improve from 0.63114
# Epoch 79/100
# 140/140 [==============================] - 10s 74ms/step - loss: 0.6814 - accuracy: 0.8248 - val_loss: 0.6344 - val_accuracy: 0.8458
#
# Epoch 00079: val_loss did not improve from 0.63114
#
# Epoch 00079: ReduceLROnPlateau reducing learning rate to 1.0240001069306004e-10.
# Epoch 80/100
# 140/140 [==============================] - 10s 75ms/step - loss: 0.6856 - accuracy: 0.8228 - val_loss: 0.6337 - val_accuracy: 0.8458
#
# Epoch 00080: val_loss did not improve from 0.63114
# Epoch 81/100
# 140/140 [==============================] - 10s 75ms/step - loss: 0.6867 - accuracy: 0.8197 - val_loss: 0.6342 - val_accuracy: 0.8436
#
# Epoch 00081: val_loss did not improve from 0.63114
# Epoch 82/100
# 140/140 [==============================] - 10s 73ms/step - loss: 0.6913 - accuracy: 0.8226 - val_loss: 0.6346 - val_accuracy: 0.8451
#
# Epoch 00082: val_loss did not improve from 0.63114
#
# Epoch 00082: ReduceLROnPlateau reducing learning rate to 2.0480002416167767e-11.
# Epoch 83/100
# 140/140 [==============================] - 10s 74ms/step - loss: 0.6916 - accuracy: 0.8190 - val_loss: 0.6332 - val_accuracy: 0.8458
#
# Epoch 00083: val_loss did not improve from 0.63114
# Epoch 84/100
# 140/140 [==============================] - 10s 75ms/step - loss: 0.6932 - accuracy: 0.8185 - val_loss: 0.6316 - val_accuracy: 0.8473
#
# Epoch 00084: val_loss did not improve from 0.63114
# Epoch 85/100
# 140/140 [==============================] - 10s 74ms/step - loss: 0.6855 - accuracy: 0.8183 - val_loss: 0.6340 - val_accuracy: 0.8421
#
# Epoch 00085: val_loss did not improve from 0.63114
#
# Epoch 00085: ReduceLROnPlateau reducing learning rate to 4.096000622011431e-12.
# Epoch 86/100
# 140/140 [==============================] - 10s 74ms/step - loss: 0.6983 - accuracy: 0.8143 - val_loss: 0.6333 - val_accuracy: 0.8429
#
# Epoch 00086: val_loss did not improve from 0.63114
# Epoch 87/100
# 140/140 [==============================] - 10s 75ms/step - loss: 0.6947 - accuracy: 0.8188 - val_loss: 0.6316 - val_accuracy: 0.8436
#
# Epoch 00087: val_loss did not improve from 0.63114
# Epoch 88/100
# 140/140 [==============================] - 10s 74ms/step - loss: 0.6894 - accuracy: 0.8188 - val_loss: 0.6310 - val_accuracy: 0.8458
#
# Epoch 00088: val_loss improved from 0.63114 to 0.63099, saving model to cnn_scene_Adam.h5
# Epoch 89/100
# 140/140 [==============================] - 10s 75ms/step - loss: 0.6878 - accuracy: 0.8172 - val_loss: 0.6340 - val_accuracy: 0.8451
#
# Epoch 00089: val_loss did not improve from 0.63099
# Epoch 90/100
# 140/140 [==============================] - 10s 75ms/step - loss: 0.6906 - accuracy: 0.8174 - val_loss: 0.6340 - val_accuracy: 0.8458
#
# Epoch 00090: val_loss did not improve from 0.63099
# Epoch 91/100
# 140/140 [==============================] - 10s 72ms/step - loss: 0.6936 - accuracy: 0.8179 - val_loss: 0.6334 - val_accuracy: 0.8443
#
# Epoch 00091: val_loss did not improve from 0.63099
#
# Epoch 00091: ReduceLROnPlateau reducing learning rate to 8.192000897078167e-13.
# Epoch 92/100
# 140/140 [==============================] - 10s 75ms/step - loss: 0.6965 - accuracy: 0.8183 - val_loss: 0.6326 - val_accuracy: 0.8458
#
# Epoch 00092: val_loss did not improve from 0.63099
# Epoch 93/100
# 140/140 [==============================] - 10s 75ms/step - loss: 0.7067 - accuracy: 0.8120 - val_loss: 0.6316 - val_accuracy: 0.8465
#
# Epoch 00093: val_loss did not improve from 0.63099
# Epoch 94/100
# 140/140 [==============================] - 10s 74ms/step - loss: 0.7019 - accuracy: 0.8138 - val_loss: 0.6343 - val_accuracy: 0.8451
#
# Epoch 00094: val_loss did not improve from 0.63099
#
# Epoch 00094: ReduceLROnPlateau reducing learning rate to 1.6384001360475466e-13.
# Epoch 95/100
# 140/140 [==============================] - 10s 74ms/step - loss: 0.6970 - accuracy: 0.8154 - val_loss: 0.6322 - val_accuracy: 0.8451
#
# Epoch 00095: val_loss did not improve from 0.63099
# Epoch 96/100
# 140/140 [==============================] - 11s 75ms/step - loss: 0.7000 - accuracy: 0.8185 - val_loss: 0.6310 - val_accuracy: 0.8465
#
# Epoch 00096: val_loss did not improve from 0.63099
# Epoch 97/100
# 140/140 [==============================] - 10s 74ms/step - loss: 0.6862 - accuracy: 0.8203 - val_loss: 0.6316 - val_accuracy: 0.8458
#
# Epoch 00097: val_loss did not improve from 0.63099
#
# Epoch 00097: ReduceLROnPlateau reducing learning rate to 3.2768002178849846e-14.
# Epoch 98/100
# 140/140 [==============================] - 11s 75ms/step - loss: 0.6978 - accuracy: 0.8156 - val_loss: 0.6320 - val_accuracy: 0.8451
#
# Epoch 00098: val_loss did not improve from 0.63099
# Epoch 99/100
# 140/140 [==============================] - 10s 75ms/step - loss: 0.6844 - accuracy: 0.8284 - val_loss: 0.6357 - val_accuracy: 0.8421
#
# Epoch 00099: val_loss did not improve from 0.63099
# Epoch 100/100
# 140/140 [==============================] - 10s 75ms/step - loss: 0.6928 - accuracy: 0.8199 - val_loss: 0.6349 - val_accuracy: 0.8421
#
# Epoch 00100: val_loss did not improve from 0.63099
#
# Epoch 00100: ReduceLROnPlateau reducing learning rate to 6.553600300244697e-15.

# %%
print(history.history.keys())
# Plotting our loss charts
import matplotlib.pyplot as plt

history_dict = history.history
loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']
epochs = range(1, len(loss_values) + 1)

line1 = plt.plot(epochs, val_loss_values, label='Validation/Test Loss')
line2 = plt.plot(epochs, loss_values, label='Training Loss')
plt.setp(line1, linewidth=2.0, marker = '+', markersize=10.0)
plt.setp(line2, linewidth=2.0, marker = '4', markersize=10.0)
plt.xlabel('Epochs') 
plt.ylabel('Loss')
plt.grid(True)
plt.legend()
plt.savefig('Loss.png', dpi = 1200)
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])

# %%
# Plotting our accuracy charts
import matplotlib.pyplot as plt

history_dict = history.history
acc_values = history_dict['accuracy']
val_acc_values = history_dict['val_accuracy']
epochs = range(1, len(loss_values) + 1)
line1 = plt.plot(epochs, val_acc_values, label='Validation/Test Accuracy')
line2 = plt.plot(epochs, acc_values, label='Training Accuracy')
plt.setp(line1, linewidth=2.0, marker = '+', markersize=10.0)
plt.setp(line2, linewidth=2.0, marker = '4', markersize=10.0)
plt.xlabel('Epochs') 
plt.ylabel('Accuracy')
plt.grid(True)
plt.legend()
plt.savefig('Accuracy.png', dpi = 1200)
plt.show()

# %%
elapsed_time
# Out:
# 1068.2545447629996

# %% [markdown]
# # Evaluation

# %%
import seaborn as sr
import pandas as pd

y_pred=np.argmax(model.predict(validation_generator), axis=1)
y_test=validation_generator.classes


# y_predict,distances1=  face_recognition(x_test_recog,T_distance)
# accuracy=accuracy_score(y_test_recog,y_predict)
class_names=["Bedroom","Building","Store","Industry","Living room","Kitchen","Highway",'Coast',
             "Office","Mountain","Inside city","Forest","Surbub","Street","Opencountry"]
report=classification_report(y_test,y_pred,target_names=class_names)

conf=confusion_matrix(y_test,y_pred,normalize="true")
conf_df=pd.DataFrame(conf, index=class_names, columns=class_names)
# print("\nFace  accuracy =",accuracy)
print("\n Classification report: \n",report)
fig=plt.figure(figsize=(15,10))
sr.heatmap(conf_df,annot=True,cmap="Blues")
plt.title("Confusion matrix")
plt.show()
# Out:
#  Classification report:
#                precision    recall  f1-score   support
#
#      Bedroom       0.85      0.72      0.78       114
#     Building       0.96      0.97      0.96       111
#        Store       0.94      0.60      0.73       121
#     Industry       0.86      0.79      0.82       122
#  Living room       0.69      0.76      0.73       125
#      Kitchen       0.82      0.88      0.85        77
#      Highway       0.79      0.99      0.88        75
#        Coast       0.97      0.81      0.88        77
#       Office       0.84      0.89      0.86        79
#     Mountain       0.84      0.85      0.84        79
#  Inside city       0.81      0.90      0.85        77
#       Forest       0.93      0.97      0.95        79
#       Surbub       0.74      0.96      0.84        78
#       Street       0.93      0.91      0.92        76
#  Opencountry       0.79      0.88      0.83        72
#
#     accuracy                           0.84      1362
#    macro avg       0.85      0.86      0.85      1362
# weighted avg       0.85      0.84      0.84      1362

# %%
len(validation_generator.classes)
# Out:
# 1362

# %% [markdown]
# Model 3: RMSProp

# %%
checkpoint = ModelCheckpoint("cnn_scene_RMSProp.h5",
                             monitor="val_loss",
                             mode="min",
                             save_best_only = True,
                             verbose=1)

earlystop = EarlyStopping(monitor = 'val_loss', 
                          min_delta = 0, 
                          patience = 5,
                          verbose = 1,
                          restore_best_weights = True)

reduce_lr = ReduceLROnPlateau(monitor = 'val_loss',
                              factor = 0.2,
                              patience = 3,
                              verbose = 1,
                              min_delta = 0.0001)

# we put our call backs into a callback list
callbacks = [ checkpoint,reduce_lr]

# We use a very small learning rate 
model.compile(loss = 'categorical_crossentropy',
              optimizer = RMSprop(learning_rate=0.001),
              metrics = ['accuracy'])


epochs = 100
import time
time_start=time.perf_counter()

history= model.fit_generator(   
    
    train_generator,
    epochs = epochs,
    callbacks = callbacks,
    validation_data = validation_generator)
elapsed_time=time.perf_counter()-time_start
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:1972: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/100
# 140/140 [==============================] - 12s 75ms/step - loss: 3.4725 - accuracy: 0.2687 - val_loss: 5.4655 - val_accuracy: 0.0932
#
# Epoch 00001: val_loss improved from inf to 5.46550, saving model to cnn_scene_RMSProp.h5
# Epoch 2/100
# 140/140 [==============================] - 10s 74ms/step - loss: 3.1042 - accuracy: 0.2690 - val_loss: 4.9986 - val_accuracy: 0.0617
#
# Epoch 00002: val_loss improved from 5.46550 to 4.99856, saving model to cnn_scene_RMSProp.h5
# Epoch 3/100
# 140/140 [==============================] - 10s 73ms/step - loss: 3.0212 - accuracy: 0.2788 - val_loss: 3.5999 - val_accuracy: 0.1057
#
# Epoch 00003: val_loss improved from 4.99856 to 3.59987, saving model to cnn_scene_RMSProp.h5
# Epoch 4/100
# 140/140 [==============================] - 10s 74ms/step - loss: 2.9683 - accuracy: 0.2900 - val_loss: 5.3484 - val_accuracy: 0.0587
#
# Epoch 00004: val_loss did not improve from 3.59987
# Epoch 5/100
# 140/140 [==============================] - 10s 74ms/step - loss: 2.9281 - accuracy: 0.2853 - val_loss: 3.6356 - val_accuracy: 0.1292
#
# Epoch 00005: val_loss did not improve from 3.59987
# Epoch 6/100
# 140/140 [==============================] - 10s 74ms/step - loss: 2.9086 - accuracy: 0.2999 - val_loss: 8.2356 - val_accuracy: 0.1439
#
# Epoch 00006: val_loss did not improve from 3.59987
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Epoch 7/100
# 140/140 [==============================] - 10s 73ms/step - loss: 1.9974 - accuracy: 0.4260 - val_loss: 3.6253 - val_accuracy: 0.1182
#
# Epoch 00007: val_loss did not improve from 3.59987
# Epoch 8/100
# 140/140 [==============================] - 10s 74ms/step - loss: 1.7993 - accuracy: 0.4794 - val_loss: 2.1801 - val_accuracy: 0.3223
#
# Epoch 00008: val_loss improved from 3.59987 to 2.18009, saving model to cnn_scene_RMSProp.h5
# Epoch 9/100
# 140/140 [==============================] - 10s 74ms/step - loss: 1.7332 - accuracy: 0.4984 - val_loss: 1.9659 - val_accuracy: 0.4266
#
# Epoch 00009: val_loss improved from 2.18009 to 1.96595, saving model to cnn_scene_RMSProp.h5
# Epoch 10/100
# 140/140 [==============================] - 11s 79ms/step - loss: 1.7142 - accuracy: 0.5083 - val_loss: 1.9415 - val_accuracy: 0.4471
#
# Epoch 00010: val_loss improved from 1.96595 to 1.94153, saving model to cnn_scene_RMSProp.h5
# Epoch 11/100
# 140/140 [==============================] - 10s 74ms/step - loss: 1.7088 - accuracy: 0.5168 - val_loss: 2.8018 - val_accuracy: 0.2915
#
# Epoch 00011: val_loss did not improve from 1.94153
# Epoch 12/100
# 140/140 [==============================] - 10s 74ms/step - loss: 1.6769 - accuracy: 0.5379 - val_loss: 2.6879 - val_accuracy: 0.2966
#
# Epoch 00012: val_loss did not improve from 1.94153
# Epoch 13/100
# 140/140 [==============================] - 10s 74ms/step - loss: 1.6446 - accuracy: 0.5467 - val_loss: 2.1654 - val_accuracy: 0.3568
#
# Epoch 00013: val_loss did not improve from 1.94153
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 14/100
# 140/140 [==============================] - 10s 75ms/step - loss: 1.3490 - accuracy: 0.6294 - val_loss: 1.6608 - val_accuracy: 0.5162
#
# Epoch 00014: val_loss improved from 1.94153 to 1.66081, saving model to cnn_scene_RMSProp.h5
# Epoch 15/100
# 140/140 [==============================] - 10s 74ms/step - loss: 1.2550 - accuracy: 0.6339 - val_loss: 1.3347 - val_accuracy: 0.6043
#
# Epoch 00015: val_loss improved from 1.66081 to 1.33471, saving model to cnn_scene_RMSProp.h5
# Epoch 16/100
# 140/140 [==============================] - 10s 74ms/step - loss: 1.1991 - accuracy: 0.6519 - val_loss: 1.8961 - val_accuracy: 0.4280
#
# Epoch 00016: val_loss did not improve from 1.33471
# Epoch 17/100
# 140/140 [==============================] - 13s 93ms/step - loss: 1.1917 - accuracy: 0.6489 - val_loss: 1.3959 - val_accuracy: 0.5734
#
# Epoch 00017: val_loss did not improve from 1.33471
# Epoch 18/100
# 140/140 [==============================] - 10s 74ms/step - loss: 1.1702 - accuracy: 0.6640 - val_loss: 1.2083 - val_accuracy: 0.6402
#
# Epoch 00018: val_loss improved from 1.33471 to 1.20835, saving model to cnn_scene_RMSProp.h5
# Epoch 19/100
# 140/140 [==============================] - 16s 113ms/step - loss: 1.1514 - accuracy: 0.6633 - val_loss: 1.2154 - val_accuracy: 0.6410
#
# Epoch 00019: val_loss did not improve from 1.20835
# Epoch 20/100
# 140/140 [==============================] - 10s 75ms/step - loss: 1.1389 - accuracy: 0.6669 - val_loss: 1.1091 - val_accuracy: 0.6858
#
# Epoch 00020: val_loss improved from 1.20835 to 1.10912, saving model to cnn_scene_RMSProp.h5
# Epoch 21/100
# 140/140 [==============================] - 10s 74ms/step - loss: 1.1424 - accuracy: 0.6660 - val_loss: 1.4240 - val_accuracy: 0.5932
#
# Epoch 00021: val_loss did not improve from 1.10912
# Epoch 22/100
# 140/140 [==============================] - 10s 74ms/step - loss: 1.1195 - accuracy: 0.6747 - val_loss: 1.2304 - val_accuracy: 0.6336
#
# Epoch 00022: val_loss did not improve from 1.10912
# Epoch 23/100
# 140/140 [==============================] - 10s 75ms/step - loss: 1.1198 - accuracy: 0.6790 - val_loss: 1.1336 - val_accuracy: 0.6674
#
# Epoch 00023: val_loss did not improve from 1.10912
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# Epoch 24/100
# 140/140 [==============================] - 10s 75ms/step - loss: 1.0187 - accuracy: 0.7120 - val_loss: 1.0401 - val_accuracy: 0.6982
#
# Epoch 00024: val_loss improved from 1.10912 to 1.04012, saving model to cnn_scene_RMSProp.h5
# Epoch 25/100
# 140/140 [==============================] - 11s 76ms/step - loss: 1.0013 - accuracy: 0.7113 - val_loss: 1.0123 - val_accuracy: 0.7151
#
# Epoch 00025: val_loss improved from 1.04012 to 1.01232, saving model to cnn_scene_RMSProp.h5
# Epoch 26/100
# 140/140 [==============================] - 11s 76ms/step - loss: 0.9674 - accuracy: 0.7315 - val_loss: 0.9847 - val_accuracy: 0.7137
#
# Epoch 00026: val_loss improved from 1.01232 to 0.98465, saving model to cnn_scene_RMSProp.h5
# Epoch 27/100
# 140/140 [==============================] - 10s 75ms/step - loss: 0.9624 - accuracy: 0.7232 - val_loss: 0.9808 - val_accuracy: 0.7210
#
# Epoch 00027: val_loss improved from 0.98465 to 0.98077, saving model to cnn_scene_RMSProp.h5
# Epoch 28/100
# 140/140 [==============================] - 12s 85ms/step - loss: 0.9589 - accuracy: 0.7272 - val_loss: 1.0063 - val_accuracy: 0.7217
#
# Epoch 00028: val_loss did not improve from 0.98077
# Epoch 29/100
# 140/140 [==============================] - 10s 74ms/step - loss: 0.9283 - accuracy: 0.7396 - val_loss: 0.9444 - val_accuracy: 0.7335
#
# Epoch 00029: val_loss improved from 0.98077 to 0.94444, saving model to cnn_scene_RMSProp.h5
# Epoch 30/100
# 140/140 [==============================] - 11s 76ms/step - loss: 0.9131 - accuracy: 0.7414 - val_loss: 0.9875 - val_accuracy: 0.7129
#
# Epoch 00030: val_loss did not improve from 0.94444
# Epoch 31/100
# 140/140 [==============================] - 11s 75ms/step - loss: 0.9124 - accuracy: 0.7414 - val_loss: 0.9059 - val_accuracy: 0.7379
#
# Epoch 00031: val_loss improved from 0.94444 to 0.90590, saving model to cnn_scene_RMSProp.h5
# Epoch 32/100
# 140/140 [==============================] - 10s 75ms/step - loss: 0.9095 - accuracy: 0.7409 - val_loss: 0.9582 - val_accuracy: 0.7239
#
# Epoch 00032: val_loss did not improve from 0.90590
# Epoch 33/100
# 140/140 [==============================] - 12s 85ms/step - loss: 0.8932 - accuracy: 0.7476 - val_loss: 0.9273 - val_accuracy: 0.7247
#
# Epoch 00033: val_loss did not improve from 0.90590
# Epoch 34/100
# 140/140 [==============================] - 11s 75ms/step - loss: 0.8803 - accuracy: 0.7510 - val_loss: 0.9101 - val_accuracy: 0.7298
#
# Epoch 00034: val_loss did not improve from 0.90590
#
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# Epoch 35/100
# 140/140 [==============================] - 10s 75ms/step - loss: 0.8658 - accuracy: 0.7562 - val_loss: 0.8378 - val_accuracy: 0.7614
#
# Epoch 00035: val_loss improved from 0.90590 to 0.83784, saving model to cnn_scene_RMSProp.h5
# Epoch 36/100
# 140/140 [==============================] - 11s 75ms/step - loss: 0.8558 - accuracy: 0.7633 - val_loss: 0.8450 - val_accuracy: 0.7621
#
# Epoch 00036: val_loss did not improve from 0.83784
# Epoch 37/100
# 140/140 [==============================] - 10s 75ms/step - loss: 0.8533 - accuracy: 0.7600 - val_loss: 0.8267 - val_accuracy: 0.7665
#
# Epoch 00037: val_loss improved from 0.83784 to 0.82673, saving model to cnn_scene_RMSProp.h5
# Epoch 38/100
# 140/140 [==============================] - 11s 75ms/step - loss: 0.8425 - accuracy: 0.7618 - val_loss: 0.8249 - val_accuracy: 0.7680
#
# Epoch 00038: val_loss improved from 0.82673 to 0.82487, saving model to cnn_scene_RMSProp.h5
# Epoch 39/100
# 140/140 [==============================] - 11s 76ms/step - loss: 0.8307 - accuracy: 0.7633 - val_loss: 0.8041 - val_accuracy: 0.7805
#
# Epoch 00039: val_loss improved from 0.82487 to 0.80408, saving model to cnn_scene_RMSProp.h5
# Epoch 40/100
# 140/140 [==============================] - 11s 76ms/step - loss: 0.8407 - accuracy: 0.7647 - val_loss: 0.8126 - val_accuracy: 0.7731
#
# Epoch 00040: val_loss did not improve from 0.80408
# Epoch 41/100
# 140/140 [==============================] - 11s 75ms/step - loss: 0.8315 - accuracy: 0.7699 - val_loss: 0.8257 - val_accuracy: 0.7643
#
# Epoch 00041: val_loss did not improve from 0.80408
# Epoch 42/100
# 140/140 [==============================] - 10s 74ms/step - loss: 0.8300 - accuracy: 0.7627 - val_loss: 0.7973 - val_accuracy: 0.7753
#
# Epoch 00042: val_loss improved from 0.80408 to 0.79732, saving model to cnn_scene_RMSProp.h5
# Epoch 43/100
# 140/140 [==============================] - 11s 75ms/step - loss: 0.8228 - accuracy: 0.7719 - val_loss: 0.8159 - val_accuracy: 0.7717
#
# Epoch 00043: val_loss did not improve from 0.79732
# Epoch 44/100
# 140/140 [==============================] - 10s 75ms/step - loss: 0.8283 - accuracy: 0.7719 - val_loss: 0.8062 - val_accuracy: 0.7819
#
# Epoch 00044: val_loss did not improve from 0.79732
# Epoch 45/100
# 140/140 [==============================] - 10s 75ms/step - loss: 0.8270 - accuracy: 0.7696 - val_loss: 0.8047 - val_accuracy: 0.7805
#
# Epoch 00045: val_loss did not improve from 0.79732
#
# Epoch 00045: ReduceLROnPlateau reducing learning rate to 3.200000264769187e-07.
# Epoch 46/100
# 140/140 [==============================] - 10s 75ms/step - loss: 0.8188 - accuracy: 0.7714 - val_loss: 0.7853 - val_accuracy: 0.7812
#
# Epoch 00046: val_loss improved from 0.79732 to 0.78527, saving model to cnn_scene_RMSProp.h5
# Epoch 47/100
# 140/140 [==============================] - 11s 75ms/step - loss: 0.8232 - accuracy: 0.7638 - val_loss: 0.7846 - val_accuracy: 0.7819
#
# Epoch 00047: val_loss improved from 0.78527 to 0.78463, saving model to cnn_scene_RMSProp.h5
# Epoch 48/100
# 140/140 [==============================] - 11s 76ms/step - loss: 0.8127 - accuracy: 0.7764 - val_loss: 0.7849 - val_accuracy: 0.7805
#
# Epoch 00048: val_loss did not improve from 0.78463
# Epoch 49/100
# 140/140 [==============================] - 12s 88ms/step - loss: 0.8127 - accuracy: 0.7743 - val_loss: 0.7843 - val_accuracy: 0.7812
#
# Epoch 00049: val_loss improved from 0.78463 to 0.78427, saving model to cnn_scene_RMSProp.h5
# Epoch 50/100
# 140/140 [==============================] - 12s 83ms/step - loss: 0.8198 - accuracy: 0.7732 - val_loss: 0.7781 - val_accuracy: 0.7827
#
# Epoch 00050: val_loss improved from 0.78427 to 0.77807, saving model to cnn_scene_RMSProp.h5
# Epoch 51/100
# 140/140 [==============================] - 14s 100ms/step - loss: 0.8143 - accuracy: 0.7642 - val_loss: 0.7757 - val_accuracy: 0.7856
#
# Epoch 00051: val_loss improved from 0.77807 to 0.77566, saving model to cnn_scene_RMSProp.h5
# Epoch 52/100
# 140/140 [==============================] - 12s 87ms/step - loss: 0.8061 - accuracy: 0.7750 - val_loss: 0.7799 - val_accuracy: 0.7827
#
# Epoch 00052: val_loss did not improve from 0.77566
# Epoch 53/100
# 140/140 [==============================] - 10s 75ms/step - loss: 0.8297 - accuracy: 0.7627 - val_loss: 0.7766 - val_accuracy: 0.7790
#
# Epoch 00053: val_loss did not improve from 0.77566
# Epoch 54/100
# 140/140 [==============================] - 12s 86ms/step - loss: 0.8169 - accuracy: 0.7755 - val_loss: 0.7794 - val_accuracy: 0.7819
#
# Epoch 00054: val_loss did not improve from 0.77566
#
# Epoch 00054: ReduceLROnPlateau reducing learning rate to 6.400000529538374e-08.
# Epoch 55/100
# 140/140 [==============================] - 11s 80ms/step - loss: 0.7946 - accuracy: 0.7826 - val_loss: 0.7772 - val_accuracy: 0.7834
#
# Epoch 00055: val_loss did not improve from 0.77566
# Epoch 56/100
# 140/140 [==============================] - 13s 97ms/step - loss: 0.8182 - accuracy: 0.7728 - val_loss: 0.7770 - val_accuracy: 0.7812
#
# Epoch 00056: val_loss did not improve from 0.77566
# Epoch 57/100
# 140/140 [==============================] - 12s 82ms/step - loss: 0.8073 - accuracy: 0.7658 - val_loss: 0.7768 - val_accuracy: 0.7805
#
# Epoch 00057: val_loss did not improve from 0.77566
#
# Epoch 00057: ReduceLROnPlateau reducing learning rate to 1.2800001059076749e-08.
# Epoch 58/100
# 140/140 [==============================] - 13s 91ms/step - loss: 0.8091 - accuracy: 0.7790 - val_loss: 0.7764 - val_accuracy: 0.7805
#
# Epoch 00058: val_loss did not improve from 0.77566
# Epoch 59/100
# 140/140 [==============================] - 12s 84ms/step - loss: 0.8163 - accuracy: 0.7743 - val_loss: 0.7747 - val_accuracy: 0.7790
#
# Epoch 00059: val_loss improved from 0.77566 to 0.77465, saving model to cnn_scene_RMSProp.h5
# Epoch 60/100
# 140/140 [==============================] - 11s 76ms/step - loss: 0.8086 - accuracy: 0.7746 - val_loss: 0.7719 - val_accuracy: 0.7827
#
# Epoch 00060: val_loss improved from 0.77465 to 0.77188, saving model to cnn_scene_RMSProp.h5
# Epoch 61/100
# 140/140 [==============================] - 10s 75ms/step - loss: 0.8068 - accuracy: 0.7739 - val_loss: 0.7749 - val_accuracy: 0.7812
#
# Epoch 00061: val_loss did not improve from 0.77188
# Epoch 62/100
# 140/140 [==============================] - 10s 74ms/step - loss: 0.7964 - accuracy: 0.7779 - val_loss: 0.7747 - val_accuracy: 0.7819
#
# Epoch 00062: val_loss did not improve from 0.77188
# Epoch 63/100
# 140/140 [==============================] - 11s 77ms/step - loss: 0.7982 - accuracy: 0.7808 - val_loss: 0.7763 - val_accuracy: 0.7819
#
# Epoch 00063: val_loss did not improve from 0.77188
#
# Epoch 00063: ReduceLROnPlateau reducing learning rate to 2.5600002118153498e-09.
# Epoch 64/100
# 140/140 [==============================] - 15s 108ms/step - loss: 0.8065 - accuracy: 0.7734 - val_loss: 0.7737 - val_accuracy: 0.7819
#
# Epoch 00064: val_loss did not improve from 0.77188
# Epoch 65/100
# 140/140 [==============================] - 11s 76ms/step - loss: 0.8104 - accuracy: 0.7777 - val_loss: 0.7752 - val_accuracy: 0.7819
#
# Epoch 00065: val_loss did not improve from 0.77188
# Epoch 66/100
# 140/140 [==============================] - 13s 92ms/step - loss: 0.8030 - accuracy: 0.7761 - val_loss: 0.7736 - val_accuracy: 0.7819
#
# Epoch 00066: val_loss did not improve from 0.77188
#
# Epoch 00066: ReduceLROnPlateau reducing learning rate to 5.1200004236307e-10.
# Epoch 67/100
# 140/140 [==============================] - 12s 85ms/step - loss: 0.8203 - accuracy: 0.7681 - val_loss: 0.7745 - val_accuracy: 0.7812
#
# Epoch 00067: val_loss did not improve from 0.77188
# Epoch 68/100
# 140/140 [==============================] - 10s 75ms/step - loss: 0.8053 - accuracy: 0.7811 - val_loss: 0.7752 - val_accuracy: 0.7827
#
# Epoch 00068: val_loss did not improve from 0.77188
# Epoch 69/100
# 140/140 [==============================] - 10s 75ms/step - loss: 0.8099 - accuracy: 0.7759 - val_loss: 0.7732 - val_accuracy: 0.7827
#
# Epoch 00069: val_loss did not improve from 0.77188
#
# Epoch 00069: ReduceLROnPlateau reducing learning rate to 1.0240001069306004e-10.
# Epoch 70/100
# 140/140 [==============================] - 10s 75ms/step - loss: 0.8103 - accuracy: 0.7786 - val_loss: 0.7768 - val_accuracy: 0.7797
#
# Epoch 00070: val_loss did not improve from 0.77188
# Epoch 71/100
# 140/140 [==============================] - 11s 75ms/step - loss: 0.8106 - accuracy: 0.7716 - val_loss: 0.7756 - val_accuracy: 0.7827
#
# Epoch 00071: val_loss did not improve from 0.77188
# Epoch 72/100
# 140/140 [==============================] - 11s 76ms/step - loss: 0.8079 - accuracy: 0.7723 - val_loss: 0.7751 - val_accuracy: 0.7827
#
# Epoch 00072: val_loss did not improve from 0.77188
#
# Epoch 00072: ReduceLROnPlateau reducing learning rate to 2.0480002416167767e-11.
# Epoch 73/100
# 140/140 [==============================] - 11s 75ms/step - loss: 0.7913 - accuracy: 0.7820 - val_loss: 0.7716 - val_accuracy: 0.7819
#
# Epoch 00073: val_loss improved from 0.77188 to 0.77161, saving model to cnn_scene_RMSProp.h5
# Epoch 74/100
# 140/140 [==============================] - 11s 82ms/step - loss: 0.8055 - accuracy: 0.7826 - val_loss: 0.7739 - val_accuracy: 0.7827
#
# Epoch 00074: val_loss did not improve from 0.77161
# Epoch 75/100
# 140/140 [==============================] - 11s 76ms/step - loss: 0.8083 - accuracy: 0.7714 - val_loss: 0.7709 - val_accuracy: 0.7849
#
# Epoch 00075: val_loss improved from 0.77161 to 0.77091, saving model to cnn_scene_RMSProp.h5
# Epoch 76/100
# 140/140 [==============================] - 11s 75ms/step - loss: 0.8021 - accuracy: 0.7759 - val_loss: 0.7716 - val_accuracy: 0.7819
#
# Epoch 00076: val_loss did not improve from 0.77091
# Epoch 77/100
# 140/140 [==============================] - 11s 75ms/step - loss: 0.8148 - accuracy: 0.7725 - val_loss: 0.7723 - val_accuracy: 0.7827
#
# Epoch 00077: val_loss did not improve from 0.77091
# Epoch 78/100
# 140/140 [==============================] - 11s 76ms/step - loss: 0.8039 - accuracy: 0.7786 - val_loss: 0.7753 - val_accuracy: 0.7819
#
# Epoch 00078: val_loss did not improve from 0.77091
#
# Epoch 00078: ReduceLROnPlateau reducing learning rate to 4.096000622011431e-12.
# Epoch 79/100
# 140/140 [==============================] - 11s 77ms/step - loss: 0.8094 - accuracy: 0.7732 - val_loss: 0.7738 - val_accuracy: 0.7834
#
# Epoch 00079: val_loss did not improve from 0.77091
# Epoch 80/100
# 140/140 [==============================] - 11s 76ms/step - loss: 0.8079 - accuracy: 0.7721 - val_loss: 0.7761 - val_accuracy: 0.7819
#
# Epoch 00080: val_loss did not improve from 0.77091
# Epoch 81/100
# 140/140 [==============================] - 11s 76ms/step - loss: 0.8096 - accuracy: 0.7811 - val_loss: 0.7743 - val_accuracy: 0.7812
#
# Epoch 00081: val_loss did not improve from 0.77091
#
# Epoch 00081: ReduceLROnPlateau reducing learning rate to 8.192000897078167e-13.
# Epoch 82/100
# 140/140 [==============================] - 11s 76ms/step - loss: 0.8088 - accuracy: 0.7759 - val_loss: 0.7709 - val_accuracy: 0.7841
#
# Epoch 00082: val_loss did not improve from 0.77091
# Epoch 83/100
# 140/140 [==============================] - 12s 87ms/step - loss: 0.8062 - accuracy: 0.7768 - val_loss: 0.7726 - val_accuracy: 0.7841
#
# Epoch 00083: val_loss did not improve from 0.77091
# Epoch 84/100
# 140/140 [==============================] - 10s 74ms/step - loss: 0.8163 - accuracy: 0.7674 - val_loss: 0.7719 - val_accuracy: 0.7834
#
# Epoch 00084: val_loss did not improve from 0.77091
#
# Epoch 00084: ReduceLROnPlateau reducing learning rate to 1.6384001360475466e-13.
# Epoch 85/100
# 140/140 [==============================] - 11s 77ms/step - loss: 0.8244 - accuracy: 0.7593 - val_loss: 0.7747 - val_accuracy: 0.7805
#
# Epoch 00085: val_loss did not improve from 0.77091
# Epoch 86/100
# 140/140 [==============================] - 10s 75ms/step - loss: 0.7974 - accuracy: 0.7757 - val_loss: 0.7732 - val_accuracy: 0.7827
#
# Epoch 00086: val_loss did not improve from 0.77091
# Epoch 87/100
# 140/140 [==============================] - 11s 75ms/step - loss: 0.8113 - accuracy: 0.7707 - val_loss: 0.7731 - val_accuracy: 0.7819
#
# Epoch 00087: val_loss did not improve from 0.77091
#
# Epoch 00087: ReduceLROnPlateau reducing learning rate to 3.2768002178849846e-14.
# Epoch 88/100
# 140/140 [==============================] - 12s 86ms/step - loss: 0.8140 - accuracy: 0.7692 - val_loss: 0.7729 - val_accuracy: 0.7812
#
# Epoch 00088: val_loss did not improve from 0.77091
# Epoch 89/100
# 140/140 [==============================] - 12s 88ms/step - loss: 0.8104 - accuracy: 0.7699 - val_loss: 0.7748 - val_accuracy: 0.7819
#
# Epoch 00089: val_loss did not improve from 0.77091
# Epoch 90/100
# 140/140 [==============================] - 11s 78ms/step - loss: 0.8126 - accuracy: 0.7719 - val_loss: 0.7742 - val_accuracy: 0.7841
#
# Epoch 00090: val_loss did not improve from 0.77091
#
# Epoch 00090: ReduceLROnPlateau reducing learning rate to 6.553600300244697e-15.
# Epoch 91/100
# 140/140 [==============================] - 11s 77ms/step - loss: 0.8167 - accuracy: 0.7716 - val_loss: 0.7733 - val_accuracy: 0.7841
#
# Epoch 00091: val_loss did not improve from 0.77091
# Epoch 92/100
# 140/140 [==============================] - 11s 75ms/step - loss: 0.8153 - accuracy: 0.7734 - val_loss: 0.7767 - val_accuracy: 0.7812
#
# Epoch 00092: val_loss did not improve from 0.77091
# Epoch 93/100
# 140/140 [==============================] - 11s 76ms/step - loss: 0.8046 - accuracy: 0.7759 - val_loss: 0.7756 - val_accuracy: 0.7827
#
# Epoch 00093: val_loss did not improve from 0.77091
#
# Epoch 00093: ReduceLROnPlateau reducing learning rate to 1.3107200431082805e-15.
# Epoch 94/100
# 140/140 [==============================] - 11s 76ms/step - loss: 0.8184 - accuracy: 0.7723 - val_loss: 0.7755 - val_accuracy: 0.7827
#
# Epoch 00094: val_loss did not improve from 0.77091
# Epoch 95/100
# 140/140 [==============================] - 11s 77ms/step - loss: 0.8071 - accuracy: 0.7737 - val_loss: 0.7746 - val_accuracy: 0.7827
#
# Epoch 00095: val_loss did not improve from 0.77091
# Epoch 96/100
# 140/140 [==============================] - 11s 76ms/step - loss: 0.8077 - accuracy: 0.7734 - val_loss: 0.7745 - val_accuracy: 0.7827
#
# Epoch 00096: val_loss did not improve from 0.77091
#
# Epoch 00096: ReduceLROnPlateau reducing learning rate to 2.6214401285682084e-16.
# Epoch 97/100
# 140/140 [==============================] - 11s 75ms/step - loss: 0.8181 - accuracy: 0.7705 - val_loss: 0.7733 - val_accuracy: 0.7819
#
# Epoch 00097: val_loss did not improve from 0.77091
# Epoch 98/100
# 140/140 [==============================] - 10s 75ms/step - loss: 0.8059 - accuracy: 0.7786 - val_loss: 0.7747 - val_accuracy: 0.7827
#
# Epoch 00098: val_loss did not improve from 0.77091
# Epoch 99/100
# 140/140 [==============================] - 11s 76ms/step - loss: 0.8169 - accuracy: 0.7678 - val_loss: 0.7742 - val_accuracy: 0.7812
#
# Epoch 00099: val_loss did not improve from 0.77091
#
# Epoch 00099: ReduceLROnPlateau reducing learning rate to 5.2428803630155353e-17.
# Epoch 100/100
# 140/140 [==============================] - 11s 76ms/step - loss: 0.8096 - accuracy: 0.7737 - val_loss: 0.7746 - val_accuracy: 0.7834
#
# Epoch 00100: val_loss did not improve from 0.77091

# %%
print(history.history.keys())
# Plotting our loss charts
import matplotlib.pyplot as plt

history_dict = history.history
loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']
epochs = range(1, len(loss_values) + 1)

line1 = plt.plot(epochs, val_loss_values, label='Validation/Test Loss')
line2 = plt.plot(epochs, loss_values, label='Training Loss')
plt.setp(line1, linewidth=2.0, marker = '+', markersize=10.0)
plt.setp(line2, linewidth=2.0, marker = '4', markersize=10.0)
plt.xlabel('Epochs') 
plt.ylabel('Loss')
plt.grid(True)
plt.legend()
plt.savefig('Loss.png', dpi = 1200)
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])

# %%
# Plotting our accuracy charts
import matplotlib.pyplot as plt

history_dict = history.history
acc_values = history_dict['accuracy']
val_acc_values = history_dict['val_accuracy']
epochs = range(1, len(loss_values) + 1)
line1 = plt.plot(epochs, val_acc_values, label='Validation/Test Accuracy')
line2 = plt.plot(epochs, acc_values, label='Training Accuracy')
plt.setp(line1, linewidth=2.0, marker = '+', markersize=10.0)
plt.setp(line2, linewidth=2.0, marker = '4', markersize=10.0)
plt.xlabel('Epochs') 
plt.ylabel('Accuracy')
plt.grid(True)
plt.legend()
plt.savefig('Accuracy.png', dpi = 1200)
plt.show()

# %%
elapsed_time
# Out:
# 1172.713862298

# %% [markdown]
# Evaluation model 3

# %%
import seaborn as sr
import pandas as pd

y_pred=np.argmax(model.predict(validation_generator), axis=1)
y_test=validation_generator.classes


# y_predict,distances1=  face_recognition(x_test_recog,T_distance)
# accuracy=accuracy_score(y_test_recog,y_predict)
class_names=["Bedroom","Building","Store","Industry","Living room","Kitchen","Highway",'Coast',
             "Office","Mountain","Inside city","Forest","Surbub","Street","Opencountry"]
report=classification_report(y_test,y_pred,target_names=class_names)

conf=confusion_matrix(y_test,y_pred,normalize="true")
conf_df=pd.DataFrame(conf, index=class_names, columns=class_names)
# print("\nFace  accuracy =",accuracy)
print("\n Classification report: \n",report)
fig=plt.figure(figsize=(15,10))
sr.heatmap(conf_df,annot=True,cmap="Blues")
plt.title("Confusion matrix")
plt.show()
# Out:
#  Classification report:
#                precision    recall  f1-score   support
#
#      Bedroom       0.84      0.52      0.64       114
#     Building       0.96      0.95      0.96       111
#        Store       0.89      0.45      0.60       121
#     Industry       0.75      0.70      0.72       122
#  Living room       0.60      0.71      0.65       125
#      Kitchen       0.79      0.86      0.82        77
#      Highway       0.82      0.97      0.89        75
#        Coast       0.88      0.79      0.84        77
#       Office       0.74      0.87      0.80        79
#     Mountain       0.83      0.82      0.83        79
#  Inside city       0.73      0.79      0.76        77
#       Forest       0.91      0.95      0.93        79
#       Surbub       0.66      0.97      0.78        78
#       Street       0.78      0.89      0.83        76
#  Opencountry       0.77      0.82      0.79        72
#
#     accuracy                           0.78      1362
#    macro avg       0.80      0.81      0.79      1362
# weighted avg       0.80      0.78      0.78      1362

# %%
len(validation_generator.classes)
# Out:
# 1362

# %% [markdown]
# # Download the pretrained weights of ResNet32 or 50 model on ImageNet dataset, use the pretrained weights and fine-tune the model. Please provide the testing results for the experiment of 1 and 2. Ref. code: Lecture_10_TL_X. ipynb

# %%
import matplotlib.pyplot as plt
import numpy as np

from sklearn.ensemble import VotingClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from keras.datasets import mnist
from keras.wrappers.scikit_learn import KerasClassifier
from keras.datasets import mnist
from keras.models import Sequential
from keras.utils.np_utils import to_categorical
from keras.models import Sequential
from keras.layers import Activation, Dense, BatchNormalization, Dropout
from keras import optimizers



from tensorflow.keras.applications import ResNet50

image_size = 224
#Load the VGG model
resnet = ResNet50(weights='imagenet', include_top=False, input_shape=(image_size, image_size, 3))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94773248/94765736 [==============================] - 1s 0us/step
# 94781440/94765736 [==============================] - 1s 0us/step

# %%
resnet.summary()
# Out:
# Model: "resnet50"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 230, 230, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 112, 112, 64) 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, 112, 112, 64) 256         conv1_conv[0][0]
# __________________________________________________________________________________________________
# conv1_relu (Activation)         (None, 112, 112, 64) 0           conv1_bn[0][0]
# __________________________________________________________________________________________________
# pool1_pad (ZeroPadding2D)       (None, 114, 114, 64) 0           conv1_relu[0][0]
# __________________________________________________________________________________________________
# pool1_pool (MaxPooling2D)       (None, 56, 56, 64)   0           pool1_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_conv (Conv2D)    (None, 56, 56, 64)   4160        pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_relu (Activation (None, 56, 56, 64)   0           conv2_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_conv (Conv2D)    (None, 56, 56, 64)   36928       conv2_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_relu (Activation (None, 56, 56, 64)   0           conv2_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_conv (Conv2D)    (None, 56, 56, 256)  16640       pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_conv (Conv2D)    (None, 56, 56, 256)  16640       conv2_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_bn (BatchNormali (None, 56, 56, 256)  1024        conv2_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_bn (BatchNormali (None, 56, 56, 256)  1024        conv2_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_add (Add)          (None, 56, 56, 256)  0           conv2_block1_0_bn[0][0]
#                                                                  conv2_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_out (Activation)   (None, 56, 56, 256)  0           conv2_block1_add[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_conv (Conv2D)    (None, 56, 56, 64)   16448       conv2_block1_out[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_relu (Activation (None, 56, 56, 64)   0           conv2_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_conv (Conv2D)    (None, 56, 56, 64)   36928       conv2_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_relu (Activation (None, 56, 56, 64)   0           conv2_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_conv (Conv2D)    (None, 56, 56, 256)  16640       conv2_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_bn (BatchNormali (None, 56, 56, 256)  1024        conv2_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_add (Add)          (None, 56, 56, 256)  0           conv2_block1_out[0][0]
#                                                                  conv2_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_out (Activation)   (None, 56, 56, 256)  0           conv2_block2_add[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_conv (Conv2D)    (None, 56, 56, 64)   16448       conv2_block2_out[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_relu (Activation (None, 56, 56, 64)   0           conv2_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_conv (Conv2D)    (None, 56, 56, 64)   36928       conv2_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_relu (Activation (None, 56, 56, 64)   0           conv2_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_conv (Conv2D)    (None, 56, 56, 256)  16640       conv2_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_bn (BatchNormali (None, 56, 56, 256)  1024        conv2_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_add (Add)          (None, 56, 56, 256)  0           conv2_block2_out[0][0]
#                                                                  conv2_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_out (Activation)   (None, 56, 56, 256)  0           conv2_block3_add[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_conv (Conv2D)    (None, 28, 28, 128)  32896       conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_relu (Activation (None, 28, 28, 128)  0           conv3_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_conv (Conv2D)    (None, 28, 28, 128)  147584      conv3_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_relu (Activation (None, 28, 28, 128)  0           conv3_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_conv (Conv2D)    (None, 28, 28, 512)  131584      conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_add (Add)          (None, 28, 28, 512)  0           conv3_block1_0_bn[0][0]
#                                                                  conv3_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_out (Activation)   (None, 28, 28, 512)  0           conv3_block1_add[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_conv (Conv2D)    (None, 28, 28, 128)  65664       conv3_block1_out[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_relu (Activation (None, 28, 28, 128)  0           conv3_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_conv (Conv2D)    (None, 28, 28, 128)  147584      conv3_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_relu (Activation (None, 28, 28, 128)  0           conv3_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_add (Add)          (None, 28, 28, 512)  0           conv3_block1_out[0][0]
#                                                                  conv3_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_out (Activation)   (None, 28, 28, 512)  0           conv3_block2_add[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_conv (Conv2D)    (None, 28, 28, 128)  65664       conv3_block2_out[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_relu (Activation (None, 28, 28, 128)  0           conv3_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_conv (Conv2D)    (None, 28, 28, 128)  147584      conv3_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_relu (Activation (None, 28, 28, 128)  0           conv3_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_add (Add)          (None, 28, 28, 512)  0           conv3_block2_out[0][0]
#                                                                  conv3_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_out (Activation)   (None, 28, 28, 512)  0           conv3_block3_add[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_conv (Conv2D)    (None, 28, 28, 128)  65664       conv3_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_relu (Activation (None, 28, 28, 128)  0           conv3_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_conv (Conv2D)    (None, 28, 28, 128)  147584      conv3_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_relu (Activation (None, 28, 28, 128)  0           conv3_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_add (Add)          (None, 28, 28, 512)  0           conv3_block3_out[0][0]
#                                                                  conv3_block4_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_out (Activation)   (None, 28, 28, 512)  0           conv3_block4_add[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_conv (Conv2D)    (None, 14, 14, 256)  131328      conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_relu (Activation (None, 14, 14, 256)  0           conv4_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_relu (Activation (None, 14, 14, 256)  0           conv4_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_conv (Conv2D)    (None, 14, 14, 1024) 525312      conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_add (Add)          (None, 14, 14, 1024) 0           conv4_block1_0_bn[0][0]
#                                                                  conv4_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_out (Activation)   (None, 14, 14, 1024) 0           conv4_block1_add[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block1_out[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_relu (Activation (None, 14, 14, 256)  0           conv4_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_relu (Activation (None, 14, 14, 256)  0           conv4_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_add (Add)          (None, 14, 14, 1024) 0           conv4_block1_out[0][0]
#                                                                  conv4_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_out (Activation)   (None, 14, 14, 1024) 0           conv4_block2_add[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block2_out[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_relu (Activation (None, 14, 14, 256)  0           conv4_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_relu (Activation (None, 14, 14, 256)  0           conv4_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_add (Add)          (None, 14, 14, 1024) 0           conv4_block2_out[0][0]
#                                                                  conv4_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_out (Activation)   (None, 14, 14, 1024) 0           conv4_block3_add[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block3_out[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_relu (Activation (None, 14, 14, 256)  0           conv4_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_relu (Activation (None, 14, 14, 256)  0           conv4_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_add (Add)          (None, 14, 14, 1024) 0           conv4_block3_out[0][0]
#                                                                  conv4_block4_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_out (Activation)   (None, 14, 14, 1024) 0           conv4_block4_add[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_relu (Activation (None, 14, 14, 256)  0           conv4_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_relu (Activation (None, 14, 14, 256)  0           conv4_block5_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block5_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block5_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_add (Add)          (None, 14, 14, 1024) 0           conv4_block4_out[0][0]
#                                                                  conv4_block5_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_out (Activation)   (None, 14, 14, 1024) 0           conv4_block5_add[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block5_out[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_relu (Activation (None, 14, 14, 256)  0           conv4_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_relu (Activation (None, 14, 14, 256)  0           conv4_block6_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block6_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block6_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_add (Add)          (None, 14, 14, 1024) 0           conv4_block5_out[0][0]
#                                                                  conv4_block6_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_out (Activation)   (None, 14, 14, 1024) 0           conv4_block6_add[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_conv (Conv2D)    (None, 7, 7, 512)    524800      conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_relu (Activation (None, 7, 7, 512)    0           conv5_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_conv (Conv2D)    (None, 7, 7, 512)    2359808     conv5_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_relu (Activation (None, 7, 7, 512)    0           conv5_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_conv (Conv2D)    (None, 7, 7, 2048)   2099200     conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_conv (Conv2D)    (None, 7, 7, 2048)   1050624     conv5_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_bn (BatchNormali (None, 7, 7, 2048)   8192        conv5_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_bn (BatchNormali (None, 7, 7, 2048)   8192        conv5_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_add (Add)          (None, 7, 7, 2048)   0           conv5_block1_0_bn[0][0]
#                                                                  conv5_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_out (Activation)   (None, 7, 7, 2048)   0           conv5_block1_add[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_conv (Conv2D)    (None, 7, 7, 512)    1049088     conv5_block1_out[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_relu (Activation (None, 7, 7, 512)    0           conv5_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_conv (Conv2D)    (None, 7, 7, 512)    2359808     conv5_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_relu (Activation (None, 7, 7, 512)    0           conv5_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_conv (Conv2D)    (None, 7, 7, 2048)   1050624     conv5_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_bn (BatchNormali (None, 7, 7, 2048)   8192        conv5_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_add (Add)          (None, 7, 7, 2048)   0           conv5_block1_out[0][0]
#                                                                  conv5_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_out (Activation)   (None, 7, 7, 2048)   0           conv5_block2_add[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_conv (Conv2D)    (None, 7, 7, 512)    1049088     conv5_block2_out[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_relu (Activation (None, 7, 7, 512)    0           conv5_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_conv (Conv2D)    (None, 7, 7, 512)    2359808     conv5_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_relu (Activation (None, 7, 7, 512)    0           conv5_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_conv (Conv2D)    (None, 7, 7, 2048)   1050624     conv5_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_bn (BatchNormali (None, 7, 7, 2048)   8192        conv5_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_add (Add)          (None, 7, 7, 2048)   0           conv5_block2_out[0][0]
#                                                                  conv5_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_out (Activation)   (None, 7, 7, 2048)   0           conv5_block3_add[0][0]
# ==================================================================================================
# Total params: 23,587,712
# Trainable params: 23,534,592
# Non-trainable params: 53,120
# __________________________________________________________________________________________________

# %% [markdown]
# # Freeze the required layers

# %%
# Freeze the layers except the last 4 layers
for layer in resnet.layers[:-4]:
    layer.trainable = False
 
# Check the trainable status of the individual layers
for layer in resnet.layers:
    print(layer, layer.trainable)
# Out:
# <keras.engine.input_layer.InputLayer object at 0x7f68736c22d0> False
# <keras.layers.convolutional.ZeroPadding2D object at 0x7f68704e89d0> False
# <keras.layers.convolutional.Conv2D object at 0x7f68733118d0> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f68704cd350> False
# <keras.layers.core.Activation object at 0x7f687046d290> False
# <keras.layers.convolutional.ZeroPadding2D object at 0x7f6870470a10> False
# <keras.layers.pooling.MaxPooling2D object at 0x7f6870477f90> False
# <keras.layers.convolutional.Conv2D object at 0x7f6870487190> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f6870481490> False
# <keras.layers.core.Activation object at 0x7f687047cfd0> False
# <keras.layers.convolutional.Conv2D object at 0x7f6870492290> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f68704d7250> False
# <keras.layers.core.Activation object at 0x7f687049d590> False
# <keras.layers.convolutional.Conv2D object at 0x7f68704e8f10> False
# <keras.layers.convolutional.Conv2D object at 0x7f68704a2650> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f687047c350> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f6870481d90> False
# <keras.layers.merge.Add object at 0x7f68736dde50> False
# <keras.layers.core.Activation object at 0x7f68704964d0> False
# <keras.layers.convolutional.Conv2D object at 0x7f687049e890> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f687043cb90> False
# <keras.layers.core.Activation object at 0x7f6870496490> False
# <keras.layers.convolutional.Conv2D object at 0x7f687043d550> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f6870443090> False
# <keras.layers.core.Activation object at 0x7f68739eec90> False
# <keras.layers.convolutional.Conv2D object at 0x7f687049eed0> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f6870456790> False
# <keras.layers.merge.Add object at 0x7f6870444850> False
# <keras.layers.core.Activation object at 0x7f687045f910> False
# <keras.layers.convolutional.Conv2D object at 0x7f6873427790> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f68703eded0> False
# <keras.layers.core.Activation object at 0x7f6870460c90> False
# <keras.layers.convolutional.Conv2D object at 0x7f68703f09d0> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f68704bd650> False
# <keras.layers.core.Activation object at 0x7f68703fa110> False
# <keras.layers.convolutional.Conv2D object at 0x7f68703ffcd0> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f6870418450> False
# <keras.layers.merge.Add object at 0x7f687040dad0> False
# <keras.layers.core.Activation object at 0x7f68736e80d0> False
# <keras.layers.convolutional.Conv2D object at 0x7f687040dd90> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f68703ff990> False
# <keras.layers.core.Activation object at 0x7f6870456950> False
# <keras.layers.convolutional.Conv2D object at 0x7f68704b8150> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f68704a7110> False
# <keras.layers.core.Activation object at 0x7f6870477b90> False
# <keras.layers.convolutional.Conv2D object at 0x7f6870424810> False
# <keras.layers.convolutional.Conv2D object at 0x7f687046dc90> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f6870424bd0> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f6870407190> False
# <keras.layers.merge.Add object at 0x7f687041d290> False
# <keras.layers.core.Activation object at 0x7f68704bdf50> False
# <keras.layers.convolutional.Conv2D object at 0x7f68703b3c90> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f68703b7f10> False
# <keras.layers.core.Activation object at 0x7f68703bf3d0> False
# <keras.layers.convolutional.Conv2D object at 0x7f68703ba710> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f68703c7390> False
# <keras.layers.core.Activation object at 0x7f68703cf190> False
# <keras.layers.convolutional.Conv2D object at 0x7f68703cfad0> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f68703d5fd0> False
# <keras.layers.merge.Add object at 0x7f68703df110> False
# <keras.layers.core.Activation object at 0x7f68703df6d0> False
# <keras.layers.convolutional.Conv2D object at 0x7f6873311bd0> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f6870371d50> False
# <keras.layers.core.Activation object at 0x7f687037b190> False
# <keras.layers.convolutional.Conv2D object at 0x7f68703df790> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f6870386210> False
# <keras.layers.core.Activation object at 0x7f6870389050> False
# <keras.layers.convolutional.Conv2D object at 0x7f68703898d0> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f6870395e10> False
# <keras.layers.merge.Add object at 0x7f68703a10d0> False
# <keras.layers.core.Activation object at 0x7f68703a1150> False
# <keras.layers.convolutional.Conv2D object at 0x7f68703a6450> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f6870332bd0> False
# <keras.layers.core.Activation object at 0x7f6870338310> False
# <keras.layers.convolutional.Conv2D object at 0x7f6870338890> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f6870343090> False
# <keras.layers.core.Activation object at 0x7f687034c190> False
# <keras.layers.convolutional.Conv2D object at 0x7f6870332810> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f6870351cd0> False
# <keras.layers.merge.Add object at 0x7f6870363bd0> False
# <keras.layers.core.Activation object at 0x7f6870363ed0> False
# <keras.layers.convolutional.Conv2D object at 0x7f687039e090> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f6870392a90> False
# <keras.layers.core.Activation object at 0x7f687037f810> False
# <keras.layers.convolutional.Conv2D object at 0x7f68703df090> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f687036bad0> False
# <keras.layers.core.Activation object at 0x7f68703cfd10> False
# <keras.layers.convolutional.Conv2D object at 0x7f687035d7d0> False
# <keras.layers.convolutional.Conv2D object at 0x7f68703c4fd0> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f6870334910> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f68704d7690> False
# <keras.layers.merge.Add object at 0x7f687036be90> False
# <keras.layers.core.Activation object at 0x7f6873427750> False
# <keras.layers.convolutional.Conv2D object at 0x7f68703650d0> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f6870492bd0> False
# <keras.layers.core.Activation object at 0x7f6870386810> False
# <keras.layers.convolutional.Conv2D object at 0x7f6870384390> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f68703857d0> False
# <keras.layers.core.Activation object at 0x7f6870384710> False
# <keras.layers.convolutional.Conv2D object at 0x7f68703e0f50> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f6870365390> False
# <keras.layers.merge.Add object at 0x7f68702f5790> False
# <keras.layers.core.Activation object at 0x7f68702f2950> False
# <keras.layers.convolutional.Conv2D object at 0x7f6870309450> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f6870309650> False
# <keras.layers.core.Activation object at 0x7f68702f0410> False
# <keras.layers.convolutional.Conv2D object at 0x7f68702f2c90> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f687031b550> False
# <keras.layers.core.Activation object at 0x7f68703144d0> False
# <keras.layers.convolutional.Conv2D object at 0x7f6870321850> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f686d858110> False
# <keras.layers.merge.Add object at 0x7f6870321090> False
# <keras.layers.core.Activation object at 0x7f6870325550> False
# <keras.layers.convolutional.Conv2D object at 0x7f686d8650d0> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f686d865550> False
# <keras.layers.core.Activation object at 0x7f686d85be10> False
# <keras.layers.convolutional.Conv2D object at 0x7f6870325790> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f686d87b210> False
# <keras.layers.core.Activation object at 0x7f686d860990> False
# <keras.layers.convolutional.Conv2D object at 0x7f686d870ad0> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f686d888850> False
# <keras.layers.merge.Add object at 0x7f686d880ad0> False
# <keras.layers.core.Activation object at 0x7f686d881c50> False
# <keras.layers.convolutional.Conv2D object at 0x7f6870325210> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f6870314ad0> False
# <keras.layers.core.Activation object at 0x7f686d860810> False
# <keras.layers.convolutional.Conv2D object at 0x7f686d87b990> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f68704d7350> False
# <keras.layers.core.Activation object at 0x7f6870309550> False
# <keras.layers.convolutional.Conv2D object at 0x7f68703cb850> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f686d814390> False
# <keras.layers.merge.Add object at 0x7f6870351750> False
# <keras.layers.core.Activation object at 0x7f687034c590> False
# <keras.layers.convolutional.Conv2D object at 0x7f686d81b8d0> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f686d820b50> False
# <keras.layers.core.Activation object at 0x7f686d818c50> False
# <keras.layers.convolutional.Conv2D object at 0x7f686d825710> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f686d82aa10> False
# <keras.layers.core.Activation object at 0x7f686d827090> False
# <keras.layers.convolutional.Conv2D object at 0x7f686d825c10> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f686d840090> False
# <keras.layers.merge.Add object at 0x7f686d81bc50> False
# <keras.layers.core.Activation object at 0x7f686d837a50> False
# <keras.layers.convolutional.Conv2D object at 0x7f686d8497d0> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f686d7da890> False
# <keras.layers.core.Activation object at 0x7f686d7e3710> False
# <keras.layers.convolutional.Conv2D object at 0x7f686d7dc7d0> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f686d7ea850> False
# <keras.layers.core.Activation object at 0x7f686d7f8610> False
# <keras.layers.convolutional.Conv2D object at 0x7f686d84e5d0> False
# <keras.layers.convolutional.Conv2D object at 0x7f686d7e3550> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f686d84e290> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f686d7f2e50> False
# <keras.layers.merge.Add object at 0x7f686d807850> False
# <keras.layers.core.Activation object at 0x7f686d808550> False
# <keras.layers.convolutional.Conv2D object at 0x7f686d799e50> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f686d79d050> False
# <keras.layers.core.Activation object at 0x7f686d803910> False
# <keras.layers.convolutional.Conv2D object at 0x7f686d7a2650> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f686d7b03d0> False
# <keras.layers.core.Activation object at 0x7f686d79d8d0> False
# <keras.layers.convolutional.Conv2D object at 0x7f686d795410> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f686d7eac10> False
# <keras.layers.merge.Add object at 0x7f686d7f2e90> False
# <keras.layers.core.Activation object at 0x7f686d807d10> False
# <keras.layers.convolutional.Conv2D object at 0x7f686d7e3c50> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f686d832690> False
# <keras.layers.core.Activation object at 0x7f686d795950> False
# <keras.layers.convolutional.Conv2D object at 0x7f686d849750> False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f687034af50> False
# <keras.layers.core.Activation object at 0x7f686d814750> False
# <keras.layers.convolutional.Conv2D object at 0x7f687039e790> True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f686d7bd550> True
# <keras.layers.merge.Add object at 0x7f686d7b85d0> True
# <keras.layers.core.Activation object at 0x7f686d7b9ed0> True

# %% [markdown]
# # Create model

# %%
from keras import models
from keras import layers
from keras import optimizers
 
# Create the model
model = models.Sequential()
 
# Add the vgg convolutional base model
model.add(resnet)
 
# Add new layers
model.add(layers.Flatten())
model.add(layers.Dense(1024, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(200, activation='softmax'))
 
# Show a summary of the model. Check the number of trainable parameters
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50 (Functional)        (None, 7, 7, 2048)        23587712
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 100352)            0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1024)              102761472
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 200)               205000
# =================================================================
# Total params: 126,554,184
# Trainable params: 104,021,192
# Non-trainable params: 22,532,992
# _________________________________________________________________

# %% [markdown]
# # Load data

# %%
 train_dir="/content/drive/MyDrive/2021 Spring Courses/train_validation/train"
 validation_dir= "/content/drive/MyDrive/2021 Spring Courses/train_validation/validation"

# %%
train_datagen = ImageDataGenerator(
      rescale=1./255,
      rotation_range=20,
      width_shift_range=0.2,
      height_shift_range=0.2,
      horizontal_flip=True,
      fill_mode='nearest')
 
validation_datagen = ImageDataGenerator(rescale=1./255)

 
# Change the batchsize according to your system RAM
train_batchsize = 100
val_batchsize = 10
 
train_generator = train_datagen.flow_from_directory(
        train_dir,
        target_size=(image_size, image_size),
        batch_size=train_batchsize,
        class_mode='categorical')
 
validation_generator = validation_datagen.flow_from_directory(
        validation_dir,
        target_size=(image_size, image_size),
        batch_size=val_batchsize,
        class_mode='categorical',
        shuffle=False)
# Out:
# Found 4458 images belonging to 15 classes.
# Found 1362 images belonging to 15 classes.

# %%
# Compile the model
model.compile(loss='categorical_crossentropy',
              optimizer=optimizers.Adam(lr=1e-4),
              metrics=['acc'])
# Train the model
history = model.fit_generator(
      train_generator,
      steps_per_epoch=train_generator.samples/train_generator.batch_size ,
      epochs=30,
      validation_data=validation_generator,
      validation_steps=validation_generator.samples/validation_generator.batch_size,
      verbose=1)
 
# Save the model
model.save('small_last4.h5')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-42-f383559e3fb0> in <module>()
#       1 # Compile the model
#       2 model.compile(loss='categorical_crossentropy',
# ----> 3               optimizer=optimizers.Adam(lr=1e-4),
#       4               metrics=['acc'])
#       5 # Train the model
#
# AttributeError: module 'keras.optimizers' has no attribute 'Adam'

# %%
resnet = history.history['resnet']
resnet = history.history['resnet']
loss = history.history['loss']
val_loss = history.history['val_loss']
 
epochs = range(len(resnet))
 
plt.plot(epochs, resnet, 'b', label='Training resnet')
plt.plot(epochs, resnet, 'r', label='Validation resnet')
plt.title('Training and validation accuracy')
plt.legend()
 
plt.figure()
 
plt.plot(epochs, loss, 'b', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
 
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-43-a0d30983e1e1> in <module>()
#       1
# ----> 2 resnet = history.history['resnet']
#       3 resnet = history.history['resnet']
#       4 loss = history.history['loss']
#       5 val_loss = history.history['val_loss']
#
# KeyError: 'resnet'

# %% [markdown]
# # Lecture_10_TL2.ipynb

# %%
# !wget https://upload.wikimedia.org/wikipedia/commons/f/f9/Zoorashia_elephant.jpg -O elephant.jpg
# Out:
# --2021-10-12 00:03:18--  https://upload.wikimedia.org/wikipedia/commons/f/f9/Zoorashia_elephant.jpg
# Resolving upload.wikimedia.org (upload.wikimedia.org)... 208.80.154.240, 2620:0:861:ed1a::2:b
# Connecting to upload.wikimedia.org (upload.wikimedia.org)|208.80.154.240|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 168370 (164K) [image/jpeg]
# Saving to: ‘elephant.jpg’
#
# elephant.jpg        100%[===================>] 164.42K  --.-KB/s    in 0.04s
#
# 2021-10-12 00:03:18 (4.07 MB/s) - ‘elephant.jpg’ saved [168370/168370]

# %%
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions
import numpy as np

model = ResNet50(weights='imagenet')

img_path = 'elephant.jpg'
img = image.load_img(img_path, target_size=(224, 224))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

preds = model.predict(x)
# decode the results into a list of tuples (class, description, probability)
# (one such list for each sample in the batch)
print('Predicted:', decode_predictions(preds, top=3)[0])
# Predicted: [(u'n02504013', u'Indian_elephant', 0.82658225), (u'n01871265', u'tusker
# Out:
# Downloading data from https://storage.googleapis.com/download.tensorflow.org/data/imagenet_class_index.json
# 40960/35363 [==================================] - 0s 0us/step
# 49152/35363 [=========================================] - 0s 0us/step
# Predicted: [('n02504013', 'Indian_elephant', 0.81985754), ('n02504458', 'African_elephant', 0.11778772), ('n01871265', 'tusker', 0.05829764)]

# %% [markdown]
# # Extract features with resnet

# %%
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import preprocess_input
import numpy as np

model = ResNet50(weights='imagenet', include_top=False)

#base_model = resnet(weights='imagenet', include_top=False)

img_path = 'elephant.jpg'
img = image.load_img(img_path, target_size=(224, 224))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

features = model.predict(x)
print('The shape of the feature representation is : ', features.shape)
# Out:
# The shape of the feature representation is :  (1, 7, 7, 2048)

# %% [markdown]
# # Fine-tune resnet50 on a new set of classes

# %%
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D

# create the base pre-trained model
base_model = ResNet50(weights='imagenet', include_top=False)

# add a global spatial average pooling layer
x = base_model.output
x = GlobalAveragePooling2D()(x)
# let's add a fully-connected layer
x = Dense(1024, activation='relu')(x)
# and a logistic layer -- let's say we have 200 classes
predictions = Dense(200, activation='softmax')(x)

# this is the model we will train
model = Model(inputs=base_model.input, outputs=predictions)

# first: train only the top layers (which were randomly initialized)
# i.e. freeze all convolutional InceptionV3 layers
for layer in base_model.layers:
    layer.trainable = False

# compile the model (should be done *after* setting layers to non-trainable)
model.compile(optimizer='rmsprop', loss='categorical_crossentropy')

# train the model on the new data for a few epochs
model.fit(...)

# at this point, the top layers are well trained and we can start fine-tuning
# convolutional layers from inception V3. We will freeze the bottom N layers
# and train the remaining top layers.

# let's visualize layer names and layer indices to see how many layers
# we should freeze:
for i, layer in enumerate(base_model.layers):
   print(i, layer.name)

# we chose to train the top 2 inception blocks, i.e. we will freeze
# the first 249 layers and unfreeze the rest:
for layer in model.layers[:249]:
   layer.trainable = False
for layer in model.layers[249:]:
   layer.trainable = True

# we need to recompile the model for these modifications to take effect
# we use SGD with a low learning rate
from tensorflow.keras.optimizers import SGD
model.compile(optimizer=SGD(lr=0.0001, momentum=0.9), loss='categorical_crossentropy')

# we train our model again (this time fine-tuning the top 2 inception blocks
# alongside the top Dense layers
model.fit(...)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-51-8ad366ecc04d> in <module>()
#      27
#      28 # train the model on the new data for a few epochs
# ---> 29 model.fit(...)
#      30
#      31 # at this point, the top layers are well trained and we can start fine-tuning
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1146           use_multiprocessing=use_multiprocessing,
#    1147           model=self,
# -> 1148           steps_per_execution=self._steps_per_execution)
#    1149
#    1150       # Container that configures and calls `tf.keras.Callback`s.
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/data_adapter.py in get_data_handler(*args, **kwargs)
#    1381   if getattr(kwargs["model"], "_cluster_coordinator", None):
#    1382     return _ClusterCoordinatorDataHandler(*args, **kwargs)
# -> 1383   return DataHandler(*args, **kwargs)
#    1384
#    1385
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/data_adapter.py in __init__(self, x, y, sample_weight, batch_size, steps_per_epoch, initial_epoch, epochs, shuffle, class_weight, max_queue_size, workers, use_multiprocessing, model, steps_per_execution, distribute)
#    1135       self._steps_per_execution_value = steps_per_execution.numpy().item()
#    1136
# -> 1137     adapter_cls = select_data_adapter(x, y)
#    1138     self._adapter = adapter_cls(
#    1139         x,
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/data_adapter.py in select_data_adapter(x, y)
#     977         "Failed to find data adapter that can handle "
#     978         "input: {}, {}".format(
# --> 979             _type_name(x), _type_name(y)))
#     980   elif len(adapter_cls) > 1:
#     981     raise RuntimeError(
#
# ValueError: Failed to find data adapter that can handle input: <class 'ellipsis'>, <class 'NoneType'>

# %% [markdown]
# # Build InceptionV3 over a custom input tensor

# %%
from tensorflow.keras.applications.inception_v3 import InceptionV3
from tensorflow.keras.layers import Input

# this could also be the output a different Keras model or layer
input_tensor = Input(shape=(224, 224, 3))

model = InceptionV3(input_tensor=input_tensor, weights='imagenet', include_top=True)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels.h5
# 96116736/96112376 [==============================] - 1s 0us/step
# 96124928/96112376 [==============================] - 1s 0us/step

# %% [markdown]
# 3. Select the best model from assignment 2 for 15 classification tasks.
# a. Train and test single DCNN model on 15 classification tasks. Ref. the best model from
# assignment 2.
# b. Ensemble the three models and compare the results against the single model
# implementation in 3(a). Ref. code: Lecture_10_model_ensemble. ipynb

# %%
import matplotlib.pyplot as plt
import numpy as np

from sklearn.ensemble import VotingClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from keras.datasets import mnist
from keras.wrappers.scikit_learn import KerasClassifier
from keras.datasets import mnist
from keras.models import Sequential
from keras.utils.np_utils import to_categorical
from keras.models import Sequential
from keras.layers import Activation, Dense, BatchNormalization, Dropout
from keras import optimizers

# %% [markdown]
# # Load Dataset

# %%
X_train="/content/drive/MyDrive/2021 Spring Courses/train_validation/train"
X_test="/content/drive/MyDrive/2021 Spring Courses/train_validation/validation"

# %%
#(X_train, y_train), (X_test, y_test) = mnist.load_data()

# reshaping X data: (n, 28, 28) => (n, 784)
X_train = X_train.reshape((X_train.shape[0], X_train.shape[1] * X_train.shape[2]))
X_test = X_test.reshape((X_test.shape[0], X_test.shape[1] * X_test.shape[2]))


# We use all training data and validate on all test data
print(X_train.shape)
print(X_test.shape)
#print(y_train.shape)
#print(y_test.shape)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-62-0b016134e32d> in <module>()
#       2
#       3 # reshaping X data: (n, 28, 28) => (n, 784)
# ----> 4 X_train = X_train.reshape((X_train.shape[0], X_train.shape[1] * X_train.shape[2]))
#       5 X_test = X_test.reshape((X_test.shape[0], X_test.shape[1] * X_test.shape[2]))
#       6
#
# AttributeError: 'str' object has no attribute 'reshape'

# %% [markdown]
# # Training & Validating Model
# - Measures to improve training is applied simultaneously
# - More training set
# - Weight Initialization scheme
# - Nonlinearity (Activation function)
# - Optimizers: adaptvie
# - Batch Normalization
# - Dropout (Regularization)
# - Model Ensemble

# %%
def mlp_model():
    model = Sequential()
    
    model.add(Dense(50, input_shape = (784, ), kernel_initializer='he_normal'))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(Dropout(0.2))
    model.add(Dense(50, kernel_initializer='he_normal'))
    model.add(BatchNormalization())
    model.add(Activation('relu'))    
    model.add(Dropout(0.2))
    model.add(Dense(50, kernel_initializer='he_normal'))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(Dropout(0.2))
    model.add(Dense(50, kernel_initializer='he_normal'))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(Dropout(0.2))
    model.add(Dense(10, kernel_initializer='he_normal'))
    model.add(Activation('softmax'))
    
    adam = optimizers.Adam(lr = 0.001)
    model.compile(optimizer = adam, loss = 'categorical_crossentropy', metrics = ['accuracy'])
    
    return model

# %%
# create 5 models to ensemble
model1 = KerasClassifier(build_fn = mlp_model, epochs = 10)
model2 = KerasClassifier(build_fn = mlp_model, epochs = 10)
model3 = KerasClassifier(build_fn = mlp_model, epochs = 10)
model4 = KerasClassifier(build_fn = mlp_model, epochs = 10)
model5 = KerasClassifier(build_fn = mlp_model, epochs = 10)

# %%
ensemble_clf = VotingClassifier(estimators = [('model1', model1), ('model2', model2), ('model3', model3), ('model4', model4), ('model5', model5)], voting = 'soft')

# %%
#ensemble_clf.fit(X_train, y_train)

# %%
#y_pred = ensemble_clf.predict(X_test)
#print('Acc: ', accuracy_score(y_pred, y_test))
